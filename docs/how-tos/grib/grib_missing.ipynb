# %% [markdown]
# # GRIB: missing values

# %% [raw]
# We read a GRIB file containing 2 messages with missing values using :ref:`from_source() <data-sources-file>`. First we ensure the example file is available.

# %%
import numpy as np

import earthkit.data as ekd

ekd.download_example_file("missing.grib")

# %%
ds = ekd.from_source("file", "missing.grib").to_fieldlist()

# %%
ds.ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                 2t 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
# 1                msl 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0               0             surface               0          regular_ll
# 1               0             surface               0          regular_ll

# %% [markdown]
# When can see how many missing values we have by inspecting the metadata:

# %%
ds.metadata("bitmapPresent")
# Out:
# [1, 1]

# %%
ds.metadata("numberOfMissingValues")
# Out:
# [142, 13]

# %% [markdown]
# When data values are extracted as numpy arrays missing values are automatically replaced by np.nan:

# %%
for f in ds:
    v = f.values
    print(f"Number of nans={np.count_nonzero(np.isnan(v))}")
# Out:
# Number of nans=142
# Number of nans=13
