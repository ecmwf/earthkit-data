# %% [markdown]
# ## Reduced Gaussian grid

# %%
import earthkit.data

fname = "reduced_gg_O32.grib1"
earthkit.data.download_example_file(fname, remote_dir="test-data/xr_engine/grid")
ds_ek = earthkit.data.from_source("file", fname)

# %%
ds = ds_ek.to_xarray()
ds
# Out:
# Finding coords in dataset for ('step',):   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('step',):   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 252kB
# Dimensions:    (step: 2, values: 5248)
# Coordinates:
#   * step       (step) timedelta64[ns] 16B 00:00:00 06:00:00
#     latitude   (values) float64 42kB ...
#     longitude  (values) float64 42kB ...
# Dimensions without coordinates: values
# Data variables:
#     r          (step, values) float64 84kB ...
#     t          (step, values) float64 84kB ...
