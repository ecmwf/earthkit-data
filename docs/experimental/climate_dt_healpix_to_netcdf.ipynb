# %% [markdown]
# ## Convert Climate DT data into CF compliant NetCDF

# %%
import earthkit.data

r = {
        "class": "d1",
        "dataset": "climate-dt",
        "activity": "ScenarioMIP",
        "experiment": "SSP3-7.0",
        "generation": "1",
        "realization": "1",
        "model": "IFS-NEMO",
        "resolution": "high",
        "expver": "0001",
        "stream": "clte",
        "date": "20220903/20220904", # 20200101/20200102
        "time": "0000/0012", # 1/to/12/by/1
        "step": "0/12",
        "type": "fc",
        "levtype": "hl",
        "levelist" : "100",
        "param": "228246/228247",
    }
 
ds = earthkit.data.from_source("polytope", "destination-earth", r, 
                                 address="polytope.lumi.apps.dte.destination-earth.eu", 
                                 stream=False)

a = ds.to_xarray(profile="grib")
a
# Out:
# 2024-08-04 21:46:52 - INFO - Key read from /Users/cgr/.polytopeapirc
# 2024-08-04 21:46:52 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             'date: 20220903/20220904\n'
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             "levelist: '100'\n"
#             'levtype: hl\n'
#             'model: IFS-NEMO\n'
#             'param: 228246/228247\n'
#             "realization: '1'\n"
#             'resolution: high\n'
#             'step: 0/12\n'
#             'stream: clte\n'
#             'time: 0000/0012\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2024-08-04 21:46:52 - INFO - Polytope user key found in session cache for user cgr
# 2024-08-04 21:46:53 - INFO - Request accepted. Please poll http://polytope.lumi.apps.dte.destination-earth.eu/api/v1/requests/a2d1da0c-4725-4f0b-9649-43dd07b4934e for status
# 2024-08-04 21:46:53 - INFO - Polytope user key found in session cache for user cgr
# 2024-08-04 21:46:53 - INFO - Checking request status (a2d1da0c-4725-4f0b-9649-43dd07b4934e)...
# 2024-08-04 21:46:54 - INFO - The current status of the request is 'queued'
# 2024-08-04 21:46:54 - INFO - The current status of the request is 'processing'
# 2024-08-04 21:46:57 - INFO - The current status of the request is 'processed'
# a2d1da0c-4725-4f0b-9649-43dd07b4934e.grib:   0%|          | 0.00/106M [00:00<?, ?B/s]
# <xarray.Dataset> Size: 604MB
# Dimensions:                  (forecast_reference_time: 2, values: 12582912)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 16B 202...
#     latitude                 (values) float64 101MB ...
#     longitude                (values) float64 101MB ...
# Dimensions without coordinates: values
# Data variables:
#     100u                     (forecast_reference_time, values) float64 201MB ...
#     100v                     (forecast_reference_time, values) float64 201MB ...
# Attributes:
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %%
a.to_netcdf("_climate_dt_healpix.nc")

# %%
import subprocess
result = subprocess.run(["ncdump", "-h", "_climate_dt_healpix.nc"], stdout=subprocess.PIPE)
t = result.stdout.decode('utf-8').split('\n')
for line in t:
    print(line)
# Out:
# netcdf _climate_dt_healpix {
# dimensions:
# 	forecast_reference_time = 2 ;
# 	values = 12582912 ;
# variables:
# 	double \100u(forecast_reference_time, values) ;
# 		\100u:_FillValue = NaN ;
# 		\100u:standard_name = "eastward_wind" ;
# 		\100u:long_name = "100 metre U wind component" ;
# 		\100u:units = "m s**-1" ;
# 		\100u:typeOfLevel = "heightAboveGround" ;
# 		\100u:coordinates = "latitude longitude" ;
# 	double \100v(forecast_reference_time, values) ;
# 		\100v:_FillValue = NaN ;
# 		\100v:standard_name = "northward_wind" ;
# 		\100v:long_name = "100 metre V wind component" ;
# 		\100v:units = "m s**-1" ;
# 		\100v:typeOfLevel = "heightAboveGround" ;
# 		\100v:coordinates = "latitude longitude" ;
# 	int64 forecast_reference_time(forecast_reference_time) ;
# 		forecast_reference_time:standard_name = "forecast_reference_time" ;
# 		forecast_reference_time:long_name = "initial time of forecast" ;
# 		forecast_reference_time:units = "days since 2022-09-03 00:00:00" ;
# 		forecast_reference_time:calendar = "proleptic_gregorian" ;
# 	double latitude(values) ;
# 		latitude:_FillValue = NaN ;
# 		latitude:units = "degrees_north" ;
# 		latitude:standard_name = "latitude" ;
# 		latitude:long_name = "latitude" ;
# 	double longitude(values) ;
# 		longitude:_FillValue = NaN ;
# 		longitude:units = "degrees_east" ;
# 		longitude:standard_name = "longitude" ;
# 		longitude:long_name = "longitude" ;
#
# // global attributes:
# 		:Conventions = "CF-1.8" ;
# 		:institution = "ECMWF" ;
# }
