# %% [markdown]
# ## Mixed analysis and forecast

# %%
import earthkit.data

fname = "pl_an_fc.grib"
earthkit.data.download_example_file(fname, remote_dir="test-data/xr_engine/level")
ds_ek = earthkit.data.from_source("file", fname)

# %%
ds = ds_ek.to_xarray()
ds
# Out:
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds = ds_ek.to_xarray()
#       2 ds
#
# File ~/git/earthkit-data/src/earthkit/data/readers/grib/xarray.py:150, in XarrayMixIn.to_xarray(self, engine, xarray_open_dataset_kwargs, **kwargs)
#     147         backend_kwargs[key] = user_xarray_open_dataset_kwargs.pop(key)
#     148 user_xarray_open_dataset_kwargs["backend_kwargs"] = backend_kwargs
# --> 150 return engines[engine](user_xarray_open_dataset_kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/readers/grib/xarray.py:187, in XarrayMixIn.to_xarray_earthkit(self, user_kwargs)
#     182 # print(f"{kwargs=}")
#     183 # print(f"{xarray_open_dataset_kwargs=}")
#     185 from earthkit.data.utils.xarray.engine import from_earthkit
# --> 187 return from_earthkit(self, **xarray_open_dataset_kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/utils/xarray/engine.py:30, in from_earthkit(ds, **kwargs)
#      28     backend_kwargs.pop("auto_split", None)
#      29     backend_kwargs.pop("split_dims", None)
# ---> 30     return xarray.open_dataset(ds, **kwargs)
#      31 else:
#      32     from .builder import SplitDatasetBuilder
#
# File ~/git/xarray/xarray/backends/api.py:578, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     566 decoders = _resolve_decoders_kwargs(
#     567     decode_cf,
#     568     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     574     decode_coords=decode_coords,
#     575 )
#     577 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 578 backend_ds = backend.open_dataset(
#     579     filename_or_obj,
#     580     drop_variables=drop_variables,
#     581     **decoders,
#     582     **kwargs,
#     583 )
#     584 ds = _dataset_from_backend_dataset(
#     585     backend_ds,
#     586     filename_or_obj,
#    (...)
#     596     **kwargs,
#     597 )
#     598 return ds
#
# File ~/git/earthkit-data/src/earthkit/data/utils/xarray/engine.py:174, in EarthkitBackendEntrypoint.open_dataset(self, filename_or_obj, source_type, variable_key, drop_variables, extra_variable_attrs, extra_global_attrs, extra_dims, drop_dims, ensure_dims, fixed_dims, flatten_values, remapping, profile, time_dim_mode, time_dim_mapping, add_valid_time_coord, decode_time, level_dim_mode, add_geo_coords, merge_cf_and_pf, errors, array_module)
#     172 else:
#     173     from .builder import SingleDatasetBuilder
# --> 174 return SingleDatasetBuilder(fieldlist, **_kwargs).build()
#
# File ~/git/earthkit-data/src/earthkit/data/utils/xarray/builder.py:368, in SingleDatasetBuilder.build(self)
#     357 dims = profile.dims.to_list()
#     358 builder = TensorBackendBuilder(
#     359     ds_sorted,
#     360     profile,
#    (...)
#     365     array_module=numpy,
#     366 )
# --> 368 return builder.build()
#
# File ~/git/earthkit-data/src/earthkit/data/utils/xarray/builder.py:158, in TensorBackendBuilder.build(self)
#     156 # we assume each variable forms a full cube
#     157 for variable in self.profile.variables:
# --> 158     xr_vars[variable] = self.make_variable(self.ds, self.dims, self.profile.variable_key, variable)
#     160 attrs = self.profile.g_attrs.attrs(self.ds)
#     161 coords = self.profile.rename_coords(self.coords())
#
# File ~/git/earthkit-data/src/earthkit/data/utils/xarray/builder.py:189, in TensorBackendBuilder.make_variable(self, ds, dims, key, name)
#     169 # tensor_coords = {}
#     170 # for d in dims:
#     171 #     num = len(ds_var.index(d.key))
#    (...)
#     184 #                     )
#     185 #                 )
#     187 tensor_dim_keys = [d.key for d in tensor_dims]
# --> 189 tensor = ds_var.to_tensor(
#     190     *tensor_dim_keys,
#     191     sort=False,
#     192     progress_bar=False,
#     193     # user_coords=tensor_coords,
#     194     field_dims_and_coords=(self.grid.dims, self.grid.coords),
#     195     flatten_values=self.flatten_values,
#     196 )
#     198 var_dims = []
#     199 for d in tensor_dims:
#
# File ~/git/earthkit-data/src/earthkit/data/core/fieldlist.py:1445, in FieldList.to_tensor(self, *args, **kwargs)
#    1442 def to_tensor(self, *args, **kwargs):
#    1443     from earthkit.data.indexing.tensor import FieldListTensor
# -> 1445     return FieldListTensor.from_fieldlist(self, *args, **kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/tensor.py:540, in FieldListTensor.from_fieldlist(cls, ds, remapping, flatten_values, sort, progress_bar, user_dims_and_coords, field_dims_and_coords, *args)
#     495     field_dims, field_coords, _ = FieldListTensor._field_part(source[0], flatten_values)
#     497 # first = source[0]
#     498
#     499 # # determine field shape
#    (...)
#     538 #             f.unload()
#     539 # diag(" LATLON")
# --> 540 return cls(source, user_coords, field_coords, field_dims, flatten_values)
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/tensor.py:423, in FieldListTensor.__init__(self, source, user_coords, field_coords, field_dims, flatten_values)
#     421 # consistency check
#     422 checker = CubeChecker(self)
# --> 423 checker.check(details=True)
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/tensor.py:167, in CubeChecker.check(self, details)
#     164 for k, v in md.items():
#     165     text_meta += f"{k}:\n {v}\n"
# --> 167 raise ValueError(f"{text_num}{text_dims}{text_ns}{text_meta}")
#
# ValueError: Input does not form a full hypercube with dimensions=['levelist']. Expected number of fields based on the dimensions does not match actual number of fields: 2 != 4.
# Dimension sizes: {'levelist': 2}
# First difference from the expected dimensions occurs at field[1] for dimension "levelist". Expected 850 got 500.
# Comparing field[1] with field[0], the following metadata difference was found:
# namespace=mars:
#  type: fc != an
# namespace=ls:
#  dataType: fc != an
#
# Field[1] metadata:
# dims:
#  {'levelist': 500}
# namespace=mars:
#  {'domain': 'g', 'levtype': 'pl', 'levelist': 500, 'date': 20240718, 'time': 0, 'step': 0, 'param': 't', 'class': 'od', 'type': 'an', 'stream': 'oper', 'expver': '0001'}
# namespace=ls:
#  {'edition': 1, 'centre': 'ecmf', 'typeOfLevel': 'isobaricInhPa', 'level': 500, 'dataDate': 20240718, 'stepRange': '0', 'dataType': 'an', 'shortName': 't', 'packingType': 'grid_simple', 'gridType': 'regular_ll'}
# namespace=time:
#  {'dataDate': 20240718, 'dataTime': 0, 'stepUnits': 1, 'stepType': 'instant', 'stepRange': '0', 'startStep': 0, 'endStep': 0, 'validityDate': 20240718, 'validityTime': 0}
# namespace=vertical:
#  {'typeOfLevel': 'isobaricInhPa', 'level': 500}
# namespace=geography:
#  {'bitmapPresent': 0, 'latitudeOfFirstGridPointInDegrees': 90.0, 'longitudeOfFirstGridPointInDegrees': 0.0, 'latitudeOfLastGridPointInDegrees': -90.0, 'longitudeOfLastGridPointInDegrees': 350.0, 'iScansNegatively': 0, 'jScansPositively': 0, 'jPointsAreConsecutive': 0, 'jDirectionIncrementInDegrees': 10.0, 'iDirectionIncrementInDegrees': 10.0, 'gridType': 'regular_ll'}
