# %% [markdown]
# ## Time

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

# %%
f = ds[5]

# %%
f.time.to_dict()
# Out:
# {'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#  'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#  'step': datetime.timedelta(0)}

# %%
f.time.base_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time.valid_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time.step
# Out:
# datetime.timedelta(0)

# %%
f.base_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
#
#   number grid_type
# 0   None      None

# %%
f.datetime()
# Out:
# {'base_time': datetime.datetime(2018, 8, 1, 12, 0),
#  'valid_time': datetime.datetime(2018, 8, 1, 12, 0)}

# %%
f.time.base_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time_base_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.sel(base_datetime=...)

# %%
f.forecast_reference_time
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time.forecast_reference_time
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
type(f.time).forecast_reference_time.__doc__
# Out:
# 'Return the forecast_reference_time. Alias for :obj:`base_datetime`.'

# %%
type(f.time)
# Out:
# earthkit.data.field.spec.time.Time

# %%
f.get_as_dict("valid_datetime", "step")
# Out:
# {'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#  'step': datetime.timedelta(0)}

# %%
f.get("time.valid_datetime")
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.get("time_valid_datetime")
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time

# %%
f.step
# Out:
# datetime.timedelta(0)

# %%
r = f.set(step=6)

# %%
r.step
# Out:
# datetime.timedelta(seconds=21600)

# %%
r.valid_datetime
# Out:
# datetime.datetime(2018, 8, 1, 18, 0)

# %%
f.set(aaa=2)

# %%
f.get("grib.stream")
# Out:
# 'oper'

# %%
f.namespace("grib.mars")
# Out:
# GribEnsembleBuilder.build: {'member': 0}
# {'grib.mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 850,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 'v',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'}}

# %%
f.namespace("grib")
# Out:
# {'grib.ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 850,
#   'dataDate': 20180801,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 'v',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'grib.geography': {'Ni': 12,
#   'Nj': 7,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPointInDegrees': 330.0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 30.0,
#   'iDirectionIncrementInDegrees': 30.0,
#   'gridType': 'regular_ll'},
#  'grib.mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 850,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 'v',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'},
#  'grib.parameter': {'centre': 'ecmf',
#   'paramId': 132,
# ...

# %%
f.namespace("time")
# Out:
# {'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)}}

# %%
f.dump()
# Out:
# {'parameter': {'variable': 'v', 'units': 'm s**-1'},
#  'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'vertical': {'level': 850, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '0'}}
