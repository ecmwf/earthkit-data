# %% [markdown]
# ## Proc

# %%
import earthkit.data as ekd
# ds = ekd.from_source("file", "/Users/cgr/git/earthkit-data/docs/examples/tuv_pl.grib")


path = "~/metview/earthkit/xr_engine/nexus/downloads/test-data/earthkit-data/test-data/xr_engine/date/tp_step_range.grib2"
ds = ekd.from_source("file", path)

# %%
f = ds[0]

# %%
f.proc.time
# Out:
# GribProcBuilder.build: {'time': {'value': datetime.timedelta(seconds=3600), 'method': <TimeMethods.ACCUMULATED: <earthkit.data.field.spec.time_span.TimeMethod object at 0x105d0b8c0>>}}
# TimeProcItem(1:00:00, accum)

# %%
f.proc

# %%
f.proc.items
# Out:
# [TimeProcItem(1:00:00, accum)]

# %%
f.proc.time
# Out:
# TimeProcItem(1:00:00, accum)

# %%
f.proc.time.value
# Out:
# datetime.timedelta(seconds=3600)

# %%
f.proc.time.method

# %%
#f.get("proc.temporal.value")

# %%
f.time

# %%
f.time.valid_datetime, f.get("time_valid_datetime")
# Out:
# (datetime.datetime(2025, 5, 30, 0, 0), datetime.datetime(2025, 5, 30, 0, 0))

# %%
#f.proc_time_value

# %%
#f.time_span

# %%
f.get("proc_time")
# Out:
# TimeProcItem(1:00:00, accum)

# %%
f.get("proc.time")
# Out:
# TimeProcItem(1:00:00, accum)

# %%
f.get("proc.time_value")
# Out:
# datetime.timedelta(seconds=3600)

# %%
# r = f.set(proc_time_value="6h")

# %%
f.get("proc")
