# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

# %%
f = ds[0]

# %%
f.time

# %%
f.time.valid_datetime()
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time.base_datetime()
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.time.step()
# Out:
# datetime.timedelta(0)

# %%
f.time.forecast_period()
# Out:
# datetime.timedelta(0)

# %%
f.time.forecast_reference_time()
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.geography.latitudes().shape
# Out:
# (7, 12)

# %%
f.geography.longitudes().shape
# Out:
# (7, 12)

# %%
f.geography.latitudes()[0:3], f.geography.longitudes()[0:3]
# Out:
# (array([[90., 90., 90., 90., 90., 90., 90., 90., 90., 90., 90., 90.],
#         [60., 60., 60., 60., 60., 60., 60., 60., 60., 60., 60., 60.],
#         [30., 30., 30., 30., 30., 30., 30., 30., 30., 30., 30., 30.]]),
#  array([[  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.,
#          330.],
#         [  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.,
#          330.],
#         [  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.,
#          330.]]))

# %%
#f.projection

# %%
f.vertical.level()
# Out:
# 1000

# %%
f.vertical.type()
# Out:
# 'pressure'

# %%
f.parameter.variable()
# Out:
# 't'

# %%
f.parameter.units()
# Out:
# 'K'

# %%
f.ensemble.member()
# Out:
# '0'

# %%
f.values.shape
# Out:
# (84,)

# %%
f.to_numpy(flatten=False).shape
# Out:
# (7, 12)

# %%
f.to_array(flatten=True, array_backend="torch")
# Out:
# tensor([272.5642, 272.5642, 272.5642, 272.5642, 272.5642, 272.5642, 272.5642,
#         272.5642, 272.5642, 272.5642, 272.5642, 272.5642, 288.5642, 296.5642,
#         288.5642, 288.5642, 288.5642, 288.5642, 280.5642, 288.5642, 296.5642,
#         288.5642, 280.5642, 280.5642, 312.5642, 304.5642, 320.5642, 296.5642,
#         304.5642, 296.5642, 296.5642, 296.5642, 288.5642, 296.5642, 296.5642,
#         296.5642, 296.5642, 304.5642, 296.5642, 304.5642, 296.5642, 296.5642,
#         296.5642, 296.5642, 296.5642, 296.5642, 296.5642, 296.5642, 288.5642,
#         296.5642, 288.5642, 288.5642, 280.5642, 288.5642, 288.5642, 288.5642,
#         288.5642, 288.5642, 280.5642, 288.5642, 272.5642, 264.5642, 264.5642,
#         272.5642, 272.5642, 272.5642, 280.5642, 272.5642, 264.5642, 264.5642,
#         272.5642, 272.5642, 240.5642, 240.5642, 240.5642, 240.5642, 240.5642,
#         240.5642, 240.5642, 240.5642, 240.5642, 240.5642, 240.5642, 240.5642],
#        dtype=torch.float64)

# %%
f.to_numpy(dtype="float32").dtype
# Out:
# dtype('float32')

# %%
v = f.values
f1 = f.set(values=v+1)
f.values.max(), f1.values.max()
# Out:
# (np.float64(320.5641784667969), np.float64(321.5641784667969))

# %%
f1.time.base_datetime()
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f.get("metadata.class")
# Out:
# 'od'

# %%
# ds.ls()

# %%
f.get("metadata.bitsPerValue")
# Out:
# 4

# %%
f.get("time.valid_datetime")
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f1 = f.set({"vertical.level": 111})

# %%
f1.vertical.level()
# Out:
# 111

# %%
f1.get("metadata.typeOfLevel")
# Out:
# 'isobaricInhPa'

# %%
#f.namespace("grib.mars")

# %%
#f.dump()

# %%
#f.dump(namespace="grib")
