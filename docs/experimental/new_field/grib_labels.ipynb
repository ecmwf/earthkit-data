# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

f = ds[0]

# %%
f.get("shortName")

# %%
f.get("paramId")

# %%
f.get("grib.shortName")
# Out:
# 't'

# %%
f.get("name")

# %%
f.get("my_name")

# %%
f1 = f.set(my_name="theta")

# %%
f1.get("my_name")
# Out:
# 'theta'

# %%
f1 = f.set(name="alpha")
f1.get("name")
# Out:
# 'alpha'

# %%
#f1.labels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 f1.labels
#
# AttributeError: 'Field' object has no attribute 'labels'
