# %% [markdown]
# ## Data

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

# %%
f = ds[0]

# %%
f.values.shape, f.values[:5]
# Out:
# ((84,),
#  array([272.56417847, 272.56417847, 272.56417847, 272.56417847,
#         272.56417847]))

# %%
v =  f.values + 100
r = f.set(values=v)

# %%
r.values.shape, r.values[:5]
# Out:
# ((84,),
#  array([372.56417847, 372.56417847, 372.56417847, 372.56417847,
#         372.56417847]))
