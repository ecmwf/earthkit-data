# %% [markdown]
# ## Ensemble

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../../tests/data/ens_50.grib")

# %%
f = ds[0]

# %%
f.member
# Out:
# GribEnsembleBuilder.build: {'member': 1}
# '1'

# %%
f.ensemble.realization
# Out:
# '1'

# %%
f.ensemble

# %%
f.get("member")
# Out:
# '1'

# %%
# dir(f)

# %%
r = f.set(member=12)

# %%
r.member
# Out:
# '12'

# %%
f.dump("grib")
# Out:
# {'grib.ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 850,
#   'dataDate': 20131025,
#   'stepRange': '78',
#   'dataType': 'pf',
#   'shortName': 'z',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'grib.geography': {'Ni': 3,
#   'Nj': 2,
#   'latitudeOfFirstGridPointInDegrees': 60.0,
#   'longitudeOfFirstGridPointInDegrees': -10.0,
#   'latitudeOfLastGridPointInDegrees': 50.0,
#   'longitudeOfLastGridPointInDegrees': 10.0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 10.0,
#   'iDirectionIncrementInDegrees': 10.0,
#   'gridType': 'regular_ll'},
#  'grib.mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 850,
#   'date': 20131025,
#   'time': 0,
#   'step': 78,
#   'param': 'z',
#   'class': 'od',
#   'type': 'pf',
#   'stream': 'enfo',
#   'expver': '0001',
#   'number': 1,
#   '_leg_number': 1},
# ...

# %%
f.dump()
# Out:
# {'parameter': {'variable': 'z', 'units': 'm**2 s**-2'},
#  'time': {'base_datetime': datetime.datetime(2013, 10, 25, 0, 0),
#   'valid_datetime': datetime.datetime(2013, 10, 28, 6, 0),
#   'step': datetime.timedelta(days=3, seconds=21600)},
#  'vertical': {'level': 850, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '1'}}
