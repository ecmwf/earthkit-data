# %% [markdown]
# ## Ensemble

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../../tests/data/ens_50.grib")

# %%
f = ds[0]

# %%
f.ensemble.member()
# Out:
# '1'

# %%
f.ensemble.realization()
# Out:
# '1'

# %%
f.ensemble

# %%
f.get("ensemble.member")
# Out:
# '1'

# %%
# dir(f)

# %%
r = f.set({"ensemble.member": 12})

# %%
r.ensemble.member()
# Out:
# '12'

# %%
#f.dump("grib")

# %%
#f.dump()
