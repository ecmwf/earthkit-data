# %% [markdown]
# ## Maths

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

f = ds[0]

# %%
f1 = f + 1

# %%
f.values.max(), f1.values.max()
# Out:
# (np.float64(320.5641784667969), np.float64(321.5641784667969))

# %%
f.ls()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 f.ls()
#
# File ~/git/earthkit-data/src/earthkit/data/core/field.py:1259, in Field.ls(self, *args, **kwargs)
#    1243 def ls(self, *args, **kwargs):
#    1244     r"""Generate a list-like summary using a set of metadata keys.
#    1245
#    1246     Parameters
#    (...)   1257
#    1258     """
# -> 1259     return self.to_fieldlist().ls(*args, **kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/indexed.py:383, in IndexedFieldList.ls(self, n, keys, extra_keys, namespace)
#     380         for i in pos_range:
#     381             yield (self[i]._get_fast(keys, output=dict))
# --> 383 return ls(_proc, self._default_ls_keys(), n=n, keys=keys, extra_keys=extra_keys, namespace=namespace)
#
# ...

# %%
#f1.ls()

# %%
type(f), type(f1)

# %%
# f1.to_target("file", "f1_plus1.grib", base_datetime=..., grib_shortName="q", metadata={"grib.shortName": "q"})
f1.to_target("file", "f1_plus1.grib")
ds1 = ekd.from_source("file", "f1_plus1.grib")
ds1[0].values.max()

# %%
ds1[0].ls()

# %%
r = (f*9.81).set(variable="gh")

# %%
r.ls()

# %%
r.values.max()
