# %% [markdown]
# ## Maths

# %%
import earthkit.data as ekd
ds = ekd.from_source("file", "../../examples/tuv_pl.grib")

f = ds[0]

# %%
f1 = f + 1

# %%
f.values.max(), f1.values.max()
# Out:
# (np.float64(320.5641784667969), np.float64(321.5641784667969))

# %%
f.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
#
#   number grid_type
# 0   None      None

# %%
f1.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
#
#   number grid_type
# 0   None      None

# %%
type(f), type(f1)
# Out:
# (earthkit.data.core.field.Field, earthkit.data.core.field.Field)

# %%
# f1.to_target("file", "f1_plus1.grib", base_datetime=..., grib_shortName="q", metadata={"grib.shortName": "q"})
f1.to_target("file", "f1_plus1.grib")
ds1 = ekd.from_source("file", "f1_plus1.grib")
ds1[0].values.max()
# Out:
# np.float64(321.5641784667969)

# %%
ds1[0].ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
#
#   number grid_type
# 0   None      None

# %%
r = (f*9.81).set(variable="gh")

# %%
r.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0       gh 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
#
#   number grid_type
# 0   None      None

# %%
r.values.max()
# Out:
# np.float64(3144.7345907592776)
