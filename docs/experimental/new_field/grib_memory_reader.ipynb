# %%
from earthkit.data import from_source

ds = from_source("file", "../../examples/tuv_pl.grib", stream=True, read_all=True)

# %%
type(ds)
# Out:
# earthkit.data.indexing.simple.SimpleFieldList

# %%
len(ds)
# Out:
# 18

# %%
ds[0].valid_datetime
# Out:
# datetime.datetime(2018, 8, 1, 12, 0)

# %%
f = ds.sel(param="t")

# %%
f.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700       None
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500       None
# 4        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    400       None
# 5        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    300       None
#
#   number grid_type
# 0   None      None
# 1   None      None
# 2   None      None
# 3   None      None
# 4   None      None
# 5   None      None

# %%
ds.ls()
# Out:
#    variable      valid_datetime       base_datetime   step  level level_type  \
# 0         t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 1         u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 2         v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 3         t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 4         u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 5         v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 6         t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700       None
# 7         u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700       None
# 8         v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700       None
# 9         t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500       None
# 10        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500       None
# ...

# %%
ds.sel(level=500)

# %%
# suppose level is an object 
# level.value # number
# level.type # object
ds.sel({"level.value": 500, "level.type.name": "pressure"})
