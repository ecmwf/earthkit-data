# %%
import os
os.environ['GRIB_DEFINITION_PATH'] = "/Users/cgr/git/eccodes-cosmo-resources/definitions:/Users/cgr/install/eccodes/release/share/eccodes/definitions"

# %%
import earthkit.data

#fname = "pl_an_fc.grib"
# earthkit.data.download_example_file(fname, remote_dir="test-data/xr_engine/level")
fname = "/Users/cgr/metview/earthkit/meteo-swiss/483a7194-f82d-4b04-925d-9b78917e9c66.grib"
ds_ek = earthkit.data.from_source("file", fname)

# %%
ds = ds_ek.to_xarray(fixed_dims=["perturbationNumber", "step", "level"], 
                     ensure_dims=["perturbationNumber", "step", "level"], 
                     mapping={"perturbationNumber": "eps", "step": "time", "levelist": "z"}, 
                     add_valid_time_coord=True,
                     decode_time=False,
                     strict=False)
ds
# Out:
# <xarray.Dataset> Size: 603MB
# Dimensions:     (perturbationNumber: 1, step: 1, levelist: 80, y: 786, x: 1170,
#                  eps: 1, time: 1, z: 80)
# Coordinates:
#   * eps         (eps) int64 8B 0
#   * time        (time) int64 8B 1
#   * z           (z) int64 640B 1 2 3 4 5 6 7 8 9 ... 72 73 74 75 76 77 78 79 80
#     valid_time  (time) datetime64[ns] 8B ...
#     latitude    (y, x) float64 7MB ...
#     longitude   (y, x) float64 7MB ...
# Dimensions without coordinates: perturbationNumber, step, levelist, y, x
# Data variables:
#     DBZ         (perturbationNumber, step, levelist, y, x) float64 589MB ...
# Attributes: (12/27)
#     param:        DBZ
#     class:        od
#     stream:       enfo
#     levtype:      ml
#     type:         ememb
#     expver:       0001
#     ...           ...
#     diagnostic:   None
#     iteration:    None
#     number:       0
#     quantile:     None
#     Conventions:  CF-1.8
#     institution:  ECMWF
