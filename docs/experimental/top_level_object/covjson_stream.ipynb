# %%
import os

import earthkit.data as ekd

p = os.path.expanduser("~/git/earthkit-data/tests/data/points.covjson")

stream = open(p, "rb")
ds = ekd.from_source("stream", stream)
# Out:
# _from_source: src= <earthkit.data.sources.stream.StreamSource object at 0x1077467b0>
# src= <earthkit.data.sources.stream.StreamSource object at 0x1077467b0>

# %%
ds.to_xarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds.to_xarray()
#
# File ~/git/earthkit-data/src/earthkit/data/readers/covjson.py:153, in CovjsonData.to_xarray(self, **kwargs)
#     152 def to_xarray(self, **kwargs):
# --> 153     return self._reader.to_xarray(**kwargs)
#
# AttributeError: 'CovjsonStreamReader' object has no attribute 'to_xarray'

# %%
ds.available_types
