# %%
import os

import xarray as xr

import earthkit.data as ekd

p = os.path.expanduser("~/git/earthkit-data/docs/examples/test.nc")
ds_in = xr.open_dataset(p)

ds = ekd.from_object(ds_in)
# Out:
# /var/folders/93/w0p869rx17q98wxk83gn9ys40000gn/T/ipykernel_15452/1469585170.py:6: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds_in = xr.open_dataset(p)

# %%
ds

# %%
ds.available_types
# Out:
# ['xarray', 'pandas', 'fieldlist', 'numpy', 'array']

# %%
ds.to_xarray()
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:     (latitude: 11, longitude: 19)
# Coordinates:
#   * latitude    (latitude) float64 88B 73.0 69.0 65.0 61.0 ... 41.0 37.0 33.0
#   * longitude   (longitude) float64 152B -27.0 -23.0 -19.0 ... 37.0 41.0 45.0
#     number      int32 4B ...
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     int32 4B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     t2m         (latitude, longitude) float32 836B ...
#     msl         (latitude, longitude) float32 836B ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 GRIB to CDM+CF via cfgrib-0.9.5/ecCodes-2.17.0 w...

# %%
ds.to_fieldlist().ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                t2m 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
# 1                msl 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0               0             surface               0                None
# 1               0             surface               0                None
