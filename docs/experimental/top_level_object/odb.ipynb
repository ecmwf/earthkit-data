# %%
import earthkit.data as ekd
import os

p = os.path.expanduser("~/git/earthkit-data/docs/examples/test.odb")

ds = ekd.from_source("file", p)
# Out:
# _from_source: src= File(/Users/cgr/git/earthkit-data/docs/examples/test.odb,ODBReader)
# src= File(/Users/cgr/git/earthkit-data/docs/examples/test.odb,ODBReader)

# %%
ds.available_types
# Out:
# ['pandas']

# %%
ds.to_pandas()
# Out:
#            lat        lon    fg_dep    an_dep
# 0    38.808998   4.292600  0.514543  0.513129
# 1    73.693100  -3.416700 -0.098977 -0.123831
# 2    31.168501 -29.865499  0.420131  0.389983
# 3    49.040798 -19.877501 -0.182703 -0.124131
# 4    73.351097  40.176102  0.087687  0.149949
# ..         ...        ...       ...       ...
# 712  45.798801  -0.527100  0.103859  0.132765
# 713  73.788597  -8.806200 -0.069707 -0.080577
# 714  60.162998 -14.572900  0.138816  0.011107
# 715  53.455299 -29.641600  0.082582  0.184872
# 716  40.669201  29.702101 -0.023861 -0.032721
#
# [717 rows x 4 columns]

# %%
ds.to_fieldlist()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ds.to_fieldlist()
#
# File ~/git/earthkit-data/src/earthkit/data/readers/odb.py:51, in ODBData.to_fieldlist(self, *args, **kwargs)
#      50 def to_fieldlist(self, *args, **kwargs):
# ---> 51     self._conversion_not_implemented()
#
# File ~/git/earthkit-data/src/earthkit/data/core/data.py:80, in Data._conversion_not_implemented(self)
#      77 else:
#      78     txt = f"Conversion of {self._TYPE_NAME} with {func} is not implemented"
# ---> 80 raise NotImplementedError(txt)
#
# NotImplementedError: Conversion of ODB to fieldlist is not implemented
