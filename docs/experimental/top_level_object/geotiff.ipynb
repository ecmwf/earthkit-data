# %%
import earthkit.data as ekd

ds = ekd.from_source("sample", "multi_band.tif")
# Out:
# multi_band.tif:   0%|          | 0.00/272k [00:00<?, ?B/s]
# _from_source: src= GeoTIFFReader(/var/folders/93/w0p869rx17q98wxk83gn9ys40000gn/T/tmp90o6digz/url-efd73649afe7cbfa94c8697fce07e4d6110fa29752ad8c08ffc3b129bb4fa1fa.tif)

# %%
ds

# %%
ds.available_types
# Out:
# ['xarray', 'pandas', 'fieldlist']

# %%
ds.to_xarray()
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:      (x: 315, y: 294)
# Coordinates:
#   * x            (x) float64 3kB 3.68e+05 3.681e+05 ... 3.839e+05 3.84e+05
#   * y            (y) float64 2kB 5.632e+06 5.632e+06 ... 5.616e+06 5.616e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     band_1       (y, x) float32 370kB ...
#     band_2       (y, x) float32 370kB ...
#     band_3       (y, x) float32 370kB ...
# Attributes:
#     TIFFTAG_XRESOLUTION:     96
#     TIFFTAG_YRESOLUTION:     96
#     TIFFTAG_RESOLUTIONUNIT:  2 (pixels/inch)
#     AREA_OR_POINT:           Area

# %%
ds.to_fieldlist().ls()
# Out:
#   parameter.variable time.valid_datetime time.base_datetime time.step  \
# 0             band_1                None               None      None
# 1             band_2                None               None      None
# 2             band_3                None               None      None
#
#   vertical.level vertical.level_type ensemble.member geography.grid_type
# 0           None             unknown            None                None
# 1           None             unknown            None                None
# 2           None             unknown            None                None
