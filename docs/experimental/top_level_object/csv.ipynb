# %%
import earthkit.data as ekd
import os

p = os.path.expanduser("~/git/earthkit-data/tests/data/test.csv")

ds = ekd.from_source("file",p)
# Out:
# _from_source: src= File(/Users/cgr/git/earthkit-data/tests/data/test.csv,CSVReader)
# src= File(/Users/cgr/git/earthkit-data/tests/data/test.csv,CSVReader)

# %%
ds

# %%
ds.available_types
# Out:
# ['pandas', 'xarray']

# %%
ds.to_pandas()
# Out:
#    h1   h2  h3 name
# 0   1  4.0   9    A
# 1   2  5.0   8    B
# 2   3  NaN   7    C
# 3   4  7.0   6    a
# 4   5  8.0   5    b
# 5   6  9.0   4    c

# %%
ds.to_xarray()
# Out:
# <xarray.Dataset> Size: 240B
# Dimensions:  (index: 6)
# Coordinates:
#   * index    (index) int64 48B 0 1 2 3 4 5
# Data variables:
#     h1       (index) int64 48B 1 2 3 4 5 6
#     h2       (index) float64 48B 4.0 5.0 nan 7.0 8.0 9.0
#     h3       (index) int64 48B 9 8 7 6 5 4
#     name     (index) object 48B 'A' 'B' 'C' 'a' 'b' 'c'
