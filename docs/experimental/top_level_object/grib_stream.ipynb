# %%
import os

import earthkit.data as ekd

p = os.path.expanduser("~/git/earthkit-data/docs/examples/test4.grib")
ds = ekd.from_source("file", p, stream=True)
# Out:
# HERE file
# from_source_internal: name= file
# Creating stream source for <earthkit.data.sources.file.FileSourcePathAndParts object at 0x104c46900>
# StreamFileSource: source after mutate_source= <earthkit.data.readers.grib.file.GRIBReader object at 0x107e59be0>
# Creating stream source for [<earthkit.data.sources.file.SingleStreamFileSource object at 0x108007620>]
# Created stream sources: [<earthkit.data.sources.stream.StreamSource object at 0x1080078c0>]
# Creating reader for stream <earthkit.data.sources.stream.Stream object at 0x108007770> with kwargs {}
# Created reader <earthkit.data.readers.grib.memory.GribStreamReader object at 0x108007a10>
# from_source_internal: src= <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>
# Convert source to data object: src= <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>

# %%
type(ds._reader)
# Out:
# earthkit.data.indexing.stream.StreamFieldList

# %%
ds

# %%
ds.available_types
# Out:
# ['fieldlist']

# %%
for f in ds.to_fieldlist():
    print(f)
# Out:
# Stream <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)

# %%
ds.to_fieldlist()
# Out:
# Stream <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>
# <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>

# %%
for f in ds.to_fieldlist():
    print(f)
# Out:
# Stream <earthkit.data.indexing.stream.StreamFieldList object at 0x108007cb0>
