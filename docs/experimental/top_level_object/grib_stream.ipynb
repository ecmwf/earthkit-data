# %%
import earthkit.data as ekd
import os

p = os.path.expanduser("~/git/earthkit-data/docs/examples/test4.grib")
ds = ekd.from_source("file", p, stream=True)
# Out:
# Creating stream source for <earthkit.data.sources.file.FileSourcePathAndParts object at 0x106d227b0>
# StreamFileSource: source after mutate_source= <earthkit.data.readers.grib.file.GRIBReader object at 0x109b81be0>
# _from_source: src= StreamFileSource(/Users/cgr/git/earthkit-data/docs/examples/test4.grib,GRIBReader)

# %%
type(ds._reader)
# Out:
# earthkit.data.readers.grib.file.GRIBReader

# %%
ds

# %%
ds.available_types
# Out:
# ['fieldlist', 'pandas', 'xarray', 'numpy', 'array']

# %%
for f in ds.to_fieldlist():
    print(f)
# Out:
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)

# %%
ds.to_fieldlist()
# Out:
# <earthkit.data.readers.grib.file.GribFieldListInFile object at 0x111b57ed0>

# %%
for f in ds.to_fieldlist():
    print(f)
# Out:
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)
