# %%
import earthkit.data as ekd

import os

p = [os.path.expanduser("~/git/earthkit-data/docs/examples/test.grib"),
     os.path.expanduser("~/git/earthkit-data/docs/examples/test4.grib")]
ds = ekd.from_source("file", p)
# Out:
# HERE file
# from_source_internal: name= file
# from_source_internal: name= file
# from_source_internal: src= <earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>
# from_source_internal: name= file
# from_source_internal: src= <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>
# from_source_internal: name= multi
# MultiSource: sources= [<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>]
# MultiSource: sources after _from_sources= [<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>]
# MultiSource: sources after mutate and ignore= [<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>]
# from_source_internal: src= MultiGRIBReader([<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>])
# from_source_internal: src= MultiGRIBReader([<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>])
# Convert source to data object: src= MultiGRIBReader([<earthkit.data.readers.grib.file.GRIBReader object at 0x11f6c5be0>, <earthkit.data.readers.grib.file.GRIBReader object at 0x119ee87d0>])

# %%
ds

# %%
ds.available_types
# Out:
# ['fieldlist', 'pandas', 'xarray', 'numpy', 'array']

# %%
ds.to_fieldlist().ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                 2t 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
# 1                msl 2020-05-13 12:00:00 2020-05-13 12:00:00    0 days
# 2                  t 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 3                  z 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 4                  t 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 5                  z 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0               0             surface               0          regular_ll
# 1               0             surface               0          regular_ll
# 2             500            pressure               0          regular_ll
# 3             500            pressure               0          regular_ll
# 4             850            pressure               0          regular_ll
# 5             850            pressure               0          regular_ll

# %%
type(ds.to_fieldlist())
# Out:
# earthkit.data.indexing.simple.SimpleFieldList

# %%
type(ds.to("fieldlist"))
# Out:
# earthkit.data.indexing.simple.SimpleFieldList

# %%
ds.to_xarray()

# %%
print(ds.describe())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(ds.describe())
#
# File ~/git/earthkit-data/src/earthkit/data/readers/grib/data.py:12, in GribData.describe(self)
#      11 def describe(self):
# ---> 12     return f"GRIB data from {self._reader.path}"
#
# AttributeError: 'MultiGRIBReader' object has no attribute 'path'

# %%
for f in ds.to_fieldlist():
    print(f)
