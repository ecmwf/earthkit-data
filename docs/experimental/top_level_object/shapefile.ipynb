# %%
import os

import earthkit.data as ekd

p = os.path.expanduser("~/git/earthkit-data/tests/data/NUTS_RG_20M_2021_3035.shp.zip")

ds = ekd.from_source("file", p)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# from_source_internal: src= File(CACHE:/file-993fa390d9ec8bd5ef42887d3997462200234009fea0b28dac8fc36d4b21bcb2.d/NUTS_RG_20M_2021_3035.cpg,TextReader)
# from_source_internal: src= File(CACHE:/file-993fa390d9ec8bd5ef42887d3997462200234009fea0b28dac8fc36d4b21bcb2.d/NUTS_RG_20M_2021_3035.dbf,UnknownReader)
# from_source_internal: src= File(CACHE:/file-993fa390d9ec8bd5ef42887d3997462200234009fea0b28dac8fc36d4b21bcb2.d/NUTS_RG_20M_2021_3035.prj,UnknownReader)
# from_source_internal: src= ShapeFileReader(/var/folders/93/w0p869rx17q98wxk83gn9ys40000gn/T/tmpsj2tg6or/file-993fa390d9ec8bd5ef42887d3997462200234009fea0b28dac8fc36d4b21bcb2.d/NUTS_RG_20M_2021_3035.shp)
# from_source_internal: src= File(CACHE:/file-993fa390d9ec8bd5ef42887d3997462200234009fea0b28dac8fc36d4b21bcb2.d/NUTS_RG_20M_2021_3035.shx,UnknownReader)
# ...

# %%
ds.available_types
# Out:
# ['geopandas', 'pandas', 'xarray', 'geojson']

# %%
ds.to_pandas()
# Out:
#      NUTS_ID  LEVL_CODE CNTR_CODE               NAME_LATN  \
# 0         FR          0        FR                  France
# 1         HR          0        HR                Hrvatska
# 2         HU          0        HU            Magyarország
# 3         AL          0        AL               Shqipëria
# 4         AT          0        AT              Österreich
# ...      ...        ...       ...                     ...
# 2005   TRC21          3        TR               Şanlıurfa
# 2006   TRC22          3        TR              Diyarbakır
# 2007   NO0B2          3        NO                Svalbard
# 2008    NO0B          2        NO  Jan Mayen and Svalbard
# 2009   NO0B1          3        NO               Jan Mayen
#
#                    NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE    FID  \
# 0                     France         0.0          0           0     FR
# 1                   Hrvatska         0.0          0           0     HR
# ...

# %%
fl = ds.to_featurelist()

# %%
type(fl)
# Out:
# earthkit.data.readers.shapefile.file.ShapeFileList

# %%
fl.head()
# Out:
#   NUTS_ID  LEVL_CODE CNTR_CODE     NAME_LATN     NUTS_NAME  MOUNT_TYPE  \
# 0      FR          0        FR        France        France         0.0
# 1      HR          0        HR      Hrvatska      Hrvatska         0.0
# 2      HU          0        HU  Magyarország  Magyarország         0.0
# 3      AL          0        AL     Shqipëria     Shqipëria         0.0
# 4      AT          0        AT    Österreich    Österreich         0.0
#
#    URBN_TYPE  COAST_TYPE FID  \
# 0          0           0  FR
# 1          0           0  HR
# 2          0           0  HU
# 3          0           0  AL
# 4          0           0  AT
#
#                                             geometry
# 0  MULTIPOLYGON (((9954236.116 -3059379.316, 9961...
# 1  MULTIPOLYGON (((4827385.889 2618351.326, 48483...
# 2  POLYGON ((5214660.069 2880853.832, 5216710.22 ...
# 3  POLYGON ((5129579.17 2204098.752, 5148385.473 ...
# 4  POLYGON ((4742889.368 2876362.725, 4783217.798...

# %%
fl._df
# Out:
#      NUTS_ID  LEVL_CODE CNTR_CODE               NAME_LATN  \
# 0         FR          0        FR                  France
# 1         HR          0        HR                Hrvatska
# 2         HU          0        HU            Magyarország
# 3         AL          0        AL               Shqipëria
# 4         AT          0        AT              Österreich
# ...      ...        ...       ...                     ...
# 2005   TRC21          3        TR               Şanlıurfa
# 2006   TRC22          3        TR              Diyarbakır
# 2007   NO0B2          3        NO                Svalbard
# 2008    NO0B          2        NO  Jan Mayen and Svalbard
# 2009   NO0B1          3        NO               Jan Mayen
#
#                    NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE    FID  \
# 0                     France         0.0          0           0     FR
# 1                   Hrvatska         0.0          0           0     HR
# ...
