# %%
import earthkit.data as ekd

ds = ekd.from_source("url", "https://get.ecmwf.int/repository/test-data/earthkit-data/examples/test4.grib", stream=True)
# Out:
# Creating stream source for [SingleUrlStream(['https://get.ecmwf.int/repository/test-data/earthkit-data/examples/test4.grib'])]
# Created stream sources: [<earthkit.data.sources.stream.StreamSource object at 0x11564c980>]
# Using GribStreamReader for stream
# _from_source: src= <earthkit.data.indexing.stream.StreamFieldList object at 0x1213b82f0>

# %%
ds.available_types
# Out:
# ['fieldlist']

# %%
ds

# %%
for f in ds.to_fieldlist():
    print(f)
# Out:
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 500, pressure, 0, regular_ll)
# Field(t, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)
# Field(z, 2007-01-01 12:00:00, 2007-01-01 12:00:00, 0:00:00, 850, pressure, 0, regular_ll)

# %%
for f in ds.to_fieldlist():
    print(f)
