# %% [markdown]
# ## Multiple soil levels and surface data

# %%
import earthkit.data

fname = "soil_and_sfc_levels.grib"
earthkit.data.download_example_file(fname, remote_dir="test-data/xr_engine/level")
ds_ek = earthkit.data.from_source("file", fname)

# %%
ds_ek.ls()
# Out:
#   centre shortName          typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf      stl1  depthBelowLandLayer      0  20240101         0         0
# 1   ecmf      stl2  depthBelowLandLayer      7  20240101         0         0
# 2   ecmf      stl3  depthBelowLandLayer     28  20240101         0         0
# 3   ecmf      stl4  depthBelowLandLayer    100  20240101         0         0
# 4   ecmf       slt              surface      0  20240101         0         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll

# %%
ds = ds_ek.to_xarray()
ds
# Out:
# <xarray.Dataset> Size: 28kB
# Dimensions:    (latitude: 19, longitude: 36)
# Coordinates:
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     slt        (latitude, longitude) float64 5kB ...
#     stl1       (latitude, longitude) float64 5kB ...
#     stl2       (latitude, longitude) float64 5kB ...
#     stl3       (latitude, longitude) float64 5kB ...
#     stl4       (latitude, longitude) float64 5kB ...
# Attributes:
#     class:        ea
#     stream:       oper
#     levtype:      sfc
#     type:         an
#     expver:       0001
#     date:         20240101
#     time:         0
#     domain:       g
#     number:       0
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %%
ds = ds_ek.to_xarray(profile="grib")
ds
# Out:
# <xarray.Dataset> Size: 28kB
# Dimensions:    (latitude: 19, longitude: 36)
# Coordinates:
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     slt        (latitude, longitude) float64 5kB ...
#     stl1       (latitude, longitude) float64 5kB ...
#     stl2       (latitude, longitude) float64 5kB ...
#     stl3       (latitude, longitude) float64 5kB ...
#     stl4       (latitude, longitude) float64 5kB ...
# Attributes:
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %%
ds = ds_ek.to_xarray(profile="grib", ensure_dims=["level"], dims_as_attrs="level")
ds
# Out:
# <xarray.Dataset> Size: 28kB
# Dimensions:    (latitude: 19, longitude: 36)
# Coordinates:
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     slt        (latitude, longitude) float64 5kB ...
#     stl1       (latitude, longitude) float64 5kB ...
#     stl2       (latitude, longitude) float64 5kB ...
#     stl3       (latitude, longitude) float64 5kB ...
#     stl4       (latitude, longitude) float64 5kB ...
# Attributes:
#     Conventions:  CF-1.8
#     institution:  ECMWF
