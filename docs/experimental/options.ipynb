# %% [markdown]
# ## Pressure levels

# %%
import earthkit.data

fname = "pl_regular_ll.grib"
earthkit.data.download_example_file(fname, remote_dir="test-data/xr_engine/level")
ds_ek = earthkit.data.from_source("file", fname)

# %%
ds = ds_ek.to_xarray()
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 48B 300 400 500 700 850 1000
# ...

# %%
ds = ds_ek.to_xarray(time_dim_mode="raw", decode_time=False, add_valid_time_coord=True)
ds
# Out:
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 1MB
# Dimensions:     (date: 2, time: 2, step: 2, levelist: 6, latitude: 19,
#                  longitude: 36)
# Coordinates:
#   * date        (date) int64 16B 20240603 20240604
#   * time        (time) int64 16B 0 1200
#   * step        (step) int64 16B 0 6
#   * levelist    (levelist) int64 48B 300 400 500 700 850 1000
#     valid_time  (date, time, step) datetime64[ns] 64B ...
# ...

# %%
ds = ds_ek.to_xarray(time_dim_mode="valid_time", decode_time=True)
ds
# Out:
# Finding coords in dataset for ('valid_time', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('valid_time', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('valid_time', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('valid_time', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('valid_time', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 1MB
# Dimensions:     (valid_time: 8, levelist: 6, latitude: 19, longitude: 36)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 64B 2024-06-03 ... 2024-06-04T18:...
#   * levelist    (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude    (latitude) float64 152B 90.0 80.0 70.0 ... -70.0 -80.0 -90.0
#   * longitude   (longitude) float64 288B 0.0 10.0 20.0 ... 330.0 340.0 350.0
# Data variables:
# ...

# %%
ds = ds_ek.to_xarray(level_dim_mode="level_per_type")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2, pl: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * pl                       (pl) int64 48B 300 400 500 700 850 1000
# ...

# %%
ds = ds_ek.to_xarray(level_dim_mode="level_and_type")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'level_and_type'):   0%|          | 0.00/48.…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'level_and_type'):   0%|          | 0.00/48.…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'level_and_type'):   0%|          | 0.00/48.…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'level_and_type'):   0%|          | 0.00/48.…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'level_and_type'):   0%|          | 0.00/48.…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2,
#                               level_and_type: 6, latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * level_and_type           (level_and_type) <U6 144B '1000pl' ... '850pl'
# ...

# %%
ds = ds_ek.to_xarray(variable_key="param_level")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# ...

# %%
ds = ds_ek.to_xarray(variable_key="param_level_type", 
                     remapping={"param_level_type": "{param}_{level}_{levtype}"})
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('forecast_reference_time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# ...

# %%
ds = ds_ek.to_xarray(extra_dims="type")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 48B 300 400 500 700 850 1000
# ...

# %%
ds = ds_ek.to_xarray(ensure_dims="type")
ds
# Out:
# Finding coords in dataset for ('type', 'forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/4…
# Finding coords in dataset for ('type', 'forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/4…
# Finding coords in dataset for ('type', 'forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/4…
# Finding coords in dataset for ('type', 'forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/4…
# Finding coords in dataset for ('type', 'forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/4…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (type: 1, forecast_reference_time: 4, step: 2,
#                               levelist: 6, latitude: 19, longitude: 36)
# Coordinates:
#   * type                     (type) <U2 8B 'fc'
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
# ...

# %%
ds = ds_ek.to_xarray(drop_variables="r")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude                 (latitude) float64 152B 90.0 80.0 ... -80.0 -90.0
# ...

# %%
ds = ds_ek.to_xarray(extra_variable_attrs="type")
ds
# Out:
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# Finding coords in dataset for ('forecast_reference_time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:…
# <xarray.Dataset> Size: 1MB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 48B 300 400 500 700 850 1000
# ...
