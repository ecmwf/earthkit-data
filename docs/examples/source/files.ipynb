# %% [markdown]
# ## Reading files

# %%
import earthkit.data as ekd

# %% [markdown]
# First, we ensure the example files used for this notebook are avaliable.

# %%
ekd.download_example_file(
    ["test.grib", "test4.grib", "test6.grib", "test.nc"])

# %% [raw]
# Files can be read by :ref:`from_source <data-sources-file>` as a "file" source. The resulting object provides some details about the data and the types it can be converted to for further work.

# %%
# grib data
ds_in = ekd.from_source("file", "test.grib")
ds_in
# Out:
# GribData(path={self._reader.path})

# %%
ds = ds_in.to_fieldlist().ls()

# %%
# netcdf data
ds_in = ekd.from_source("file", "test.nc")
ds_in
# Out:
# <style type="text/css">table.ek td {
#     vertical-align: top;
#     text-align: left !important;
# }
#
# table.ek th {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style><div class="eh-description">NetCDF file</div><hr>
# <table class="eh-table">
# <tr><td><b>path</b></td><td>test.nc</td></tr> <tr><td><b>size</b></td><td>6.4 KiB</td></tr> <tr><td><b>types</b></td><td>xarray, pandas, fieldlist, numpy, array</td></tr>
# </table>

# %%
ds = ds_in.to_xarray()
ds
# Out:
# /Users/cgr/git/earthkit-data/src/earthkit/data/readers/netcdf/reader.py:57: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   return xr.open_mfdataset(
# <xarray.Dataset> Size: 2kB
# Dimensions:     (latitude: 11, longitude: 19)
# Coordinates:
#   * latitude    (latitude) float64 88B 73.0 69.0 65.0 61.0 ... 41.0 37.0 33.0
#   * longitude   (longitude) float64 152B -27.0 -23.0 -19.0 ... 37.0 41.0 45.0
#     number      int32 4B ...
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     int32 4B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     t2m         (latitude, longitude) float32 836B dask.array<chunksize=(11, 19), meta=np.ndarray>
#     msl         (latitude, longitude) float32 836B dask.array<chunksize=(11, 19), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 GRIB to CDM+CF via cfgrib-0.9.5/ecCodes-2.17.0 w...

# %% [raw]
# See the other file related notebooks for more details:
#
# - :ref:`/examples/source/multi_files.ipynb`
# - :ref:`/examples/source/tar_files.ipynb`
# - :ref:`/examples/source/file_parts.ipynb`

# %% [markdown]
# ### Reading files using patterns

# %% [raw]
# The :ref:`file <data-sources-file>` source can also be specified by using :ref:`patterns <data-sources-file-pattern>`. In the example below when pattern "id" is substituted it will match two files: test4.grib and test6.grib:

# %%
ds = ekd.from_source("file-pattern", "./test{id}.grib",
                        {"id": [4, 6]})
ds.to_fieldlist().ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  t 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 1                  z 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 2                  t 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 3                  z 2007-01-01 12:00:00 2007-01-01 12:00:00    0 days
# 4                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 6                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 7                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 8                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 9                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             500            pressure               0          regular_ll
# 1             500            pressure               0          regular_ll
# 2             850            pressure               0          regular_ll
# 3             850            pressure               0          regular_ll
# 4            1000            pressure               0          regular_ll
# 5            1000            pressure               0          regular_ll
# 6            1000            pressure               0          regular_ll
# 7             850            pressure               0          regular_ll
# 8             850            pressure               0          regular_ll
# 9             850            pressure               0          regular_ll
