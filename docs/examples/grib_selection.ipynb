# %% [markdown]
# ## GRIB: selection using metadata

# %% [markdown]
# We read an example GRIB file containing 18 messages.

# %%
import earthkit.data as ekd

ds = ekd.from_source("sample", "tuv_pl.grib")
len(ds)
# Out:
# tuv_pl.grib:   0%|          | 0.00/4.22k [00:00<?, ?B/s]
# 18

# %% [markdown]
# ### Using sel

# %% [raw]
# Calling :py:meth:`~data.readers.grib.index.GribFieldList.sel` provides a "view":

# %%
a = ds.sel(level=500)
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# We can use a dict instead of keyword arguments:

# %%
a = ds.sel({"level": 500, "variable": "v"})
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll

# %% [markdown]
# Lists are accepted:

# %%
a = ds.sel(level=[500, 850])
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 5        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll
# 5      pressure      0  regular_ll

# %% [markdown]
# Slices can define closed intervals, so they are treated as inclusive of both the start and stop values, unlike normal Python indexing:

# %%
a = ds.sel(variable="t", level=slice(500, 850))
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# ### Using isel

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.isel` works similarly to :py:meth:`~data.readers.grib.index.GribFieldList.sel` but takes indices instead of values. Please note that the index values are sorted for :py:meth:`~data.readers.grib.index.GribFieldList.sel`.

# %%
a = ds.isel(level=0)
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    300
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    300
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    300
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %%
a = ds.isel({"level": 2, "shortName": 1})
a.ls()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
a = ds.isel(level=[2,3], param=0)
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %% [markdown]
# Slices are used as in normal Python indexing:

# %%
a = ds.isel(level=slice(2,5), param=0)
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# ### Using order_by

# %% [raw]
# Calling :py:meth:`~data.readers.grib.index.GribFieldList.order_by` provides a "view":

# %%
b = a.order_by()
b.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# The sorting keys can be specified as a list:

# %%
b = a.order_by(["variable"])
b.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# We can prescribe the actual order within a key. It only works when all the possible values are specified:

# %%
a = a.order_by(variable=["v", "t", "u"])
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    700
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll

# %% [markdown]
# ### Combining sel and order_by

# %%
a = ds.sel(level=[500, 850]).order_by(["variable"])
a.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 2        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 3        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
# 4        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 5        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    500
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll
# 5      pressure      0  regular_ll

# %% [markdown]
# ### Using indices

# %% [raw]
# To get the unique values for predefined set of metadata keys (the MARS ecCodes keys) we can call :py:meth:`~data.readers.grib.index.GribFieldList.indices`. By default it returns all the keys having valid values:

# %%
ds.indices()
# Out:
# {'param': ['t', 'u', 'v'],
#  'level': [300, 400, 500, 700, 850, 1000],
#  'shortName': []}

# %% [markdown]
# We can use the *squeeze* option to see only the keys having more than one values:

# %%
ds.indices(squeeze=True)
# Out:
# {'param': ['t', 'u', 'v'], 'level': [300, 400, 500, 700, 850, 1000]}

# %% [raw]
# We can get the unique values for a given key with :py:meth:`~data.readers.grib.index.GribFieldList.index` :

# %%
ds.index("param")
# Out:
# ['t', 'u', 'v']

# %%
ds.index("date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 ds.index("date")
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/fieldlist.py:336, in FieldList.index(self, key)
#     335 def index(self, key):
# --> 336     return self._md_indices.index(key)
#
# File ~/git/earthkit-data/src/earthkit/data/indexing/indices.py:103, in FieldListIndices.index(self, key)
#     100     return self.user_indices[key]
#     102 if key in self.default_index_keys:
# --> 103     return self.default_indices[key]
#     105 self.user_indices[key] = self._index_value(key)
#     106 return self.user_indices[key]
#
# KeyError: 'date'

# %% [markdown]
# Aliases can be used. E.g. instead of levelist we can use level:

# %%
ds.index("level")

# %% [markdown]
# Count the number of fields for each available level:

# %%
for level in ds.index("level"):
    print(f"level={level} len={len(ds.sel(level=level))}")
