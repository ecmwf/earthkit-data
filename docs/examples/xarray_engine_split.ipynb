# %% [markdown]
# ## Xarray engine

# %%
from earthkit.data import from_source
from earthkit.data.testing import earthkit_remote_test_data_file

ds1 = from_source("url", earthkit_remote_test_data_file("test-data", "xr_engine", "level", "pl_regular_ll.grib"))
ds2 = from_source("url", earthkit_remote_test_data_file("test-data", "xr_engine", "level", "ml_regular_ll.grib"))
ds1 = ds1.sel(param=["t", "u", "v"])
ds = ds1 + ds2

# %%
#ds.ls()

# %% [markdown]
# ### Using cfgrib

# %%
try:
    a = ds.to_xarray(engine="cfgrib")
except Exception as e:
    print(e)
# Out:
# multiple values for unique key, try re-open the file with one of:
#     filter_by_keys={'typeOfLevel': 'isobaricInhPa'}
#     filter_by_keys={'typeOfLevel': 'hybrid'}

# %% [markdown]
# ### Using earthkit engine

# %% [markdown]
# #### Auto split

# %%
# kwargs = {"xarray_open_dataset_kwargs": {
#             "backend_kwargs": {
#                 "profile": "mars", 
#                 "auto_split": True
#         }
#       }}

# a = ds.to_xarray(**kwargs)
# len(a)

# %%
#a[0]

# %%
#a[1]

# %% [markdown]
# #### Split dims

# %%
# p = "/Users/cgr/metview/python_test/earthkit_data/engine/new/pl_ml_1.grib"

# ds = from_source("file", p)

kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "split_dims": ["levtype"],
        }
      }}

a = ds.to_xarray(**kwargs)
len(a)
# Out:
# 2

# %%
a[0]
# Out:
# <xarray.Dataset> Size: 263kB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 2,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 16B 90 137
#   * latitude                 (latitude) float64 152B 90.0 80.0 ... -80.0 -90.0
#   * longitude                (longitude) float64 288B 0.0 10.0 ... 340.0 350.0
# Data variables:
#     t                        (forecast_reference_time, step, levelist, latitude, longitude) float64 88kB ...
#     u                        (forecast_reference_time, step, levelist, latitude, longitude) float64 88kB ...
#     v                        (forecast_reference_time, step, levelist, latitude, longitude) float64 88kB ...
# Attributes:
#     param:        v
#     class:        od
# ...

# %%
a[1]
# Out:
# <xarray.Dataset> Size: 789kB
# Dimensions:                  (forecast_reference_time: 4, step: 2, levelist: 6,
#                               latitude: 19, longitude: 36)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 32B 202...
#   * step                     (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist                 (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude                 (latitude) float64 152B 90.0 80.0 ... -80.0 -90.0
#   * longitude                (longitude) float64 288B 0.0 10.0 ... 340.0 350.0
# Data variables:
#     t                        (forecast_reference_time, step, levelist, latitude, longitude) float64 263kB ...
#     u                        (forecast_reference_time, step, levelist, latitude, longitude) float64 263kB ...
#     v                        (forecast_reference_time, step, levelist, latitude, longitude) float64 263kB ...
# Attributes:
#     param:        v
#     class:        od
# ...
