# %% [markdown]
# ## Xarray engine

# %%
import earthkit.data
earthkit.data.download_example_file("pl_regular_ll.grib", remote_dir="dev/engine")

# pressure level data on regular_ll grid
ds = earthkit.data.from_source("file", "pl_regular_ll.grib")

# %% [markdown]
# ### Using cfgrib

# %%
a = ds.to_xarray(_legacy=True)
a
# Out:
# kwargs={'_legacy': True}
# xarray_open_dataset_kwargs={'backend_kwargs': {'errors': 'raise'}, 'squeeze': False, 'cache': True, 'chunks': None, 'errors': 'raise', 'engine': 'cfgrib'}
# <xarray.Dataset> Size: 657kB
# Dimensions:        (number: 1, time: 4, step: 2, isobaricInhPa: 6,
#                     latitude: 19, longitude: 36)
# Coordinates:
#   * number         (number) int64 8B 0
#   * time           (time) datetime64[ns] 32B 2024-06-03 ... 2024-06-04T12:00:00
#   * step           (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 48B 1e+03 850.0 700.0 ... 400.0 300.0
#   * latitude       (latitude) float64 152B 90.0 80.0 70.0 ... -70.0 -80.0 -90.0
#   * longitude      (longitude) float64 288B 0.0 10.0 20.0 ... 330.0 340.0 350.0
#     valid_time     (time, step) datetime64[ns] 64B ...
# Data variables:
#     t              (number, time, step, isobaricInhPa, latitude, longitude) float32 131kB ...
#     r              (number, time, step, isobaricInhPa, latitude, longitude) float32 131kB ...
#     u              (number, time, step, isobaricInhPa, latitude, longitude) float32 131kB ...
#     v              (number, time, step, isobaricInhPa, latitude, longitude) float32 131kB ...
#     z              (number, time, step, isobaricInhPa, latitude, longitude) float32 131kB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-06-19T09:56 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ### Using earthkit engine

# %% [markdown]
# #### MARS keys only

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars'}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars'}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 657kB
# Dimensions:    (date: 2, time: 2, step: 2, levelist: 6, latitude: 19,
#                 longitude: 36)
# Coordinates:
#   * date       (date) int64 16B 20240603 20240604
#   * time       (time) int64 16B 0 1200
#   * step       (step) int64 16B 0 6
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     r          (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     t          (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     u          (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     v          (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     z          (date, time, step, levelist, latitude, longitude) float32 131kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %% [markdown]
# #### Merge date and time into base_datetime

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "use_base_datetime_dim": True
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'use_base_datetime_dim': True}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'use_base_datetime_dim': True}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'base_datetime']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'base_datetime']
# Finding coords in dataset for ('base_datetime', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s…
# Finding coords in dataset for ('base_datetime', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s…
# Finding coords in dataset for ('base_datetime', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s…
# Finding coords in dataset for ('base_datetime', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s…
# Finding coords in dataset for ('base_datetime', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s…
# <xarray.Dataset> Size: 657kB
# Dimensions:        (base_datetime: 4, step: 2, levelist: 6, latitude: 19,
#                     longitude: 36)
# Coordinates:
#   * base_datetime  (base_datetime) <U19 304B '2024-06-03T00:00:00' ... '2024-...
#   * step           (step) int64 16B 0 6
#   * levelist       (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude       (latitude) float64 152B 90.0 80.0 70.0 ... -70.0 -80.0 -90.0
#   * longitude      (longitude) float64 288B 0.0 10.0 20.0 ... 330.0 340.0 350.0
# Data variables:
#     r              (base_datetime, step, levelist, latitude, longitude) float32 131kB ...
#     t              (base_datetime, step, levelist, latitude, longitude) float32 131kB ...
#     u              (base_datetime, step, levelist, latitude, longitude) float32 131kB ...
#     v              (base_datetime, step, levelist, latitude, longitude) float32 131kB ...
#     z              (base_datetime, step, levelist, latitude, longitude) float32 131kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %% [markdown]
# #### Add valid datetime coord and use timedelta for steps

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "add_valid_datetime_coord": True,
                "use_timedelta_step": True
                
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'add_valid_datetime_coord': True, 'use_timedelta_step': True}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'add_valid_datetime_coord': True, 'use_timedelta_step': True}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 657kB
# Dimensions:         (date: 2, time: 2, step: 2, levelist: 6, latitude: 19,
#                      longitude: 36)
# Coordinates:
#   * date            (date) int64 16B 20240603 20240604
#   * time            (time) int64 16B 0 1200
#   * step            (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * levelist        (levelist) int64 48B 300 400 500 700 850 1000
#     valid_datetime  (date, time, step) datetime64[ns] 64B ...
#   * latitude        (latitude) float64 152B 90.0 80.0 70.0 ... -70.0 -80.0 -90.0
#   * longitude       (longitude) float64 288B 0.0 10.0 20.0 ... 330.0 340.0 350.0
# Data variables:
#     r               (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     t               (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     u               (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     v               (date, time, step, levelist, latitude, longitude) float32 131kB ...
#     z               (date, time, step, levelist, latitude, longitude) float32 131kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %% [markdown]
# #### Flatten values

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "flatten_values": True
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'flatten_values': True}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'flatten_values': True}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step', 'levelist'):   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 668kB
# Dimensions:    (date: 2, time: 2, step: 2, levelist: 6, values: 684)
# Coordinates:
#   * date       (date) int64 16B 20240603 20240604
#   * time       (time) int64 16B 0 1200
#   * step       (step) int64 16B 0 6
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#     latitude   (values) float64 5kB ...
#     longitude  (values) float64 5kB ...
# Dimensions without coordinates: values
# Data variables:
#     r          (date, time, step, levelist, values) float32 131kB ...
#     t          (date, time, step, levelist, values) float32 131kB ...
#     u          (date, time, step, levelist, values) float32 131kB ...
#     v          (date, time, step, levelist, values) float32 131kB ...
#     z          (date, time, step, levelist, values) float32 131kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %% [markdown]
# #### Use remappings

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "remapping": {"param_level": "{param}_{levelist}_{levtype}"}
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'remapping': {'param_level': '{param}_{levelist}_{levtype}'}}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'remapping': {'param_level': '{param}_{levelist}_{levtype}'}}}
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'param_level']
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 657kB
# Dimensions:    (date: 2, time: 2, step: 2, latitude: 19, longitude: 36)
# Coordinates:
#   * date       (date) int64 16B 20240603 20240604
#   * time       (time) int64 16B 0 1200
#   * step       (step) int64 16B 0 6
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables: (12/30)
#     r_1000_pl  (date, time, step, latitude, longitude) float32 22kB ...
#     r_300_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     r_400_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     r_500_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     r_700_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     r_850_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     ...         ...
#     z_1000_pl  (date, time, step, latitude, longitude) float32 22kB ...
#     z_300_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     z_400_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     z_500_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     z_700_pl   (date, time, step, latitude, longitude) float32 22kB ...
#     z_850_pl   (date, time, step, latitude, longitude) float32 22kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %% [markdown]
# #### Built-in remappings

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "extra_index_keys": ["param_level"]
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'extra_index_keys': ['param_level']}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'extra_index_keys': ['param_level']}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'param_level']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'param_level']
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('date', 'time', 'step'):   0%|          | 0.00/8.00 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 657kB
# Dimensions:    (date: 2, time: 2, step: 2, latitude: 19, longitude: 36)
# Coordinates:
#   * date       (date) int64 16B 20240603 20240604
#   * time       (time) int64 16B 0 1200
#   * step       (step) int64 16B 0 6
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables: (12/30)
#     r1000      (date, time, step, latitude, longitude) float32 22kB ...
#     r300       (date, time, step, latitude, longitude) float32 22kB ...
#     r400       (date, time, step, latitude, longitude) float32 22kB ...
#     r500       (date, time, step, latitude, longitude) float32 22kB ...
#     r700       (date, time, step, latitude, longitude) float32 22kB ...
#     r850       (date, time, step, latitude, longitude) float32 22kB ...
#     ...         ...
#     z1000      (date, time, step, latitude, longitude) float32 22kB ...
#     z300       (date, time, step, latitude, longitude) float32 22kB ...
#     z400       (date, time, step, latitude, longitude) float32 22kB ...
#     z500       (date, time, step, latitude, longitude) float32 22kB ...
#     z700       (date, time, step, latitude, longitude) float32 22kB ...
#     z850       (date, time, step, latitude, longitude) float32 22kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib

# %%
kwargs = {"xarray_open_dataset_kwargs": {
            "backend_kwargs": {
                "profile": "mars", 
                "extra_index_keys": ["level_and_type"]
        }
      }}

a = ds.to_xarray(**kwargs)
a
# Out:
# kwargs={'xarray_open_dataset_kwargs': {'backend_kwargs': {'profile': 'mars', 'extra_index_keys': ['level_and_type']}}}
# xarray_open_dataset_kwargs={'engine': 'earthkit', 'backend_kwargs': {'profile': 'mars', 'extra_index_keys': ['level_and_type']}}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'level_and_type']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection', 'level_and_type']
# Finding coords in dataset for ('date', 'time', 'step', 'level_and_type'):   0%|          | 0.00/48.0 [00:00<?,…
# Finding coords in dataset for ('date', 'time', 'step', 'level_and_type'):   0%|          | 0.00/48.0 [00:00<?,…
# Finding coords in dataset for ('date', 'time', 'step', 'level_and_type'):   0%|          | 0.00/48.0 [00:00<?,…
# Finding coords in dataset for ('date', 'time', 'step', 'level_and_type'):   0%|          | 0.00/48.0 [00:00<?,…
# Finding coords in dataset for ('date', 'time', 'step', 'level_and_type'):   0%|          | 0.00/48.0 [00:00<?,…
# <xarray.Dataset> Size: 657kB
# Dimensions:         (date: 2, time: 2, step: 2, level_and_type: 6,
#                      latitude: 19, longitude: 36)
# Coordinates:
#   * date            (date) int64 16B 20240603 20240604
#   * time            (time) int64 16B 0 1200
#   * step            (step) int64 16B 0 6
#   * level_and_type  (level_and_type) <U6 144B '1000pl' '300pl' ... '850pl'
#   * latitude        (latitude) float64 152B 90.0 80.0 70.0 ... -70.0 -80.0 -90.0
#   * longitude       (longitude) float64 288B 0.0 10.0 20.0 ... 330.0 340.0 350.0
# Data variables:
#     r               (date, time, step, level_and_type, latitude, longitude) float32 131kB ...
#     t               (date, time, step, level_and_type, latitude, longitude) float32 131kB ...
#     u               (date, time, step, level_and_type, latitude, longitude) float32 131kB ...
#     v               (date, time, step, level_and_type, latitude, longitude) float32 131kB ...
#     z               (date, time, step, level_and_type, latitude, longitude) float32 131kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            fc
#     expver:          0001
#     domain:          g
#     number:          0
#     md5GridSection:  33c7d6025995e1b4913811e77d38ec50
#     ekds_source:     pl_regular_ll.grib
