# %% [markdown]
# ## GRIB: ordering fields

# %% [markdown]
# We read an example GRIB file and load into a fieldlist. Then select a smaller subset for
# the examples.

# %%
import earthkit.data as ekd

ds_in = ekd.from_source("sample", "tuv_pl.grib").to_fieldlist()
ds = ds_in.sel({"vertical.level": slice(500, 850), 
              "parameter.variable": ["u", "v"]})
ds.ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             850            pressure               0          regular_ll
# 1             850            pressure               0          regular_ll
# 2             700            pressure               0          regular_ll
# 3             700            pressure               0          regular_ll
# 4             500            pressure               0          regular_ll
# 5             500            pressure               0          regular_ll

# %% [markdown]
# ### Using order_by

# %% [raw]
# :py:meth:`~data.core.FieldList.order_by` returns a sorted fieldlist.

# %%
ds.order_by("parameter.variable").ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             850            pressure               0          regular_ll
# 1             700            pressure               0          regular_ll
# 2             500            pressure               0          regular_ll
# 3             850            pressure               0          regular_ll
# 4             700            pressure               0          regular_ll
# 5             500            pressure               0          regular_ll

# %% [markdown]
# The sorting keys can be specified as a list:

# %%
ds.order_by(["parameter.variable", "vertical.level"]).ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             500            pressure               0          regular_ll
# 1             700            pressure               0          regular_ll
# 2             850            pressure               0          regular_ll
# 3             500            pressure               0          regular_ll
# 4             700            pressure               0          regular_ll
# 5             850            pressure               0          regular_ll

# %% [markdown]
# We can prescribe the actual order within a key. It only works when all the possible values are specified:

# %%
ds.order_by({"vertical.level": [500, 850, 700]}).ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             500            pressure               0          regular_ll
# 1             500            pressure               0          regular_ll
# 2             850            pressure               0          regular_ll
# 3             850            pressure               0          regular_ll
# 4             700            pressure               0          regular_ll
# 5             700            pressure               0          regular_ll

# %% [markdown]
# ### Ordering direction

# %%
ds.order_by({"parameter.variable": "descending"}).ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             850            pressure               0          regular_ll
# 1             700            pressure               0          regular_ll
# 2             500            pressure               0          regular_ll
# 3             850            pressure               0          regular_ll
# 4             700            pressure               0          regular_ll
# 5             500            pressure               0          regular_ll

# %%
ds.order_by({"parameter.variable": "descending", "vertical.level": "ascending"}).ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  v 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  u 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             500            pressure               0          regular_ll
# 1             700            pressure               0          regular_ll
# 2             850            pressure               0          regular_ll
# 3             500            pressure               0          regular_ll
# 4             700            pressure               0          regular_ll
# 5             850            pressure               0          regular_ll

# %% [markdown]
# ### Custom ordering

# %%
class _CustomOrder:
    def __call__(self, x, y):
        """Retuns:
            - 0: if x == y
            - 1: if x > y
            - -1: if x < y 
        """
        if x == y:
            return 0
            
        # ascending below 500 
        if x < 500 and y < 500:
            if x > y:
                return 1
            if x < y:
                return -1
        # desacending above 500 
        if x > 500 and y > 500:
            if x > y:
                return -1
            if x < y:
                return 1
        # othewise
        else:
            if x > y:
                return 1
            if x < y:
                return -1

ds_in.sel({"parameter.variable": "t"}).order_by({"vertical.level": _CustomOrder()}).ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 1                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 2                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 3                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 4                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
# 5                  t 2018-08-01 12:00:00 2018-08-01 12:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             300            pressure               0          regular_ll
# 1             400            pressure               0          regular_ll
# 2             500            pressure               0          regular_ll
# 3            1000            pressure               0          regular_ll
# 4             850            pressure               0          regular_ll
# 5             700            pressure               0          regular_ll
