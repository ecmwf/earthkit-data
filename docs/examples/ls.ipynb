# %%
# !test -f test.grib || wget https://github.com/ecmwf/emohawk/raw/main/docs/examples/tuv_pl.grib

# %%
import emohawk

fs = emohawk.load_from("file", "tuv_pl.grib")

# %% [markdown]
# #### Using ls()

# %%
fs.ls()
# Out:
#    centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0    ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1    ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2    ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3    ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4    ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5    ecmf         v  isobaricInhPa    850  20180801      1200         0
# 6    ecmf         t  isobaricInhPa    700  20180801      1200         0
# 7    ecmf         u  isobaricInhPa    700  20180801      1200         0
# 8    ecmf         v  isobaricInhPa    700  20180801      1200         0
# 9    ecmf         t  isobaricInhPa    500  20180801      1200         0
# 10   ecmf         u  isobaricInhPa    500  20180801      1200         0
# 11   ecmf         v  isobaricInhPa    500  20180801      1200         0
# ...

# %%
fs.sel({"level": 500}).ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa    500  20180801      1200         0
# 1   ecmf         u  isobaricInhPa    500  20180801      1200         0
# 2   ecmf         v  isobaricInhPa    500  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll

# %% [markdown]
# #### Using describe

# %% [markdown]
# Describe the whole object:

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_06269 th {
#   text-align: left;
# }
# #T_06269_row0_col0, #T_06269_row0_col1, #T_06269_row0_col2, #T_06269_row0_col3, #T_06269_row0_col4, #T_06269_row0_col5, #T_06269_row0_col6, #T_06269_row0_col7, #T_06269_row0_col8, #T_06269_row1_col0, #T_06269_row1_col1, #T_06269_row1_col2, #T_06269_row1_col3, #T_06269_row1_col4, #T_06269_row1_col5, #T_06269_row1_col6, #T_06269_row1_col7, #T_06269_row1_col8, #T_06269_row2_col0, #T_06269_row2_col1, #T_06269_row2_col2, #T_06269_row2_col3, #T_06269_row2_col4, #T_06269_row2_col5, #T_06269_row2_col6, #T_06269_row2_col7, #T_06269_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_06269">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06269_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_06269_level0_col1" class="col_heading level0 col1" >date</th>
# ...

# %% [markdown]
# Describe a given parameter (defined by shortName or paramId):

# %%
fs.describe("t")
# Out:
# <style type="text/css">
# #T_32fed th {
#   text-align: left;
# }
# #T_32fed_row0_col0, #T_32fed_row1_col0, #T_32fed_row2_col0, #T_32fed_row3_col0, #T_32fed_row4_col0, #T_32fed_row5_col0, #T_32fed_row6_col0, #T_32fed_row7_col0, #T_32fed_row8_col0, #T_32fed_row9_col0, #T_32fed_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_32fed">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32fed_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_32fed_row0_col0" class="data row0 col0" >t</td>
#     </tr>
#     <tr>
#       <th id="T_32fed_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_32fed_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_32fed_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_32fed_row2_col0" class="data row2 col0" >1000,300,400,850,500,700</td>
#     </tr>
#     <tr>
# ...

# %%
fs.describe(131)
# Out:
# <style type="text/css">
# #T_b52e5 th {
#   text-align: left;
# }
# #T_b52e5_row0_col0, #T_b52e5_row1_col0, #T_b52e5_row2_col0, #T_b52e5_row3_col0, #T_b52e5_row4_col0, #T_b52e5_row5_col0, #T_b52e5_row6_col0, #T_b52e5_row7_col0, #T_b52e5_row8_col0, #T_b52e5_row9_col0, #T_b52e5_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_b52e5">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b52e5_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_b52e5_row0_col0" class="data row0 col0" >u</td>
#     </tr>
#     <tr>
#       <th id="T_b52e5_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_b52e5_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_b52e5_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_b52e5_row2_col0" class="data row2 col0" >1000,300,400,850,500,700</td>
#     </tr>
#     <tr>
# ...
