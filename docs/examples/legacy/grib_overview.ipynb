# %% [markdown]
# ## Using GRIB data

# %% [raw]
# We will work with a GRIB file containing 6 messages. First we ensure the example file is available, then read the file with :ref:`from_source() <data-sources-file>`.

# %%
import earthkit.data as ekd
ekd.download_example_file("test6.grib")
# Out:
# /Users/cgr/venv/dev/lib/python3.13/site-packages/array_api_compat/torch/_info.py:361: UserWarning: 'mkldnn' is no longer used as device type. So torch.device('mkldnn') will be deprecated and removed in the future. Please use other valid device types instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/c10/core/Device.cpp:42.)
#   a = torch.empty((0,), device=torch.device(device_name, index=i))

# %%
ds = ekd.from_source("file", "test6.grib")

# %% [markdown]
# No GRIB data is actually loaded at this point.

# %% [markdown]
# ### Iteration

# %% [raw]
# A :ref:`GRIB <grib>` data object is represented by a :py:class:`~data.readers.grib.index.GribFieldList` consisting of :py:class:`~data.readers.grib.codes.GribField`\s. When used in iteration these are automatically created and released when going out of scope. As a result, during the iteration only one GRIB message at a time is kept in memory:

# %%
for f in ds:
    print(f)
# Out:
# <earthkit.data.core.field.Field object at 0x1590d9550>
# <earthkit.data.core.field.Field object at 0x158ed3750>
# <earthkit.data.core.field.Field object at 0x1590dc410>
# <earthkit.data.core.field.Field object at 0x1590e0180>
# <earthkit.data.core.field.Field object at 0x1590e0d60>
# <earthkit.data.core.field.Field object at 0x1590e8170>

# %% [markdown]
# ### Inspecting the contents

# %% [raw]
# We can use :py:meth:`~data.readers.grib.index.GribFieldList.ls` or :py:meth:`~data.readers.grib.index.GribFieldList.describe`.

# %%
len(ds)
# Out:
# 6

# %%
ds.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
# 5        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850       None
#
#   number grid_type
# 0   None      None
# 1   None      None
# 2   None      None
# 3   None      None
# 4   None      None
# 5   None      None

# %%
ds.describe()
# Out:
# <style type="text/css">
# #T_946ea th {
#   text-align: left;
# }
# </style>
# <table id="T_946ea">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_946ea_level0_col0" class="col_heading level0 col0" >shortName</th>
#       <th id="T_946ea_level0_col1" class="col_heading level0 col1" >typeOfLevel</th>
#       <th id="T_946ea_level0_col2" class="col_heading level0 col2" >level</th>
#       <th id="T_946ea_level0_col3" class="col_heading level0 col3" >date</th>
#       <th id="T_946ea_level0_col4" class="col_heading level0 col4" >time</th>
#       <th id="T_946ea_level0_col5" class="col_heading level0 col5" >stepRange</th>
#       <th id="T_946ea_level0_col6" class="col_heading level0 col6" >number</th>
#       <th id="T_946ea_level0_col7" class="col_heading level0 col7" >paramId</th>
#       <th id="T_946ea_level0_col8" class="col_heading level0 col8" >class</th>
#       <th id="T_946ea_level0_col9" class="col_heading level0 col9" >stream</th>
#       <th id="T_946ea_level0_col10" class="col_heading level0 col10" >type</th>
#       <th id="T_946ea_level0_col11" class="col_heading level0 col11" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### Slicing

# %% [markdown]
# Standard Python slicing is available. It does not involve any loading/copying of GRIB data.

# %%
g = ds[1]
g

# %%
g = ds[1:3]
g.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level level_type  \
# 0        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
# 1        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000       None
#
#   number grid_type
# 0   None      None
# 1   None      None

# %%
g = ds[-1]
g

# %% [markdown]
# ### Getting data values

# %% [markdown]
# #### Using values

# %% [raw]
# The :py:attr:`~data.readers.grib.codes.GribField.values` property always returns a flat array per field:

# %%
v = ds[0].values
v.shape
# Out:
# (84,)

# %%
v[0:4]
# Out:
# array([272.56417847, 272.56417847, 272.56417847, 272.56417847])

# %% [raw]
# When called on the whole fieldlist :py:attr:`~data.readers.grib.index.GribFieldList.values` returns a 2D array:

# %%
v = ds.values
v.shape
# Out:
# (6, 84)

# %% [markdown]
# #### Using to_numpy()

# %% [raw]
# With :py:meth:`~data.readers.grib.codes.GribField.to_numpy` the field shape is set on the array:

# %%
v = ds[0].to_numpy()
print(v.shape)
print(ds[0].shape)
# Out:
# (7, 12)
# (7, 12)

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.to_numpy` behaves in the same way when called on a fieldlist:

# %%
v = ds.to_numpy()
v.shape
# Out:
# (6, 7, 12)

# %% [markdown]
# ### Metadata

# %% [raw]
# :py:meth:`~data.readers.grib.codes.GribField.metadata` access works both on individual fields and slices:

# %%
ds[0].metadata("typeOfLevel")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ds[0].metadata("typeOfLevel")
#
# File ~/git/earthkit-data/src/earthkit/data/core/field.py:774, in Field.metadata(self, astype, remapping, patches, *keys, **kwargs)
#     770 raise_on_missing = "default" not in kwargs
#     771 default = kwargs.pop("default", None)
#     773 r = [
# --> 774     self.get(
#     775         k,
#     776         default=default,
#     777         astype=kt,
#     778         raise_on_missing=raise_on_missing,
#     779         **kwargs,
#     780     )
#     781     for k, kt in zip(key, astype)
#     782 ]
#     784 if key_arg_type is str:
#     785     return r[0]
#
# File ~/git/earthkit-data/src/earthkit/data/core/field.py:605, in Field.get(self, default, astype, raise_on_missing, remapping, patches, *keys)
#     601 assert isinstance(keys, list)
#     603 remapping = build_remapping(remapping, patches, forced_build=False)
# --> 605 r = self._get_fast(
#     606     keys,
#     607     default=default,
#     608     astype=astype,
#     609     raise_on_missing=raise_on_missing,
#     610     remapping=remapping,
#     611     output=key_arg_type,
#     612 )
#     614 return r
#
# File ~/git/earthkit-data/src/earthkit/data/core/field.py:577, in Field._get_fast(self, keys, default, astype, raise_on_missing, output, remapping, joiner)
#     575 if isinstance(astype, (list, tuple)):
#     576     astype = astype[0]
# --> 577 return meth(keys[0], astype=astype, **_kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/core/field.py:534, in Field.get_single(self, key, default, astype, raise_on_missing, remapping, patches)
#     531             return _cast(v)
#     533 if raise_on_missing:
# --> 534     raise KeyError(f"Key {key} not found in field")
#     536 return default
#
# KeyError: 'Key typeOfLevel not found in field'

# %%
ds[0:2].metadata(["level", "paramId"])

# %% [raw]
# We can also call :py:meth:`~data.readers.grib.index.GribFieldList.metadata` on a fieldlist:

# %%
ds.metadata("level")

# %% [markdown]
# Key qualifiers can be used to prescribe the required metadata type:

# %%
ds[0].metadata(["centre", "centre", "centre"], astype=(None, int, str))

# %% [raw]
# For each filed we can get the metadata as an :py:class:`object <data.readers.grib.metadata.GribMetadata>`:

# %%
md = ds[0].metadata()
md

# %%
md["level"]

# %% [markdown]
# ### Selection

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.sel` offers metadata-based selection and always creates a "view", so no copying of GRIB data is involved.

# %%
g = ds.sel(shortName=["u", "v"], level=850)
g.ls()

# %%
g = ds.sel(param="t")
g.ls()

# %% [markdown]
# ### Xarray

# %% [raw]
# Xarray conversion with :py:meth:`~data.readers.grib.index.GribFieldList.to_xarray` does not involve disk writing. Under the hood it uses cfgrib.

# %%
xds = ds.to_xarray(engine="cfgrib")
xds

# %% [raw]
# We can pass all the kwargs arguments cfgrib accepts. On top of that earthkit-data provides the :py:meth:`ignore_keys <data.readers.grib.index.GribFieldList.to_xarray>` option to omit keys from the default set of keys used by cfgrib:

# %%
xds = ds.to_xarray(engine="cfgrib", xarray_open_dataset_kwargs={"backend_kwargs": {"ignore_keys": ["number"]}})
xds
