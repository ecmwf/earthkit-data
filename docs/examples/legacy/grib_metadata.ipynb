# %% [markdown]
# ## GRIB: inspecting contents

# %% [raw]
# We will work with a GRIB file containing 6 messages. First we ensure the example file is available, then read the file with :ref:`from_source() <data-sources-file>`.

# %%
import earthkit.data as ekd
ekd.download_example_file("test6.grib")

# %%
fs = ekd.from_source("file", "test6.grib")

# %% [markdown]
# ### Using head(), tail() and ls()

# %% [raw]
# All these methods (:py:meth:`~data.readers.grib.index.GribFieldList.head`, :py:meth:`~data.readers.grib.index.GribFieldList.tail` and :py:meth:`~data.readers.grib.index.GribFieldList.ls`) take the same set of keyword arguments:
#
# - n: number of messages to list
# - keys: the metadata keys to dump
# - extra_keys: extra keys of top of the default set of keys
# - namespace: the :xref:`eccodes_namespace` to use

# %% [markdown]
# #### head()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.head` displays the first 5 messages by default:

# %%
fs.head()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll

# %% [markdown]
# The number of fields can be passed as an argument:

# %%
fs.head(2)
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
fs.head(n=2)
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %% [markdown]
# The keys can be taken from an [ecCodes GRIB namespace](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ):

# %%
fs.head(namespace="statistics")
# Out:
#           max         min         avg         sd      skew      kurt  const
# 0  320.564178  240.564178  279.707036  19.674217 -0.731230 -0.169046    0.0
# 1   17.713120   -6.286880   -0.382119   5.605310  1.139004  1.018780    0.0
# 2   11.833481  -16.166519   -0.071281   6.140457 -0.217654 -0.839983    0.0
# 3  304.539169  232.539169  272.729646  19.241867 -0.998189  0.135718    0.0
# 4   27.101624  -12.898376    0.339719   8.141047  1.542573  1.864089    0.0

# %%
fs.head(namespace="parameter")
# Out:
#   centre  paramId    units                 name shortName
# 0   ecmf      130        K          Temperature         t
# 1   ecmf      131  m s**-1  U component of wind         u
# 2   ecmf      132  m s**-1  V component of wind         v
# 3   ecmf      130        K          Temperature         t
# 4   ecmf      131  m s**-1  U component of wind         u

# %% [markdown]
# The list of keys can be prescribed:

# %%
fs.head(n=2, keys=["bitsPerValue", "packingType"])
# Out:
#    bitsPerValue  packingType
# 0             4  grid_simple
# 1             4  grid_simple

# %% [markdown]
# The list of keys can also be extended:

# %%
fs.head(extra_keys="paramId")
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType  paramId
# 0       an       0  regular_ll      130
# 1       an       0  regular_ll      131
# 2       an       0  regular_ll      132
# 3       an       0  regular_ll      130
# 4       an       0  regular_ll      131

# %% [markdown]
# #### tail()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.tail` displays the last 5 messages by default:

# %%
fs.tail(5)
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 3   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll

# %% [markdown]
# #### ls()

# %% [raw]
# By default :py:meth:`~data.readers.grib.index.GribFieldList.ls` lists all the fields:

# %%
fs.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll
# 5       an       0  regular_ll

# %% [markdown]
# The number of fields to list can also be specified:

# %%
fs.ls(2)
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
fs.ls(-2)
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 1   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %% [markdown]
# ### Using describe

# %% [raw]
# We can :py:meth:`~data.readers.grib.index.GribFieldList.describe` the whole object:

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_388b0 th {
#   text-align: left;
# }
# #T_388b0_row0_col0, #T_388b0_row0_col1, #T_388b0_row0_col2, #T_388b0_row0_col3, #T_388b0_row0_col4, #T_388b0_row0_col5, #T_388b0_row0_col6, #T_388b0_row0_col7, #T_388b0_row0_col8, #T_388b0_row1_col0, #T_388b0_row1_col1, #T_388b0_row1_col2, #T_388b0_row1_col3, #T_388b0_row1_col4, #T_388b0_row1_col5, #T_388b0_row1_col6, #T_388b0_row1_col7, #T_388b0_row1_col8, #T_388b0_row2_col0, #T_388b0_row2_col1, #T_388b0_row2_col2, #T_388b0_row2_col3, #T_388b0_row2_col4, #T_388b0_row2_col5, #T_388b0_row2_col6, #T_388b0_row2_col7, #T_388b0_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_388b0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_388b0_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_388b0_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_388b0_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_388b0_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_388b0_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_388b0_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_388b0_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_388b0_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_388b0_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_388b0_level0_row0" class="row_heading level0 row0" >t</th>
#       <th id="T_388b0_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_388b0_row0_col0" class="data row0 col0" >1000,850</td>
#       <td id="T_388b0_row0_col1" class="data row0 col1" >20180801</td>
#       <td id="T_388b0_row0_col2" class="data row0 col2" >1200</td>
#       <td id="T_388b0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_388b0_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_388b0_row0_col5" class="data row0 col5" >od</td>
#       <td id="T_388b0_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_388b0_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_388b0_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_388b0_level0_row1" class="row_heading level0 row1" >u</th>
#       <th id="T_388b0_level1_row1" class="row_heading level1 row1" >isobaricInhPa</th>
#       <td id="T_388b0_row1_col0" class="data row1 col0" >1000,850</td>
#       <td id="T_388b0_row1_col1" class="data row1 col1" >20180801</td>
#       <td id="T_388b0_row1_col2" class="data row1 col2" >1200</td>
#       <td id="T_388b0_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_388b0_row1_col4" class="data row1 col4" >131</td>
#       <td id="T_388b0_row1_col5" class="data row1 col5" >od</td>
#       <td id="T_388b0_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_388b0_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_388b0_row1_col8" class="data row1 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_388b0_level0_row2" class="row_heading level0 row2" >v</th>
#       <th id="T_388b0_level1_row2" class="row_heading level1 row2" >isobaricInhPa</th>
#       <td id="T_388b0_row2_col0" class="data row2 col0" >1000,850</td>
#       <td id="T_388b0_row2_col1" class="data row2 col1" >20180801</td>
#       <td id="T_388b0_row2_col2" class="data row2 col2" >1200</td>
#       <td id="T_388b0_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_388b0_row2_col4" class="data row2 col4" >132</td>
#       <td id="T_388b0_row2_col5" class="data row2 col5" >od</td>
#       <td id="T_388b0_row2_col6" class="data row2 col6" >oper</td>
#       <td id="T_388b0_row2_col7" class="data row2 col7" >an</td>
#       <td id="T_388b0_row2_col8" class="data row2 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# We can also :py:meth:`~data.readers.grib.index.GribFieldList.describe` a given parameter (defined by shortName or paramId):

# %%
fs.describe("t")
# Out:
# <style type="text/css">
# #T_4092d th {
#   text-align: left;
# }
# #T_4092d_row0_col0, #T_4092d_row1_col0, #T_4092d_row2_col0, #T_4092d_row3_col0, #T_4092d_row4_col0, #T_4092d_row5_col0, #T_4092d_row6_col0, #T_4092d_row7_col0, #T_4092d_row8_col0, #T_4092d_row9_col0, #T_4092d_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_4092d">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4092d_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_4092d_row0_col0" class="data row0 col0" >t</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_4092d_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_4092d_row2_col0" class="data row2 col0" >1000,850</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_4092d_row3_col0" class="data row3 col0" >20180801</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_4092d_row4_col0" class="data row4 col0" >1200</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row5" class="row_heading level0 row5" >step</th>
#       <td id="T_4092d_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row6" class="row_heading level0 row6" >paramId</th>
#       <td id="T_4092d_row6_col0" class="data row6 col0" >130</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_4092d_row7_col0" class="data row7 col0" >od</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row8" class="row_heading level0 row8" >stream</th>
#       <td id="T_4092d_row8_col0" class="data row8 col0" >oper</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row9" class="row_heading level0 row9" >type</th>
#       <td id="T_4092d_row9_col0" class="data row9 col0" >an</td>
#     </tr>
#     <tr>
#       <th id="T_4092d_level0_row10" class="row_heading level0 row10" >experimentVersionNumber</th>
#       <td id="T_4092d_row10_col0" class="data row10 col0" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %%
fs.describe(131)
# Out:
# <style type="text/css">
# #T_a45a7 th {
#   text-align: left;
# }
# #T_a45a7_row0_col0, #T_a45a7_row1_col0, #T_a45a7_row2_col0, #T_a45a7_row3_col0, #T_a45a7_row4_col0, #T_a45a7_row5_col0, #T_a45a7_row6_col0, #T_a45a7_row7_col0, #T_a45a7_row8_col0, #T_a45a7_row9_col0, #T_a45a7_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_a45a7">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a45a7_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_a45a7_row0_col0" class="data row0 col0" >u</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_a45a7_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_a45a7_row2_col0" class="data row2 col0" >1000,850</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_a45a7_row3_col0" class="data row3 col0" >20180801</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_a45a7_row4_col0" class="data row4 col0" >1200</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row5" class="row_heading level0 row5" >step</th>
#       <td id="T_a45a7_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row6" class="row_heading level0 row6" >paramId</th>
#       <td id="T_a45a7_row6_col0" class="data row6 col0" >131</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_a45a7_row7_col0" class="data row7 col0" >od</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row8" class="row_heading level0 row8" >stream</th>
#       <td id="T_a45a7_row8_col0" class="data row8 col0" >oper</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row9" class="row_heading level0 row9" >type</th>
#       <td id="T_a45a7_row9_col0" class="data row9 col0" >an</td>
#     </tr>
#     <tr>
#       <th id="T_a45a7_level0_row10" class="row_heading level0 row10" >experimentVersionNumber</th>
#       <td id="T_a45a7_row10_col0" class="data row10 col0" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Accessing metadata

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.metadata` with positional arguments works for both for a :py:meth:`field <data.readers.grib.codes.GribField.metadata>` and a :py:meth:`fieldlist <data.readers.grib.index.GribFieldList.metadata>`. Key type qualifiers are allowed to be used.

# %%
fs.metadata("typeOfLevel")
# Out:
# ['isobaricInhPa',
#  'isobaricInhPa',
#  'isobaricInhPa',
#  'isobaricInhPa',
#  'isobaricInhPa',
#  'isobaricInhPa']

# %%
fs[0].metadata(["typeOfLevel", "level", "centre", "centre"], astype=(None, None, str, int))
# Out:
# ['isobaricInhPa', 1000, 'ecmf', 98]

# %% [markdown]
# For single fields the bracket operator can also be used:

# %%
fs[0]["param"]
# Out:
# 't'

# %% [markdown]
# Namespace keys can be fetched as a dict for single fields:

# %%
fs[0].metadata(namespace="parameter")
# Out:
# {'centre': 'ecmf',
#  'paramId': 130,
#  'units': 'K',
#  'name': 'Temperature',
#  'shortName': 't'}

# %% [markdown]
# ### Inspecting all the namespace keys for a message

# %% [raw]
# :py:meth:`~data.readers.grib.codes.GribField.dump` gives a tabbed interface to inspect the various namespaces:

# %%
fs[0].dump()
# Out:
# {'default': {'globalDomain': 'g',
#   'GRIBEditionNumber': 1,
#   'eps': 0,
#   'offsetSection0': 0,
#   'section0Length': 8,
#   'totalLength': 150,
#   'editionNumber': 1,
#   'WMO': 0,
#   'productionStatusOfProcessedData': 0,
#   'section1Length': 52,
#   'wrongPadding': 0,
#   'table2Version': 128,
#   'centre': 'ecmf',
#   'centreDescription': 'European Centre for Medium-Range Weather Forecasts',
#   'generatingProcessIdentifier': 254,
#   'gridDefinition': 255,
#   'indicatorOfParameter': 130,
#   'parameterName': 'Temperature',
#   'parameterUnits': 'K',
#   'indicatorOfTypeOfLevel': 'pl',
#   'pressureUnits': 'hPa',
#   'typeOfLevelECMF': 'isobaricInhPa',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 1000,
#   'yearOfCentury': 18,
#   'month': 8,
#   'day': 1,
#   'hour': 12,
#   'minute': 0,
#   'second': 0,
#   'unitOfTimeRange': 1,
#   'P1': 0,
#   'P2': 0,
#   'timeRangeIndicator': 0,
#   'numberIncludedInAverage': 0,
#   'numberMissingFromAveragesOrAccumulations': 0,
#   'centuryOfReferenceTimeOfData': 21,
#   'subCentre': 0,
#   'paramIdECMF': '130',
#   'paramId': 130,
#   'cfNameECMF': 'air_temperature',
#   'cfName': 'air_temperature',
#   'unitsECMF': 'K',
#   'units': 'K',
#   'nameECMF': 'Temperature',
#   'name': 'Temperature',
#   'decimalScaleFactor': 0,
#   'setLocalDefinition': 0,
#   'optimizeScaleFactor': 0,
#   'dataDate': 20180801,
#   'year': 2018,
#   'dataTime': 1200,
#   'julianDay': 2458332.0,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'marsParam': '130.128',
#   'validityDate': 20180801,
#   'validityTime': 1200,
#   'validityDateTime': 2458331.5083333333,
#   'deleteLocalDefinition': 0,
#   'localUsePresent': 1,
#   'reservedNeedNotBePresent': [''],
#   'localDefinitionNumber': 1,
#   'GRIBEXSection1Problem': 0,
#   'marsClass': 'od',
#   'marsType': 'an',
#   'marsStream': 'oper',
#   'experimentVersionNumber': '0001',
#   'perturbationNumber': 0,
#   'numberOfForecastsInEnsemble': 0,
#   'padding_local1_1': '00',
#   'grib2LocalSectionNumber': 1,
#   'localExtensionPadding': '',
#   '_x': None,
#   'section1Padding': '',
#   'shortNameECMF': 't',
#   'shortName': 't',
#   'cfVarNameECMF': 't',
#   'cfVarName': 't',
#   'ifsParam': 130,
#   'stepTypeForConversion': 'unknown',
#   'md5Section1': '3ae6b1f6f34f431c6134c40ec42f27fa',
#   'md5Product': '54697e1d910c88b76a8759b67e5c7a9c',
#   'paramIdForConversion': 0,
#   'gridDescriptionSectionPresent': 1,
#   'bitmapPresent': 0,
#   'angleSubdivisions': 1000,
#   'section2Length': 32,
#   'radius': 6367470,
#   'numberOfVerticalCoordinateValues': 0,
#   'neitherPresent': 255,
#   'pvlLocation': 255,
#   'dataRepresentationType': 0,
#   'gridDefinitionDescription': 'Latitude/Longitude Grid',
#   'gridDefinitionTemplateNumber': 0,
#   'Ni': 12,
#   'Nj': 7,
#   'latitudeOfFirstGridPoint': 90000,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPoint': 0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'resolutionAndComponentFlags': 128,
#   'ijDirectionIncrementGiven': 1,
#   'earthIsOblate': 0,
#   'resolutionAndComponentFlags3': 0,
#   'resolutionAndComponentFlags4': 0,
#   'uvRelativeToGrid': 0,
#   'resolutionAndComponentFlags6': 0,
#   'resolutionAndComponentFlags7': 0,
#   'resolutionAndComponentFlags8': 0,
#   'latitudeOfLastGridPoint': -90000,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPoint': 330000,
#   'longitudeOfLastGridPointInDegrees': 330.0,
#   'iDirectionIncrement': 30000,
#   'jDirectionIncrement': 30000,
#   'isGridded': 1,
#   'scanningMode': 0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'alternativeRowScanning': 0,
#   'iScansPositively': 1,
#   'jScansNegatively': 1,
#   'scanningMode4': 0,
#   'scanningMode5': 0,
#   'scanningMode6': 0,
#   'scanningMode7': 0,
#   'scanningMode8': 0,
#   'swapScanningAlternativeRows': 0,
#   'jDirectionIncrementInDegrees': 30.0,
#   'iDirectionIncrementInDegrees': 30.0,
#   'numberOfDataPoints': 84,
#   'numberOfValues': 84,
#   'zeros': '',
#   'PVPresent': 0,
#   'padding_sec2_2': '',
#   'PLPresent': 0,
#   'padding_sec2_1': '',
#   'deletePV': '1',
#   'padding_sec2_3': '',
#   'md5Section2': 'e09e4d6171c0ac85da1d256b2f8acf88',
#   'isSpectral': 0,
#   'lengthOfHeaders': 85,
#   'md5Headers': '9160fb809a9d7b1efc95163bf36e6b51',
#   'missingValue': 9999,
#   'tableReference': 0,
#   'section4Length': 54,
#   'halfByte': 8,
#   'dataFlag': 8,
#   'binaryScaleFactor': 3,
#   'referenceValue': 240.56417846679688,
#   'referenceValueError': 1.52587890625e-05,
#   'sphericalHarmonics': 0,
#   'complexPacking': 0,
#   'integerPointValues': 0,
#   'additionalFlagPresent': 0,
#   'orderOfSPD': 2,
#   'boustrophedonic': 0,
#   'hideThis': 0,
#   'packingType': 'grid_simple',
#   'bitsPerValue': 4,
#   'constantFieldHalfByte': 8,
#   'bitMapIndicator': 255,
#   'numberOfCodedValues': 84,
#   'packingError': 4.000007629394531,
#   'unpackedError': 1.52587890625e-05,
#   'maximum': 320.5641784667969,
#   'minimum': 240.56417846679688,
#   'average': 279.70703560965404,
#   'standardDeviation': 19.67421739058438,
#   'skewness': -0.7312302105044429,
#   'kurtosis': -0.16904561574741717,
#   'isConstant': 0.0,
#   'numberOfMissing': 0,
#   'dataLength': 5,
#   'changeDecimalPrecision': 0,
#   'decimalPrecision': 0,
#   'bitsPerValueAndRepack': 4,
#   'setPackingType': 'grid_simple',
#   'scaleValuesBy': 1.0,
#   'offsetValuesBy': 0.0,
#   'gridType': 'regular_ll',
#   'getNumberOfValues': 84,
#   'padding_sec4_1': '',
#   'md5Section4': '7ea3331d80a962b5dc99276b76451eac',
#   'section5Length': 4,
#   '7777': '7777'},
#  'ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 1000,
#   'dataDate': 20180801,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 't',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'geography': {'bitmapPresent': 0,
#   'Ni': 12,
#   'Nj': 7,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPointInDegrees': 330.0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 30.0,
#   'iDirectionIncrementInDegrees': 30.0,
#   'gridType': 'regular_ll'},
#  'mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 1000,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 't',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'},
#  'parameter': {'centre': 'ecmf',
#   'paramId': 130,
#   'units': 'K',
#   'name': 'Temperature',
#   'shortName': 't'},
#  'statistics': {'max': 320.5641784667969,
#   'min': 240.56417846679688,
#   'avg': 279.70703560965404,
#   'sd': 19.67421739058438,
#   'skew': -0.7312302105044429,
#   'kurt': -0.16904561574741717,
#   'const': 0.0},
#  'time': {'dataDate': 20180801,
#   'dataTime': 1200,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'validityDate': 20180801,
#   'validityTime': 1200},
#  'vertical': {'typeOfLevel': 'isobaricInhPa', 'level': 1000}}
