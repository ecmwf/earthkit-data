# %% [markdown]
# ## Xarray engine: ensemble data

# %% [markdown]
# Get input GRIB ensemble forecast data.

# %%
import earthkit.data as ekd
ds_fl = ekd.from_source("sample", "ens_cf_pf.grib")
# Out:
# ens_cf_pf.grib:   0%|          | 0.00/7.03k [00:00<?, ?B/s]

# %% [markdown]
# The data contains 3 ensemble members: 1 control and 2 perturbed members.

# %%
ds_fl.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa    500  20240603         0         0
# 1   ecmf         t  isobaricInhPa    500  20240603         0         6
# 2   ecmf         t  isobaricInhPa    500  20240603         0         0
# 3   ecmf         t  isobaricInhPa    500  20240603         0         0
# 4   ecmf         t  isobaricInhPa    500  20240603         0         6
# 5   ecmf         t  isobaricInhPa    500  20240603         0         6
#
#   dataType  number    gridType
# 0       cf       0  regular_ll
# 1       cf       0  regular_ll
# 2       pf       1  regular_ll
# 3       pf       2  regular_ll
# 4       pf       1  regular_ll
# 5       pf       2  regular_ll

# %% [raw]
# When we convert GRIB data to Xarray with :py:meth:`~data.readers.grib.index.GribFieldList.to_xarray` the ensemble dimension is defined by the "number" :ref:`dimension role <xr_dim_roles>`. By default, this role is using the "number" metadata key.

# %%
ds_fl.to_xarray()
# Out:
# <xarray.Dataset> Size: 33kB
# Dimensions:    (number: 3, step: 2, latitude: 19, longitude: 36)
# Coordinates:
#   * number     (number) int64 24B 0 1 2
#   * step       (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     t          (number, step, latitude, longitude) float64 33kB ...
# Attributes: (12/13)
#     param:        t
#     paramId:      130
#     class:        od
#     stream:       enfo
#     levtype:      pl
#     type:         cf
#     ...           ...
#     date:         20240603
#     time:         0
#     domain:       g
#     levelist:     500
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %% [markdown]
# This default behaviour can be overridden by specifying custom ``dim_roles``. E.g. to get the ensemble member number from the "perturbatioNumber" key we can use:

# %%
ds_fl.to_xarray(dim_roles={"number": "perturbationNumber"})
# Out:
# <xarray.Dataset> Size: 33kB
# Dimensions:    (number: 3, step: 2, latitude: 19, longitude: 36)
# Coordinates:
#   * number     (number) int64 24B 0 1 2
#   * step       (step) timedelta64[ns] 16B 00:00:00 06:00:00
#   * latitude   (latitude) float64 152B 90.0 80.0 70.0 60.0 ... -70.0 -80.0 -90.0
#   * longitude  (longitude) float64 288B 0.0 10.0 20.0 30.0 ... 330.0 340.0 350.0
# Data variables:
#     t          (number, step, latitude, longitude) float64 33kB ...
# Attributes: (12/14)
#     param:        t
#     paramId:      130
#     class:        od
#     stream:       enfo
#     levtype:      pl
#     type:         cf
#     ...           ...
#     time:         0
#     domain:       g
#     number:       0
#     levelist:     500
#     Conventions:  CF-1.8
#     institution:  ECMWF
