# %%
# !test -f test6.grib || wget https://github.com/ecmwf/emohawk/raw/main/docs/examples/test6.grib

# %% [markdown]
# ### GRIB handling basics

# %% [markdown]
# We load a GRIB file containing 6 messages from disk:

# %%
import emohawk

fs = emohawk.load_from("file", "test6.grib")

# %% [markdown]
# No GRIB data is actually loaded at this point.

# %% [markdown]
# #### Iteration

# %% [markdown]
# A GRIB data object consists of GribFields. When used in iteration these are automatically created and released when going out of scope. As a result, during the iteration only one GRIB message at a time is kept in memory:

# %%
for f in fs:
    print(f)
# Out:
# GribField(t,1000,20180801,1200,0,0)
# GribField(u,1000,20180801,1200,0,0)
# GribField(v,1000,20180801,1200,0,0)
# GribField(t,850,20180801,1200,0,0)
# GribField(u,850,20180801,1200,0,0)
# GribField(v,850,20180801,1200,0,0)

# %% [markdown]
# #### Inspecting the contents

# %%
len(fs)
# Out:
# 6

# %%
fs.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll
# 5       an       0  regular_ll

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_43b06 th {
#   text-align: left;
# }
# #T_43b06_row0_col0, #T_43b06_row0_col1, #T_43b06_row0_col2, #T_43b06_row0_col3, #T_43b06_row0_col4, #T_43b06_row0_col5, #T_43b06_row0_col6, #T_43b06_row0_col7, #T_43b06_row0_col8, #T_43b06_row1_col0, #T_43b06_row1_col1, #T_43b06_row1_col2, #T_43b06_row1_col3, #T_43b06_row1_col4, #T_43b06_row1_col5, #T_43b06_row1_col6, #T_43b06_row1_col7, #T_43b06_row1_col8, #T_43b06_row2_col0, #T_43b06_row2_col1, #T_43b06_row2_col2, #T_43b06_row2_col3, #T_43b06_row2_col4, #T_43b06_row2_col5, #T_43b06_row2_col6, #T_43b06_row2_col7, #T_43b06_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_43b06">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43b06_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_43b06_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_43b06_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_43b06_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_43b06_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_43b06_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_43b06_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_43b06_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_43b06_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43b06_level0_row0" class="row_heading level0 row0" >t</th>
#       <th id="T_43b06_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_43b06_row0_col0" class="data row0 col0" >1000,850</td>
#       <td id="T_43b06_row0_col1" class="data row0 col1" >20180801</td>
#       <td id="T_43b06_row0_col2" class="data row0 col2" >1200</td>
#       <td id="T_43b06_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_43b06_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_43b06_row0_col5" class="data row0 col5" >od</td>
#       <td id="T_43b06_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_43b06_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_43b06_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_43b06_level0_row1" class="row_heading level0 row1" >u</th>
#       <th id="T_43b06_level1_row1" class="row_heading level1 row1" >isobaricInhPa</th>
#       <td id="T_43b06_row1_col0" class="data row1 col0" >1000,850</td>
#       <td id="T_43b06_row1_col1" class="data row1 col1" >20180801</td>
#       <td id="T_43b06_row1_col2" class="data row1 col2" >1200</td>
#       <td id="T_43b06_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_43b06_row1_col4" class="data row1 col4" >131</td>
#       <td id="T_43b06_row1_col5" class="data row1 col5" >od</td>
#       <td id="T_43b06_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_43b06_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_43b06_row1_col8" class="data row1 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_43b06_level0_row2" class="row_heading level0 row2" >v</th>
#       <th id="T_43b06_level1_row2" class="row_heading level1 row2" >isobaricInhPa</th>
#       <td id="T_43b06_row2_col0" class="data row2 col0" >1000,850</td>
#       <td id="T_43b06_row2_col1" class="data row2 col1" >20180801</td>
#       <td id="T_43b06_row2_col2" class="data row2 col2" >1200</td>
#       <td id="T_43b06_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_43b06_row2_col4" class="data row2 col4" >132</td>
#       <td id="T_43b06_row2_col5" class="data row2 col5" >od</td>
#       <td id="T_43b06_row2_col6" class="data row2 col6" >oper</td>
#       <td id="T_43b06_row2_col7" class="data row2 col7" >an</td>
#       <td id="T_43b06_row2_col8" class="data row2 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Slicing

# %% [markdown]
# Standard Python slicing is available. It does not involve any loading/copying of GRIB data.

# %%
g = fs[1]
g
# Out:
# GribField(u,1000,20180801,1200,0,0)

# %%
g = fs[1:3]
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         v  isobaricInhPa   1000  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
g = fs[-1]
g
# Out:
# GribField(v,850,20180801,1200,0,0)

# %% [markdown]
# #### Getting data values

# %%
v = fs[0].to_numpy()
v.shape
# Out:
# (84,)

# %%
v[0:4]
# Out:
# array([272.56417847, 272.56417847, 272.56417847, 272.56417847])

# %%
v = fs.to_numpy()
v.shape
# Out:
# (6, 84)

# %%
v[0:2,0:4]
# Out:
# array([[272.56417847, 272.56417847, 272.56417847, 272.56417847],
#        [ -6.28688049,  -6.28688049,  -6.28688049,  -6.28688049]])

# %% [markdown]
# #### Metadata

# %% [markdown]
# Metadata access works both on individual fields and slices:

# %%
fs[0].metadata("typeOfLevel")
# Out:
# 'isobaricInhPa'

# %%
fs[0:2].metadata(["level", "paramId"])
# Out:
# [[1000, 130], [1000, 131]]

# %% [markdown]
# and on all the fields:

# %%
fs[:4].metadata("level")
# Out:
# [1000, 1000, 1000, 850]

# %%
fs[:4].metadata(["level", "paramId"])
# Out:
# [[1000, 130], [1000, 131], [1000, 132], [850, 130]]

# %% [markdown]
# Key qualifiers can be used to prescribe the required metadata type:

# %%
fs[0].metadata(["centre", "centre:l", "centre:int", "centre:s", "centre:str"])
# Out:
# ['ecmf', 98, 98, 'ecmf', 'ecmf']

# %% [markdown]
# Metadata access with [] only works on individual fields:

# %%
fs[0]["centre"]
# Out:
# 'ecmf'

# %% [markdown]
# #### Selection

# %% [markdown]
# Selection by metadata is always creating a "view", no copying of GRIB data is involved.

# %%
g = fs.sel(shortName=["u", "v"], level=850)
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 1   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
g = fs.sel(param="t")
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         t  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %% [markdown]
# #### Xarray

# %% [markdown]
# Xarray conversion does not involve disk writing. Under the hood it uses cfgrib.

# %%
ds = fs.to_xarray()
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (number: 1, time: 1, step: 1, isobaricInhPa: 2, latitude: 7,
#                     longitude: 12)
# Coordinates:
#   * number         (number) int64 0
#   * time           (time) datetime64[ns] 2018-08-01T12:00:00
#   * step           (step) timedelta64[ns] 00:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 1e+03 850.0
#   * latitude       (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude      (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
#     valid_time     (time, step) datetime64[ns] ...
# Data variables:
#     t              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
#     u              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
#     v              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-02-10T08:33 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# We can pass all the kwargs arguments cfgrib accepts. On top of that emohawk provides the **ignore_keys** option to omit keys from the default set of keys used by cfgrib:

# %%
ds = fs.to_xarray(xarray_open_dataset_kwargs={"backend_kwargs": {"ignore_keys": ["number"]}})
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 1, step: 1, isobaricInhPa: 2, latitude: 7,
#                     longitude: 12)
# Coordinates:
#   * time           (time) datetime64[ns] 2018-08-01T12:00:00
#   * step           (step) timedelta64[ns] 00:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 1e+03 850.0
#   * latitude       (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude      (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
#     valid_time     (time, step) datetime64[ns] ...
# Data variables:
#     t              (time, step, isobaricInhPa, latitude, longitude) float32 ...
#     u              (time, step, isobaricInhPa, latitude, longitude) float32 ...
#     v              (time, step, isobaricInhPa, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-02-10T08:33 GRIB to CDM+CF via cfgrib-0.9.1...
