# %%
# !test -f test6.grib || wget https://github.com/ecmwf/emohawk/raw/main/docs/examples/test6.grib

# %% [markdown]
# ## GRIB handling basics

# %% [markdown]
# We load a GRIB file containing 6 messages from disk:

# %%
import emohawk

fs = emohawk.load_from("file", "test6.grib")

# %% [markdown]
# No GRIB data is actually loaded at this point.

# %% [markdown]
# ### Iteration

# %% [markdown]
# A GRIB data object consists of GribFields. When used in iteration these are automatically created and released when going out of scope. As a result, during the iteration only one GRIB message at a time is kept in memory:

# %%
for f in fs:
    print(f)
# Out:
# GribField(t,1000,20180801,1200,0,0)
# GribField(u,1000,20180801,1200,0,0)
# GribField(v,1000,20180801,1200,0,0)
# GribField(t,850,20180801,1200,0,0)
# GribField(u,850,20180801,1200,0,0)
# GribField(v,850,20180801,1200,0,0)

# %% [markdown]
# ### Inspecting the contents

# %%
len(fs)
# Out:
# 6

# %%
fs.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll
# 5       an       0  regular_ll

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_4192d th {
#   text-align: left;
# }
# #T_4192d_row0_col0, #T_4192d_row0_col1, #T_4192d_row0_col2, #T_4192d_row0_col3, #T_4192d_row0_col4, #T_4192d_row0_col5, #T_4192d_row0_col6, #T_4192d_row0_col7, #T_4192d_row0_col8, #T_4192d_row1_col0, #T_4192d_row1_col1, #T_4192d_row1_col2, #T_4192d_row1_col3, #T_4192d_row1_col4, #T_4192d_row1_col5, #T_4192d_row1_col6, #T_4192d_row1_col7, #T_4192d_row1_col8, #T_4192d_row2_col0, #T_4192d_row2_col1, #T_4192d_row2_col2, #T_4192d_row2_col3, #T_4192d_row2_col4, #T_4192d_row2_col5, #T_4192d_row2_col6, #T_4192d_row2_col7, #T_4192d_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_4192d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4192d_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_4192d_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_4192d_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_4192d_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_4192d_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_4192d_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_4192d_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_4192d_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_4192d_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4192d_level0_row0" class="row_heading level0 row0" >t</th>
#       <th id="T_4192d_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_4192d_row0_col0" class="data row0 col0" >1000,850</td>
#       <td id="T_4192d_row0_col1" class="data row0 col1" >20180801</td>
#       <td id="T_4192d_row0_col2" class="data row0 col2" >1200</td>
#       <td id="T_4192d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4192d_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_4192d_row0_col5" class="data row0 col5" >od</td>
#       <td id="T_4192d_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_4192d_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_4192d_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_4192d_level0_row1" class="row_heading level0 row1" >u</th>
#       <th id="T_4192d_level1_row1" class="row_heading level1 row1" >isobaricInhPa</th>
#       <td id="T_4192d_row1_col0" class="data row1 col0" >1000,850</td>
#       <td id="T_4192d_row1_col1" class="data row1 col1" >20180801</td>
#       <td id="T_4192d_row1_col2" class="data row1 col2" >1200</td>
#       <td id="T_4192d_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_4192d_row1_col4" class="data row1 col4" >131</td>
#       <td id="T_4192d_row1_col5" class="data row1 col5" >od</td>
#       <td id="T_4192d_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_4192d_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_4192d_row1_col8" class="data row1 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_4192d_level0_row2" class="row_heading level0 row2" >v</th>
#       <th id="T_4192d_level1_row2" class="row_heading level1 row2" >isobaricInhPa</th>
#       <td id="T_4192d_row2_col0" class="data row2 col0" >1000,850</td>
#       <td id="T_4192d_row2_col1" class="data row2 col1" >20180801</td>
#       <td id="T_4192d_row2_col2" class="data row2 col2" >1200</td>
#       <td id="T_4192d_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_4192d_row2_col4" class="data row2 col4" >132</td>
#       <td id="T_4192d_row2_col5" class="data row2 col5" >od</td>
#       <td id="T_4192d_row2_col6" class="data row2 col6" >oper</td>
#       <td id="T_4192d_row2_col7" class="data row2 col7" >an</td>
#       <td id="T_4192d_row2_col8" class="data row2 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %%
fs[0].info()
# Out:
# <style type="text/css"> /* Based on:
#  https://codepen.io/htmlcssfreebies/pen/WNpVeRK
#  https://github.com/pydata/xarray/blob/main/xarray/static/css/style.css
#  */
#
#  :root {
#     --eh-font-color0: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#     --eh-font-color2: var(--jp-content-font-color2, rgba(0, 0, 0, 0.54));
#     --eh-font-color3: var(--jp-content-font-color3, rgba(0, 0, 0, 0.38));
#     --eh-border-color: var(--jp-border-color2, #e0e0e0);
#     --eh-disabled-color: var(--jp-layout-color3, #bdbdbd);
#     --eh-background-color: var(--jp-layout-color0, white);
#     --eh-background-color-row-even: var(--jp-layout-color1, white);
#     --eh-background-color-row-odd: var(--jp-layout-color2, #eeeeee);
#   }
#
#
#  /* Reset */
#  *,
#  *::before,
#  *::after {
#      box-sizing: border-box;
#  }
#
#  .eh-description {
#     color: var(--eh-font-color2);
#  }
#
#  .eh-section {
#     padding-left: 0px;
#  }
#
#  /* Tabs Container */
#  .eh-tabs-container {
#      padding: 0px;
#  }
#
#  /* Tabs Block */
#  .eh-tabs-block {
#      display: flex;
#      align-items: center;
#      justify-content: center;
#      padding-top: 4px;
#  }
#
#  /* Tabs */
#  .eh-tabs {
#      display: flex;
#      flex-wrap: wrap;
#      width: 100%;
#  }
#
#  .eh-tabs label {
#      width: 100%;
#      display: flex;
#      align-items: center;
#      justify-content: center;
#      padding-left: 6px;
#      padding-right: 6px;
#      font-weight: 400;
#      cursor: pointer;
#      color: var(--eh-font-color2);
#      background-color: var(--eh-background-color);
#      border-top: 1px solid var(--eh-background-color);
#      border-bottom: 1px solid var(--eh-disabled-color);
#  }
#
#  /* Tab page contents */
#  .eh-tabs .tab {
#      flex-grow: 1;
#      width: 100%;
#      height: 100%;
#      display: none;
#      padding: 2px 2px;
#  }
#
#  .eh-tabs [type=radio] {
#      display: none;
#  }
#
#  .eh-tabs [type=radio]:checked + label {
#      font-weight: 500;
#      color: var(--eh-font-color0);
#      border: 1px solid var(--eh-disabled-color);
#  }
#
#  .eh-tabs [type=radio]:checked + label + .tab {
#      display: block;
#  }
#
#  .eh-tabs [type=radio]:not(:checked) + label:hover {
#     color: var(--xr-font-color0);
#  }
#
#
#  @media (min-width: 768px) {
#
#      .eh-tabs-container {
#          padding: 1rem 1rem;
#      }
#
#      .eh-tabs label {
#          order: 1;
#          width: auto;
#      }
#
#      .eh-tabs .tab {
#          order: 9;
#      }
#
#      .eh-tabs [type=radio]:checked + label {
#          border-bottom: none;
#      }
#  }
#  @media (min-width: 992px) {
#
#      .eh-tabs {
#          width: 800px;
#      }
#  }</style><div class="eh-description">GribField</div>
# <div>
# <section class="eh-section>
# <div class="eh-tabs-container">
# <div class="eh-tabs-block">
# <div class="eh-tabs">
# <input type="radio" name="eh-tabs" id="2fd94e8d-b601-42d7-9f8f-4d1fc9102005"  />
# <label for="2fd94e8d-b601-42d7-9f8f-4d1fc9102005" title="Keys in the ecCodes ls namespace">ls</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>edition</b></td><td>1</td></tr> <tr><td><b>centre</b></td><td>ecmf</td></tr> <tr><td><b>typeOfLevel</b></td><td>isobaricInhPa</td></tr> <tr><td><b>level</b></td><td>1000</td></tr> <tr><td><b>dataDate</b></td><td>20180801</td></tr> <tr><td><b>stepRange</b></td><td>0</td></tr> <tr><td><b>dataType</b></td><td>an</td></tr> <tr><td><b>shortName</b></td><td>t</td></tr> <tr><td><b>packingType</b></td><td>grid_simple</td></tr> <tr><td><b>gridType</b></td><td>regular_ll</td></tr>
# </table>
# </div>
#      <input type="radio" name="eh-tabs" id="bd005bae-d8b2-4bd4-ae40-1aa8254a0f5f"  />
# <label for="bd005bae-d8b2-4bd4-ae40-1aa8254a0f5f" title="Keys in the ecCodes geography namespace">geography</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>bitmapPresent</b></td><td>0</td></tr> <tr><td><b>latitudeOfFirstGridPointInDegrees</b></td><td>90.0</td></tr> <tr><td><b>longitudeOfFirstGridPointInDegrees</b></td><td>0.0</td></tr> <tr><td><b>latitudeOfLastGridPointInDegrees</b></td><td>-90.0</td></tr> <tr><td><b>longitudeOfLastGridPointInDegrees</b></td><td>330.0</td></tr> <tr><td><b>iScansNegatively</b></td><td>0</td></tr> <tr><td><b>jScansPositively</b></td><td>0</td></tr> <tr><td><b>jPointsAreConsecutive</b></td><td>0</td></tr> <tr><td><b>jDirectionIncrementInDegrees</b></td><td>30.0</td></tr> <tr><td><b>iDirectionIncrementInDegrees</b></td><td>30.0</td></tr> <tr><td><b>gridType</b></td><td>regular_ll</td></tr>
# </table>
# </div>
#      <input type="radio" name="eh-tabs" id="8c4d57b5-28ab-4ebf-b103-0fc35ad9f17b"  />
# <label for="8c4d57b5-28ab-4ebf-b103-0fc35ad9f17b" title="Keys in the ecCodes mars namespace">mars</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>domain</b></td><td>g</td></tr> <tr><td><b>levtype</b></td><td>pl</td></tr> <tr><td><b>levelist</b></td><td>1000</td></tr> <tr><td><b>date</b></td><td>20180801</td></tr> <tr><td><b>time</b></td><td>1200</td></tr> <tr><td><b>step</b></td><td>0</td></tr> <tr><td><b>param</b></td><td>t</td></tr> <tr><td><b>class</b></td><td>od</td></tr> <tr><td><b>type</b></td><td>an</td></tr> <tr><td><b>stream</b></td><td>oper</td></tr> <tr><td><b>expver</b></td><td>0001</td></tr>
# </table>
# </div>
#      <input type="radio" name="eh-tabs" id="d5027a03-d5a0-445e-8630-46758d1cf670" checked />
# <label for="d5027a03-d5a0-445e-8630-46758d1cf670" title="Keys in the ecCodes parameter namespace">parameter</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>centre</b></td><td>ecmf</td></tr> <tr><td><b>paramId</b></td><td>130</td></tr> <tr><td><b>units</b></td><td>K</td></tr> <tr><td><b>name</b></td><td>Temperature</td></tr> <tr><td><b>shortName</b></td><td>t</td></tr>
# </table>
# </div>
#      <input type="radio" name="eh-tabs" id="c5bfe35e-e06c-4d82-beae-53f7e93ccc1d"  />
# <label for="c5bfe35e-e06c-4d82-beae-53f7e93ccc1d" title="Keys in the ecCodes time namespace">time</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>dataDate</b></td><td>20180801</td></tr> <tr><td><b>dataTime</b></td><td>1200</td></tr> <tr><td><b>stepUnits</b></td><td>1</td></tr> <tr><td><b>stepType</b></td><td>instant</td></tr> <tr><td><b>stepRange</b></td><td>0</td></tr> <tr><td><b>startStep</b></td><td>0</td></tr> <tr><td><b>endStep</b></td><td>0</td></tr> <tr><td><b>validityDate</b></td><td>20180801</td></tr> <tr><td><b>validityTime</b></td><td>1200</td></tr>
# </table>
# </div>
#      <input type="radio" name="eh-tabs" id="d9bacc02-4003-4b63-8cfa-48e2bb5aa99f"  />
# <label for="d9bacc02-4003-4b63-8cfa-48e2bb5aa99f" title="Keys in the ecCodes vertical namespace">vertical</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>typeOfLevel</b></td><td>isobaricInhPa</td></tr> <tr><td><b>level</b></td><td>1000</td></tr>
# </table>
# </div>
#
# </div>
# </div>
# </div>
# </section>
# </div>

# %% [markdown]
# ### Slicing

# %% [markdown]
# Standard Python slicing is available. It does not involve any loading/copying of GRIB data.

# %%
g = fs[1]
g
# Out:
# GribField(u,1000,20180801,1200,0,0)

# %%
g = fs[1:3]
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         v  isobaricInhPa   1000  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
g = fs[-1]
g
# Out:
# GribField(v,850,20180801,1200,0,0)

# %% [markdown]
# ### Getting data values

# %%
v = fs[0].to_numpy()
v.shape
# Out:
# (84,)

# %%
v[0:4]
# Out:
# array([272.56417847, 272.56417847, 272.56417847, 272.56417847])

# %%
v = fs.to_numpy()
v.shape
# Out:
# (6, 84)

# %%
v[0:2,0:4]
# Out:
# array([[272.56417847, 272.56417847, 272.56417847, 272.56417847],
#        [ -6.28688049,  -6.28688049,  -6.28688049,  -6.28688049]])

# %% [markdown]
# ### Metadata

# %% [markdown]
# Metadata access works both on individual fields and slices:

# %%
fs[0].metadata("typeOfLevel")
# Out:
# 'isobaricInhPa'

# %%
fs[0:2].metadata(["level", "paramId"])
# Out:
# [[1000, 130], [1000, 131]]

# %% [markdown]
# and on all the fields:

# %%
fs[:4].metadata("level")
# Out:
# [1000, 1000, 1000, 850]

# %%
fs[:4].metadata(["level", "paramId"])
# Out:
# [[1000, 130], [1000, 131], [1000, 132], [850, 130]]

# %% [markdown]
# Key qualifiers can be used to prescribe the required metadata type:

# %%
fs[0].metadata(["centre", "centre:l", "centre:int", "centre:s", "centre:str"])
# Out:
# ['ecmf', 98, 98, 'ecmf', 'ecmf']

# %% [markdown]
# Metadata access with [] only works on individual fields:

# %%
fs[0]["centre"]
# Out:
# 'ecmf'

# %% [markdown]
# ### Selection

# %% [markdown]
# Selection by metadata is always creating a "view", no copying of GRIB data is involved.

# %%
g = fs.sel(shortName=["u", "v"], level=850)
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 1   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %%
g = fs.sel(param="t")
g.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         t  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll

# %% [markdown]
# ### Xarray

# %% [markdown]
# Xarray conversion does not involve disk writing. Under the hood it uses cfgrib.

# %%
ds = fs.to_xarray()
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (number: 1, time: 1, step: 1, isobaricInhPa: 2, latitude: 7,
#                     longitude: 12)
# Coordinates:
#   * number         (number) int64 0
#   * time           (time) datetime64[ns] 2018-08-01T12:00:00
#   * step           (step) timedelta64[ns] 00:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 1e+03 850.0
#   * latitude       (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude      (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
#     valid_time     (time, step) datetime64[ns] ...
# Data variables:
#     t              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
#     u              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
#     v              (number, time, step, isobaricInhPa, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-02-23T15:39 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# We can pass all the kwargs arguments cfgrib accepts. On top of that emohawk provides the **ignore_keys** option to omit keys from the default set of keys used by cfgrib:

# %%
ds = fs.to_xarray(xarray_open_dataset_kwargs={"backend_kwargs": {"ignore_keys": ["number"]}})
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 1, step: 1, isobaricInhPa: 2, latitude: 7,
#                     longitude: 12)
# Coordinates:
#   * time           (time) datetime64[ns] 2018-08-01T12:00:00
#   * step           (step) timedelta64[ns] 00:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 1e+03 850.0
#   * latitude       (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude      (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
#     valid_time     (time, step) datetime64[ns] ...
# Data variables:
#     t              (time, step, isobaricInhPa, latitude, longitude) float32 ...
#     u              (time, step, isobaricInhPa, latitude, longitude) float32 ...
#     v              (time, step, isobaricInhPa, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-02-23T15:39 GRIB to CDM+CF via cfgrib-0.9.1...
