# %% [markdown]
# # Decorators
#
# `earthkit-data` has a number of decorators which are used in downstream earthkit packages to
# make the user interface for the simpler for non-technical users..
#
# This notebook demonstrates the handlers and the effect when used.

# %%
# Import earhtkit data
from earthkit import data as ekd

# Import the handlers
from earthkit.data.utils.inputs_transform import format_handler, metadata_handler

# Import some common libraries we will use for typesetting example
import xarray as xr
import numpy as np

# Set cache policy
ekd.settings.set("cache-policy", "user")

# %% [markdown]
# Create some example earthkit data objects to use as examples, the following a various `Reader` objects using test data

# %%
from earthkit.data.testing import earthkit_remote_test_data_file
ekds_grib = ekd.from_source("url", earthkit_remote_test_data_file("era5_temperature_europe_20150101.grib"))
ekds_geojson = ekd.from_source("url", earthkit_remote_test_data_file("NUTS_RG_60M_2021_4326_LEVL_0.geojson"))
ekds_netcdf = ekd.from_source("url", earthkit_remote_test_data_file("test_single.nc"))
ekds_netcdf_satellite = ekd.from_source("url",earthkit_remote_test_data_file("CO2_iasi_metop_c_nlis_2021_01.nc"))

reader_objects = [
    ekds_grib,
    ekds_geojson,
    ekds_netcdf,
    ekds_netcdf_satellite
]
# Out:
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/readers/netcdf/fieldlist.py:351: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   return xr.open_dataset(self.path_or_url)

# %% [markdown]
# Create some common data objects to use examples, these are create from the `Reader` objects.

# %%
fieldlist_example = ekds_grib.to_fieldlist()
xarray_ds_example = ekds_netcdf.to_xarray()
xarray_da_example = xarray_ds_example[list(xarray_ds_example.data_vars)[0]]
pandas_df_example = ekds_netcdf_satellite.to_pandas()
pandas_series_example = pandas_df_example.iloc[:, 0]
numpy_example = ekds_grib.to_numpy()
geopandas_example = ekds_geojson.to_geopandas()

data_objects = [
    fieldlist_example,
    xarray_ds_example,
    xarray_da_example,
    pandas_df_example,
    pandas_series_example,
    numpy_example,
    geopandas_example
]
# Out:
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/readers/netcdf/fieldlist.py:235: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   return xr.open_mfdataset(

# %% [markdown]
# ## The `format_handler` decorator
#
# The `format_handler` decorator is used to automatically convert the input data to the desired format.
# The standard behaviou it to use the typesetting of the function, the example below demonstrates how `data`
# is always converted to the type by the function signiture.

# %%
@format_handler()
def xrDataArray_function(data: xr.DataArray):
    assert isinstance(data, xr.DataArray), f"data is not an xarray.DataArray: got {type(data)}"
    return data

test_types = [
    ekds_grib,
    ekds_netcdf,
    ekds_netcdf_satellite,
    fieldlist_example,
    xarray_da_example,
    xarray_ds_example,
    pandas_series_example,
    numpy_example
]

print(f"{'Input type':<30} -> {'Output type':<30}")
for input in test_types:
    output = xrDataArray_function(input)
    print(f"{type(input)} -> {type(output)}")
# Out:
# Input type                     -> Output type
# <class 'xarray.core.dataarray.DataArray'> -> <class 'xarray.core.dataarray.DataArray'>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 1
# 2
# 3
# 2 <earthkit.data.wrappers.xarray.XArrayDatasetWrapper object at 0x12e683b30>
# 3 <earthkit.data.wrappers.xarray.XArrayDatasetWrapper object at 0x12e683b30>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'xarray.core.dataset.Dataset'> -> <class 'xarray.core.dataarray.DataArray'>

# %% [markdown]
# The example above only uses input objects that can be successfully converted to the requested type, an `xarray.DataArray`. When the conversion is not possible, the decorator will pass the unconverted object to the function and let the function fail naturally. Below we pass a `pandas.DataFrame` object which can not be converted to a `xarray.DataArray` because it has too many columns, i.e. variables:

# %%
try:
    xrDataArray_function(pandas_df_example)
except Exception as e:
    print(f"Expected exception for wrong input type:\n{e}")
# Out:
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.pandas.PandasDataFrameWrapper object at 0x12c61d8b0>
# 3 <earthkit.data.wrappers.pandas.PandasDataFrameWrapper object at 0x12c61d8b0>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Expected exception for wrong input type:
# xarray.Dataset contains more than one data variable, cannot convert to DataArray

# %% [markdown]
# If the downstream function can handle multiple datatypes. The decorator will first check if it matches any type listed, if not it will then attempt to convert the input in the order of the listed types. In the example below, the function can handle `xarray.DataArray` or `xarray.Dataset`. You can see that the objects from the previous example are converted to `xarray.DataArray`, and the new ones (which cannot be converted to an `xarray.DataArray`) are converted to an `xarray.Dataset`.

# %%
@format_handler()
def xrDataArray_function(data: xr.DataArray | xr.Dataset):
    assert isinstance(data, (xr.DataArray, xr.Dataset)), f"data is not an xarray.DataArray or xarray.Dataset: got {type(data)}"
    return data

test_types = [
    ekds_grib,
    ekds_netcdf,
    ekds_netcdf_satellite,
    fieldlist_example,
    xarray_da_example,
    xarray_ds_example,
    pandas_series_example,
    numpy_example,
    pandas_df_example,
    geopandas_example,
    ekds_geojson,
]

print(f"{'Input type':<30} -> {'Output type':<30}")
for input in test_types:
    output = xrDataArray_function(input)
    print(f"{type(input)} -> {type(output)}")
# Out:
# Input type                     -> Output type
# 3 GRIBReader(/var/folders/l2/529q7bzs665bnrn7_wjx1nsr0000gn/T/earthkit-data-edwardcomyn-platt/url-774532de175ea822ed914e6ed9d6867990165a7c9a7a2ee4bbca9a34543881e9.grib)
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12c61d580>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12c6ffb00>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x108dffd40>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12d716300>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6823f0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6efc50>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6ec4a0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5010>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f4dd0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f4800>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f4d70>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5130>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f52e0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5370>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5430>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f54c0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5550>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5490>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5520>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5820>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5610>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f4f50>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5640>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f5850>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'earthkit.data.readers.grib.file.GRIBReader'> -> <class 'xarray.core.dataarray.DataArray'>
# 3 NetCDFFieldListReader(/var/folders/l2/529q7bzs665bnrn7_wjx1nsr0000gn/T/earthkit-data-edwardcomyn-platt/url-6bb0930f52d1d972bd351aa45496e5535f3654b880977291956895d953eca647.nc)
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'earthkit.data.readers.netcdf.NetCDFFieldListReader'> -> <class 'xarray.core.dataarray.DataArray'>
# 3 NetCDFFieldListReader(/var/folders/l2/529q7bzs665bnrn7_wjx1nsr0000gn/T/earthkit-data-edwardcomyn-platt/url-8fba89e643119776d3af076e26619575e3125164e8fa90e3f4d3695fa805090b.nc)
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'earthkit.data.readers.netcdf.NetCDFFieldListReader'> -> <class 'xarray.core.dataarray.DataArray'>
# 3 SimpleFieldList(24)
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6e1c10>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6e1df0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12e6f7650>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec01850>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02570>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02990>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02690>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02240>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec01af0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02450>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec020f0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02870>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02000>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec025d0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02ae0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02b70>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec026f0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec028d0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02cc0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec03050>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02bd0>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec03020>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec02b10>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.string.StrWrapper object at 0x12ec03140>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'earthkit.data.indexing.fieldlist.SimpleFieldList'> -> <class 'xarray.core.dataarray.DataArray'>
# <class 'xarray.core.dataarray.DataArray'> -> <class 'xarray.core.dataarray.DataArray'>
# <class 'xarray.core.dataset.Dataset'> -> <class 'xarray.core.dataset.Dataset'>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.pandas.PandasSeriesWrapper object at 0x12e6f7020>
# 3 <earthkit.data.wrappers.pandas.PandasSeriesWrapper object at 0x12e6f7020>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'pandas.Series'> -> <class 'xarray.core.dataarray.DataArray'>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.ndarray.NumpyNDArrayWrapper object at 0x12e6f7950>
# 3 <earthkit.data.wrappers.ndarray.NumpyNDArrayWrapper object at 0x12e6f7950>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# Transformed type: <class 'xarray.core.dataarray.DataArray'>
# <class 'numpy.ndarray'> -> <class 'xarray.core.dataarray.DataArray'>
# 1 {'pandas': <function wrapper at 0x11d15f2e0>, 'integer': <function wrapper at 0x12e6a8220>, 'ndarray': <function wrapper at 0x12e6a8680>, 'string': <function wrapper at 0x12e6a8c20>, 'xarray': <function wrapper at 0x12e6a9300>}
# 2 <earthkit.data.wrappers.pandas.PandasDataFrameWrapper object at 0x12e6f7950>
# 3 <earthkit.data.wrappers.pandas.PandasDataFrameWrapper object at 0x12e6f7950>
# Using translator: XArrayDataArrayTranslator
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_not_implemented', '_user_coords_to_fl_idx', 'batched', 'bounding_box', 'data', 'datetime', 'group_by', 'isel', 'merge', 'metadata', 'mutate', 'observer', 'order_by', 'sel', 'to_numpy', 'to_pandas', 'to_target', 'to_xarray', 'unique_values']
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/readers/netcdf/fieldlist.py:235: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   return xr.open_mfdataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 22
#      20 print(f"{'Input type':<30} -> {'Output type':<30}")
#      21 for input in test_types:
# ---> 22     output = xrDataArray_function(input)
#      23     print(f"{type(input)} -> {type(output)}")
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/utils/inputs_transform.py:311, in format_handler.<locals>.decorator.<locals>.wrapper(_auto_inputs_transform, *args, **kwargs)
#     309 if not _auto_inputs_transform:
#     310     return function(*args, **kwargs)
# --> 311 return _wrapper(kwarg_types, convert_types, *args, **kwargs)
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/utils/inputs_transform.py:286, in format_handler.<locals>.decorator.<locals>._wrapper(_kwarg_types, _convert_types, *args, **kwargs)
#     284 if type(value) not in types_allowed:
#     285     for target_type in types_allowed:
# --> 286         kwargs[key] = transform(value, target_type)
#     287         # try:
#     288         #     kwargs[key] = transform(value, target_type)
#     289         # except Exception as e:
#     290         #     print(f'hello {e}')
#     291         #     continue
#     292         break
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/translators/__init__.py:46, in transform(*args, **kwargs)
#      44 print(f"Using translator: {translator.__class__.__name__}")
#      45 print(dir(translator))
# ---> 46 transformed = translator()
#      47 print(f"Transformed type: {type(transformed)}")
#      49 return transformed
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/src/earthkit/data/translators/xarray.py:27, in XArrayDataArrayTranslator.__call__(self)
#      24 if isinstance(self.data, xr.Dataset):
#      25     # TODO: consider a warning under a strict=False mode?
#      26     if len(self.data.data_vars) > 1:
# ---> 27         raise ValueError(
#      28             "xarray.Dataset contains more than one data variable, cannot convert to DataArray"
#      29         )
#      30     elif len(self.data.data_vars) == 0:
#      31         raise ValueError("xarray.Dataset contains no data variables, cannot convert to DataArray")
#
# ValueError: xarray.Dataset contains more than one data variable, cannot convert to DataArray

# %%
@format_handler()
def np_str_function(data: str | np.ndarray):
    print(type(data))
    return data

this_np_str = np_str_function(ekds_netcdf_satellite)
this_converted_str = np_str_function("a_string")
this_converted_str = np_str_function(1)
# Out:
# <class 'earthkit.data.readers.netcdf.NetCDFFieldListReader'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ## The `metadata_handler` handler decorator
#
# The `metadata_handler` decorator enables modifications to the metadata based on the function requirements. Currently this includes an option to ensure that units are the correct type, and an option to add provenance metadata to the returned object.
#
# ## `ensure_units`
#
# The example below demonstrates how to ensure that the units are in degrees Celsius. The conversion uses [`pint`](https://pint.readthedocs.io/en/stable/), therefore the units string provided must be recognised as such. The source units are detected from the data object metadata. If the source units or target units cannot be detected, no attempt to convert will be made.

# %%
@metadata_handler(ensure_units = {"data": "celsius"})
def xrDataArray_convert_units(data: xr.DataArray):
    print(f"Units in function: {data.units}")
    return data

print(f"Input units before function call: {xarray_da_example.units}")
new_data = xrDataArray_convert_units(xarray_da_example)
print(f"Input units after function call: {xarray_da_example.units}")
print(f"New data units after function call: {new_data.units}")
# Out:
# Cannot find a wrapper for class: xarray.core.dataarray.DataArray, returning unwrapped object
# Cannot find a wrapper for class: xarray.core.dataarray.DataArray, returning unwrapped object
# Input units before function call: K
# Units in function: K
# Input units after function call: K
# New data units after function call: K

# %% [markdown]
# The output above demonstrates that units within the function call have been updated to those requests ("celsius"), but upon returning to the top level workflow the units were as initially provided.
