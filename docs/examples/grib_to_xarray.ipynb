# %% [markdown]
# ## Converting GRIB to NetCDF

# %%
import xarray as xr

ds = xr.open_dataset('tuv_pl.grib', engine='earthkit') #, engine='earthkit')'cfgrib'
ds.t  # .to_netcdf('temp.nc')
# Out:
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)>
# [504 values with dtype=<class 'numpy.float32'>]
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     metadata:  <earthkit.data.readers.grib.metadata.GribMetadata object at 0x...

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys=[]) #, engine='earthkit')'cfgrib'
ds.t
# Out:
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)>
# [504 values with dtype=<class 'numpy.float32'>]
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys=["shortName"]) #, engine='earthkit')'cfgrib'
ds.t
# Out:
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)>
# [504 values with dtype=<class 'numpy.float32'>]
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     shortName:  t

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys="describe") # 'CF'
ds.t
# Out:
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)>
# [504 values with dtype=<class 'numpy.float32'>]
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     shortName:                t
#     date:                     20180801
#     time:                     1200
#     step:                     0
#     paramId:                  130
#     marsClass:                od
#     marsStream:               oper
#     marsType:                 an
#     experimentVersionNumber:  0001

# %%
from earthkit.data import from_object
ek_xr = from_object(ds)

# %%
ek_xr.to_fieldlist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> ek_xr.to_fieldlist()
#
# AttributeError: 'XArrayDatasetWrapper' object has no attribute 'to_fieldlist'

# %%
import earthkit.data
earthkit.data.download_example_file("tuv_pl.grib")

# %%
fs = earthkit.data.from_source("file", "tuv_pl.grib")
print(fs)
# Out:
# GRIBReader(tuv_pl.grib)

# %%
fs_xr = fs.to_xarray(variable_metadata_keys=[])
fs_xr
# Out:
# {}
# GRIBReader(tuv_pl.grib)
# {'engine': 'earthkitobject'}
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.Dataset>
# Dimensions:    (levelist: 6, latitude: 7, longitude: 12)
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Data variables:
#     t          (levelist, latitude, longitude) <class 'numpy.float32'> ...
#     u          (levelist, latitude, longitude) <class 'numpy.float32'> ...
#     v          (levelist, latitude, longitude) <class 'numpy.float32'> ...
# Attributes:
#     centre:       ecmf
#     typeOfLevel:  isobaricInhPa
#     dataDate:     20180801
#     dataTime:     1200
#     stepRange:    0
#     dataType:     an
#     number:       0
#     gridType:     regular_ll
#     ekds_source:  tuv_pl.grib

# %%
fs_xr.t
# Out:
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)>
# [504 values with dtype=<class 'numpy.float32'>]
# Coordinates:
#   * levelist   (levelist) int64 300 400 500 700 850 1000
#   * latitude   (latitude) float64 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     shortName:                t
#     typeOfLevel:              isobaricInhPa
#     level:                    300
#     date:                     20180801
#     time:                     1200
#     step:                     0
#     number:                   0
#     paramId:                  130
#     marsClass:                od
#     marsStream:               oper
#     marsType:                 an
#     experimentVersionNumber:  0001

# %%
# dir(fs_xr.t.attrs['metadata'])
# fs_xr.t.attrs['metadata']._handle
# for k in fs_xr.t.attrs['metadata'].keys():
#     print(k)
fsm = fs.metadata()[0]
fsm.describe_keys()
# Out:
# ['shortName',
#  'typeOfLevel',
#  'level',
#  'date',
#  'time',
#  'step',
#  'number',
#  'paramId',
#  'marsClass',
#  'marsStream',
#  'marsType',
#  'experimentVersionNumber']

# %%
fs_xr.to_netcdf('_tuv_pl.nc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> fs_xr.to_netcdf('_tuv_pl.nc')
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/dataset.py:2280, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    2277     encoding = {}
#    2278 from xarray.backends.api import to_netcdf
# -> 2280 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    2281     self,
#    2282     path,
#    2283     mode=mode,
#    2284     format=format,
#    2285     group=group,
#    2286     engine=engine,
#    2287     encoding=encoding,
#    2288     unlimited_dims=unlimited_dims,
#    2289     compute=compute,
#    2290     multifile=False,
#    2291     invalid_netcdf=invalid_netcdf,
#    2292 )
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/backends/api.py:1259, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1254 # TODO: figure out how to refactor this logic (here and in save_mfdataset)
#    1255 # to avoid this mess of conditionals
#    1256 try:
#    1257     # TODO: allow this work (setting up the file for writing array data)
#    1258     # to be parallelized with dask
# -> 1259     dump_to_store(
#    1260         dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1261     )
#    1262     if autoclose:
#    1263         store.close()
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/backends/api.py:1306, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1303 if encoder:
#    1304     variables, attrs = encoder(variables, attrs)
# -> 1306 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/backends/common.py:352, in AbstractWritableDataStore.store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     349 if writer is None:
#     350     writer = ArrayWriter()
# --> 352 variables, attributes = self.encode(variables, attributes)
#     354 self.set_attributes(attributes)
#     355 self.set_dimensions(variables, unlimited_dims=unlimited_dims)
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/backends/common.py:441, in WritableCFDataStore.encode(self, variables, attributes)
#     438 def encode(self, variables, attributes):
#     439     # All NetCDF files get CF encoded by default, without this attempting
#     440     # to write times, for example, would fail.
# --> 441     variables, attributes = cf_encoder(variables, attributes)
#     442     variables = {k: self.encode_variable(v) for k, v in variables.items()}
#     443     attributes = {k: self.encode_attribute(v) for k, v in attributes.items()}
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/conventions.py:781, in cf_encoder(variables, attributes)
#     778 # add encoding for time bounds variables if present.
#     779 _update_bounds_encoding(variables)
# --> 781 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     783 # Remove attrs from bounds variables (issue #2921)
#     784 for var in new_vars.values():
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/conventions.py:781, in <dictcomp>(.0)
#     778 # add encoding for time bounds variables if present.
#     779 _update_bounds_encoding(variables)
# --> 781 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     783 # Remove attrs from bounds variables (issue #2921)
#     784 for var in new_vars.values():
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/conventions.py:188, in encode_cf_variable(var, needs_copy, name)
#     176 ensure_not_multiindex(var, name=name)
#     178 for coder in [
#     179     times.CFDatetimeCoder(),
#     180     times.CFTimedeltaCoder(),
#    (...)
#     186     variables.BooleanCoder(),
#     187 ]:
# --> 188     var = coder.encode(var, name=name)
#     190 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     191 var = ensure_dtype_not_object(var, name=name)
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/coding/times.py:809, in CFDatetimeCoder.encode(self, variable, name)
#     807 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     808     if np.issubdtype(
# --> 809         variable.data.dtype, np.datetime64
#     810     ) or contains_cftime_datetimes(variable):
#     811         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     813         units = encoding.pop("units", None)
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/variable.py:416, in Variable.data(self)
#     414     return self._data
#     415 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 416     return self._data.get_duck_array()
#     417 else:
#     418     return self.values
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/indexing.py:699, in MemoryCachedArray.get_duck_array(self)
#     698 def get_duck_array(self):
# --> 699     self._ensure_cached()
#     700     return self.array.get_duck_array()
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/indexing.py:693, in MemoryCachedArray._ensure_cached(self)
#     692 def _ensure_cached(self):
# --> 693     self.array = as_indexable(self.array.get_duck_array())
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/indexing.py:667, in CopyOnWriteArray.get_duck_array(self)
#     666 def get_duck_array(self):
# --> 667     return self.array.get_duck_array()
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/indexing.py:554, in LazilyIndexedArray.get_duck_array(self)
#     553 def get_duck_array(self):
# --> 554     array = self.array[self.key]
#     555     # self.array[self.key] is now a numpy array when
#     556     # self.array is a BackendArray subclass
#     557     # and self.key is BasicIndexer((slice(None, None, None),))
#     558     # so we need the explicit check for ExplicitlyIndexed
#     559     if isinstance(array, ExplicitlyIndexed):
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/utils/xarrayengine.py:38, in EarthkitBackendArray.__getitem__(self, key)
#      34 indexing_support = indexing.IndexingSupport.BASIC
#      35 raw_key, numpy_indices = indexing.decompose_indexer(
#      36     key, self.shape, indexing_support
#      37 )
# ---> 38 result = self._raw_indexing_method(raw_key.tuple)
#      39 if numpy_indices.tuple:
#      40     # index the loaded np.ndarray
#      41     result = indexing.NdArrayLikeIndexingAdapter(result)[numpy_indices]
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/utils/xarrayengine.py:55, in EarthkitBackendArray._raw_indexing_method(self, key)
#      52 def _raw_indexing_method(self, key: tuple):
#      53     # must be threadsafe
#      54     isels = dict(zip(self.dims, key))
# ---> 55     result = self.ekds.isel(**isels).to_numpy()
#      56     print(f"Loaded {self.xp.__name__} with shape: {result.shape}")
#      58     # Loading as numpy but then converting. This needs to be changed upstream (eccodes)
#      59     # to load directly into cupy.
#      60     # Maybe some incompatibilities when trying to copy from FFI to cupy directly
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/indexing/tensor.py:190, in TensorCore.isel(self, remapping, *args, **kwargs)
#     187 indexes = tuple(indexes)
#     188 # print(f"{indexes=}")
# --> 190 return self._subset(indexes)
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/indexing/tensor.py:349, in FieldListTensor._subset(self, indexes)
#     347 coords = self._subset_coords(indexes)
#     348 ds = self.source[tuple(dataset_indexes)]
# --> 349 return self.from_tensor(self, ds, coords)
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/indexing/tensor.py:265, in FieldListTensor.from_tensor(cls, owner, source, coords)
#     262 else:
#     263     user_shape = tuple(user_shape)
# --> 265 return cls(source, coords, user_shape, field_shape, flatten_values)
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/indexing/tensor.py:244, in FieldListTensor.__init__(self, source, coords, user_shape, field_shape, flatten_values)
#     241 self.flatten_values = flatten_values
#     243 # consistency check
# --> 244 self._check()
#     246 if len(self.source) != math.prod(self._user_shape):
#     247     raise ValueError(
#     248         (
#     249             f"user shape={self._user_shape} does not match number of available "
#     250             f"fields={len(self.source)}"
#     251         )
#     252     )
#
# File ~/Work/Git_Repositories/EARTHKIT/earthkit-data/earthkit/data/indexing/tensor.py:221, in TensorCore._check(self)
#     219 s = tuple(len(v) for _, v in self._coords.items())
#     220 if s != self._shape:
# --> 221     raise ValueError(
#     222         f"shape={self._shape} does not match shape deduced from coords={s}"
#     223     )
#
# ValueError: shape=([6], 7, 12) does not match shape deduced from coords=(6, 7, 12)

# %%
fs_xr.t._data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/edwardcomyn-platt/Work/Git_Repositories/EARTHKIT/earthkit-data/docs/examples/grib_to_xarray.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> fs_xr.t._data
#
# File ~/miniconda3/envs/earthkit/lib/python3.11/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'DataArray' object has no attribute '_data'

# %%
try:
    from netCDF4 import Dataset
    r = Dataset("_tuv_pl.nc", "r")
    print(r.dimensions)
except ImportError:
    pass
# Out:
# {'isobaricInhPa': <class 'netCDF4._netCDF4.Dimension'>: name = 'isobaricInhPa', size = 6, 'latitude': <class 'netCDF4._netCDF4.Dimension'>: name = 'latitude', size = 7, 'longitude': <class 'netCDF4._netCDF4.Dimension'>: name = 'longitude', size = 12}

# %%
from earthkit import aggregate
