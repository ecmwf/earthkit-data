# %% [markdown]
# ## Converting GRIB to NetCDF

# %%
import xarray as xr

ds = xr.open_dataset('tuv_pl.grib', engine='earthkit') #, engine='earthkit')'cfgrib'
ds.t  # .to_netcdf('temp.nc')
# Out:
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)> Size: 2kB
# [504 values with dtype=float32]
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     param:     t
#     metadata:  ('grib_handle', 'tuv_pl.grib', 3600)

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys=[]) #, engine='earthkit')'cfgrib'
ds.t
# Out:
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)> Size: 2kB
# [504 values with dtype=float32]
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     param:     t
#     metadata:  ('grib_handle', 'tuv_pl.grib', 3600)

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys=["shortName"]) #, engine='earthkit')'cfgrib'
ds.t
# Out:
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)> Size: 2kB
# [504 values with dtype=float32]
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     param:      t
#     shortName:  t
#     metadata:   ('grib_handle', 'tuv_pl.grib', 3600)

# %%
ds = xr.open_dataset('tuv_pl.grib', engine='earthkit', variable_metadata_keys="describe") # 'CF'
ds.t
# Out:
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)> Size: 2kB
# [504 values with dtype=float32]
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     param:      t
#     shortName:  t
#     paramId:    130
#     metadata:   ('grib_handle', 'tuv_pl.grib', 3600)

# %%
from earthkit.data import from_object
ek_xr = from_object(ds.t)
ek_xr
# Out:
# XArrayFieldList

# %%
ds
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:    (levelist: 6, latitude: 7, longitude: 12)
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Data variables:
#     t          (levelist, latitude, longitude) float32 2kB ...
#     u          (levelist, latitude, longitude) float32 2kB ...
#     v          (levelist, latitude, longitude) float32 2kB ...
# Attributes: (12/17)
#     class:                    od
#     stream:                   oper
#     levtype:                  pl
#     type:                     an
#     expver:                   0001
#     date:                     20180801
#     ...                       ...
#     typeOfLevel:              isobaricInhPa
#     marsClass:                od
#     marsStream:               oper
#     marsType:                 an
#     experimentVersionNumber:  0001
#     ekds_source:              tuv_pl.grib

# %%
import earthkit.data
earthkit.data.download_example_file("tuv_pl.grib")

# %%
fs = earthkit.data.from_source("file", "tuv_pl.grib")
print(fs)
# Out:
# GRIBReader(tuv_pl.grib)

# %%
fs_xr = fs.to_xarray(variable_metadata_keys=[])
fs_xr
# Out:
# kwargs={'variable_metadata_keys': []}
# xarray_open_dataset_kwargs={'engine': 'earthkit'}
# index_keys ['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# profile index_keys=['param', 'class', 'stream', 'levtype', 'type', 'expver', 'date', 'hdate', 'andate', 'time', 'antime', 'step', 'reference', 'anoffset', 'verify', 'fcmonth', 'fcperiod', 'leadtime', 'opttime', 'origin', 'domain', 'method', 'diagnostic', 'iteration', 'number', 'quantile', 'levelist', 'md5GridSection']
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# Finding coords in dataset for ('levelist',):   0%|          | 0.00/6.00 [00:00<?, ?B/s]
# <xarray.Dataset> Size: 6kB
# Dimensions:    (levelist: 6, latitude: 7, longitude: 12)
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Data variables:
#     t          (levelist, latitude, longitude) float32 2kB ...
#     u          (levelist, latitude, longitude) float32 2kB ...
#     v          (levelist, latitude, longitude) float32 2kB ...
# Attributes:
#     class:           od
#     stream:          oper
#     levtype:         pl
#     type:            an
#     expver:          0001
#     date:            20180801
#     time:            1200
#     step:            0
#     domain:          g
#     number:          0
#     md5GridSection:  e09e4d6171c0ac85da1d256b2f8acf88
#     ekds_source:     tuv_pl.grib

# %%
fs_xr.t
# Out:
# <xarray.DataArray 't' (levelist: 6, latitude: 7, longitude: 12)> Size: 2kB
# [504 values with dtype=float32]
# Coordinates:
#   * levelist   (levelist) int64 48B 300 400 500 700 850 1000
#   * latitude   (latitude) float64 56B 90.0 60.0 30.0 0.0 -30.0 -60.0 -90.0
#   * longitude  (longitude) float64 96B 0.0 30.0 60.0 90.0 ... 270.0 300.0 330.0
# Attributes:
#     param:     t
#     metadata:  ('grib_handle', 'tuv_pl.grib', 3600)

# %%
# dir(fs_xr.t.attrs['metadata'])
# fs_xr.t.attrs['metadata']._handle
# for k in fs_xr.t.attrs['metadata'].keys():
#     print(k)
fsm = fs.metadata()[0]
fsm.describe_keys()
# Out:
# ['shortName',
#  'typeOfLevel',
#  'level',
#  'date',
#  'time',
#  'step',
#  'number',
#  'paramId',
#  'marsClass',
#  'marsStream',
#  'marsType',
#  'experimentVersionNumber']

# %%
fs_xr.to_netcdf('_tuv_pl.nc')
# Out:
# dims: ['levelist', 'latitude', 'longitude'] key: (slice(None, None, None), slice(None, None, None), slice(None, None, None)) shape: (6, 7, 12)
# indexes=[slice(None, None, None)] user_shape=self.user_shape=(6,)
# dims: ['levelist', 'latitude', 'longitude'] key: (slice(None, None, None), slice(None, None, None), slice(None, None, None)) shape: (6, 7, 12)
# indexes=[slice(None, None, None)] user_shape=self.user_shape=(6,)
# dims: ['levelist', 'latitude', 'longitude'] key: (slice(None, None, None), slice(None, None, None), slice(None, None, None)) shape: (6, 7, 12)
# indexes=[slice(None, None, None)] user_shape=self.user_shape=(6,)

# %%
# fs_xr.t._data

# %%
# try:
#     from netCDF4 import Dataset
#     r = Dataset("_tuv_pl.nc", "r")
#     print(r.dimensions)
# except ImportError:
#     pass

# %%
#from earthkit import aggregate
