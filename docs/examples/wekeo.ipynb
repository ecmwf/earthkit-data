# %% [markdown]
# ## Retieving data from WEkEO

# %% [raw]
# The :ref:`wekeo <data-sources-wekeo>` and :ref:`wekeocds <data-sources-wekeocds>` sources provide access to `WEkEO <https://www.wekeo.eu/>`_.

# %% [markdown]
# #### Using the WEkEO grammar

# %% [raw]
# When we want access data using the WEkEO grammar (see the `hda <https://hda.readthedocs.io/>`_ documentation) we need to use the :ref:`wekeo <data-sources-wekeo>` source. The following example retrieves Normalized Difference Vegetation Index data derived from EO satellite imagery in NetCDF format:

# %%
import earthkit.data as ekd

ds = ekd.from_source(
        "wekeo",
        "EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF",
        request={
            "dataset_id": "EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF",
            "startdate": "2019-01-01T00:00:00.000Z",
            "enddate": "2019-01-01T23:59:59.999Z",
        }
    )

ds.to_xarray()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import earthkit.data as ekd
# ----> 3 ds = ekd.from_source(
#       4         "wekeo",
#       5         "EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF",
#       6         request={
#       7             "dataset_id": "EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF",
#       8             "startdate": "2019-01-01T00:00:00.000Z",
#       9             "enddate": "2019-01-01T23:59:59.999Z",
#      10         }
#      11     )
#      13 ds.to_xarray()
#
# File ~/git/earthkit-data/src/earthkit/data/sources/__init__.py:116, in from_source(name, lazily, *args, **kwargs)
#     113 if lazily:
#     114     return from_source_lazily(name, *args, **kwargs)
# --> 116 src = from_source_internal(name, *args, **kwargs)
#     118 if hasattr(src, "to_data_object"):
#     119     data = src.to_data_object()
#
# File ~/git/earthkit-data/src/earthkit/data/sources/__init__.py:131, in from_source_internal(name, lazily, *args, **kwargs)
#     128     return from_source_lazily(name, *args, **kwargs)
#     130 prev = None
# --> 131 src = get_source(name, *args, **kwargs)
#     132 while src is not prev:
#     133     prev = src
#
# File ~/git/earthkit-data/src/earthkit/data/sources/__init__.py:98, in SourceMaker.__call__(self, name, *args, **kwargs)
#      95     klass = find_plugin(os.path.dirname(__file__), name, loader)
#      96     self.SOURCES[name] = klass
# ---> 98 source = klass(*args, **kwargs)
#     100 if getattr(source, "name", None) is None:
#     101     source.name = name
#
# File ~/git/earthkit-data/src/earthkit/data/sources/wekeo.py:102, in WekeoRetriever.__init__(self, dataset, request, prompt, *args, **kwargs)
#     100 # Download each request in parallel when the config allows it
#     101 retriever = FileRequestRetriever(self, retriever=self._retrieve_one)
# --> 102 self.path = retriever.retrieve(self.request, dataset)
#
# File ~/git/earthkit-data/src/earthkit/data/utils/request.py:138, in FileRequestRetriever.retrieve(self, requests, *extra_args)
#     135 nthreads = min(CONFIG.get("number-of-download-threads"), len(requests))
#     137 if nthreads < 2:
# --> 138     path = [self.retriever(r, *extra_args) for r in requests]
#     139 else:
#     140     from earthkit.data.utils.progbar import tqdm
#
# File ~/git/earthkit-data/src/earthkit/data/sources/wekeo.py:128, in WekeoRetriever._retrieve_one(self, request, dataset)
#     125 def retrieve(target, args):
#     126     self.client(self.prompt).retrieve(args[0], args[1], target)
# --> 128 return self.cache_file(
#     129     retrieve,
#     130     (dataset, request),
#     131     extension=EXTENSIONS.get(request.get("format"), ".cache"),
#     132 )
#
# File ~/git/earthkit-data/src/earthkit/data/sources/__init__.py:37, in Source.cache_file(self, create, args, **kwargs)
#      34 if owner is None:
#      35     owner = re.sub(r"(?!^)([A-Z]+)", r"-\1", self.__class__.__name__).lower()
# ---> 37 return cache_file(owner, create, args, **kwargs)
#
# File ~/git/earthkit-data/src/earthkit/data/core/caching.py:1050, in cache_file(owner, create, args, hash_extra, extension, force, replace)
#    1048 with FileLock(lock):
#    1049     if not os.path.exists(path):  # Check again, another thread/process may have created the file
# -> 1050         owner_data = create(path + ".tmp", args)
#    1051         os.rename(path + ".tmp", path)
#    1052         CACHE._update_entry(path, owner_data)
#
# File ~/git/earthkit-data/src/earthkit/data/sources/wekeo.py:126, in WekeoRetriever._retrieve_one.<locals>.retrieve(target, args)
#     125 def retrieve(target, args):
# --> 126     self.client(self.prompt).retrieve(args[0], args[1], target)
#
# File ~/git/earthkit-data/src/earthkit/data/sources/wekeo.py:68, in ApiClient.retrieve(self, name, request, target)
#      67 def retrieve(self, name, request, target=None):
# ---> 68     matches = self.search(request["request"])
#      69     out = []
#      70     for result in matches.results:
#
# File ~/venv/dev/lib/python3.13/site-packages/hda/api.py:629, in Client.search(self, query, limit)
#     627 query = convert(query)
#     628 assert "dataset_id" in query, "Missing dataset_id, check your query"
# --> 629 self.accept_tac(query["dataset_id"])
#     630 results = SearchPaginator(self.post).run(query=query, limit=limit)
#     631 return SearchResults(self, list(results), query["dataset_id"])
#
# File ~/venv/dev/lib/python3.13/site-packages/hda/api.py:526, in Client.accept_tac(self, dataset_id)
#     524 def accept_tac(self, dataset_id):
#     525     """Implicitly accept the terms and conditions of the service."""
# --> 526     result = self.dataset(dataset_id)
#     527     tacs = result["terms"]
#     528     for tac in tacs:
#
# File ~/venv/dev/lib/python3.13/site-packages/hda/api.py:651, in Client.dataset(self, dataset_id)
#     644 def dataset(self, dataset_id):
#     645     """Returns a JSON object that includes the abstract,
#     646     the datasetId and other properties of the given dataset.
#     647
#     648     :param dataset_id: The dataset ID
#     649     :type dataset_id: str
#     650     """
# --> 651     return self.get("datasets", dataset_id)
#
# File ~/venv/dev/lib/python3.13/site-packages/hda/api.py:679, in Client.get(self, *args, **kwargs)
#     674 logger.debug("===> GET %s", full)
#     676 r = self.robust(self.session.get)(
#     677     full, params=kwargs, verify=self.config.verify, timeout=self.timeout
#     678 )
# --> 679 r.raise_for_status()
#     680 result = r.json()
#     681 logger.debug("<=== %s", shorten(result))
#
# File ~/venv/dev/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://gateway.prod.wekeo2.eu/hda-broker/api/v1/datasets/EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF

# %% [markdown]
# ####  Using the CDSAPI grammar

# %% [raw]
# We can use the :ref:`wekeocds <data-sources-wekeocds>` source to access `Copernicus Climate Data Store (CDS) <https://cds.climate.copernicus.eu>`_ datasets served on `WEkEO <https://www.wekeo.eu/>`_ using the `cdsapi <https://pypi.org/project/cdsapi>`_ standard grammar.

# %% [markdown]
# The following example retrieves ERA5 surface data in GRIB format:

# %%
ds = ekd.from_source(
    "wekeocds",
    "EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS",
    request=dict(
        variable=["2m_temperature", "mean_sea_level_pressure"],
        product_type=["monthly_averaged_reanalysis_by_hour_of_day"],
        year="2012",
        month="12",
        time="12:00",
        data_format="grib",
        download_format="zip",
    ),
)

ds.fieldlist().ls()
