# %%
# !test -f test6.grib || wget https://github.com/ecmwf/emohawk/raw/main/docs/examples/test6.grib

# %% [markdown]
# ## Inspecting GRIB contents

# %% [markdown]
# We load a GRIB file containing 6 messages:

# %%
import emohawk

fs = emohawk.load_from("file", "test6.grib")

# %% [markdown]
# ### Using ls()

# %%
fs.ls()
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType
# 0       an       0  regular_ll
# 1       an       0  regular_ll
# 2       an       0  regular_ll
# 3       an       0  regular_ll
# 4       an       0  regular_ll
# 5       an       0  regular_ll

# %% [markdown]
# We can add extra keys:

# %%
fs.ls(extra_keys=["paramId"])
# Out:
#   centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf         t  isobaricInhPa   1000  20180801      1200         0
# 1   ecmf         u  isobaricInhPa   1000  20180801      1200         0
# 2   ecmf         v  isobaricInhPa   1000  20180801      1200         0
# 3   ecmf         t  isobaricInhPa    850  20180801      1200         0
# 4   ecmf         u  isobaricInhPa    850  20180801      1200         0
# 5   ecmf         v  isobaricInhPa    850  20180801      1200         0
#
#   dataType  number    gridType  paramId
# 0       an       0  regular_ll      130
# 1       an       0  regular_ll      131
# 2       an       0  regular_ll      132
# 3       an       0  regular_ll      130
# 4       an       0  regular_ll      131
# 5       an       0  regular_ll      132

# %% [markdown]
# ### Using describe

# %% [markdown]
# We can describe the whole object:

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_639c8 th {
#   text-align: left;
# }
# #T_639c8_row0_col0, #T_639c8_row0_col1, #T_639c8_row0_col2, #T_639c8_row0_col3, #T_639c8_row0_col4, #T_639c8_row0_col5, #T_639c8_row0_col6, #T_639c8_row0_col7, #T_639c8_row0_col8, #T_639c8_row1_col0, #T_639c8_row1_col1, #T_639c8_row1_col2, #T_639c8_row1_col3, #T_639c8_row1_col4, #T_639c8_row1_col5, #T_639c8_row1_col6, #T_639c8_row1_col7, #T_639c8_row1_col8, #T_639c8_row2_col0, #T_639c8_row2_col1, #T_639c8_row2_col2, #T_639c8_row2_col3, #T_639c8_row2_col4, #T_639c8_row2_col5, #T_639c8_row2_col6, #T_639c8_row2_col7, #T_639c8_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_639c8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_639c8_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_639c8_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_639c8_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_639c8_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_639c8_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_639c8_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_639c8_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_639c8_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_639c8_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_639c8_level0_row0" class="row_heading level0 row0" >t</th>
#       <th id="T_639c8_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_639c8_row0_col0" class="data row0 col0" >1000,850</td>
#       <td id="T_639c8_row0_col1" class="data row0 col1" >20180801</td>
#       <td id="T_639c8_row0_col2" class="data row0 col2" >1200</td>
#       <td id="T_639c8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_639c8_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_639c8_row0_col5" class="data row0 col5" >od</td>
#       <td id="T_639c8_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_639c8_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_639c8_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_639c8_level0_row1" class="row_heading level0 row1" >u</th>
#       <th id="T_639c8_level1_row1" class="row_heading level1 row1" >isobaricInhPa</th>
#       <td id="T_639c8_row1_col0" class="data row1 col0" >1000,850</td>
#       <td id="T_639c8_row1_col1" class="data row1 col1" >20180801</td>
#       <td id="T_639c8_row1_col2" class="data row1 col2" >1200</td>
#       <td id="T_639c8_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_639c8_row1_col4" class="data row1 col4" >131</td>
#       <td id="T_639c8_row1_col5" class="data row1 col5" >od</td>
#       <td id="T_639c8_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_639c8_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_639c8_row1_col8" class="data row1 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_639c8_level0_row2" class="row_heading level0 row2" >v</th>
#       <th id="T_639c8_level1_row2" class="row_heading level1 row2" >isobaricInhPa</th>
#       <td id="T_639c8_row2_col0" class="data row2 col0" >1000,850</td>
#       <td id="T_639c8_row2_col1" class="data row2 col1" >20180801</td>
#       <td id="T_639c8_row2_col2" class="data row2 col2" >1200</td>
#       <td id="T_639c8_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_639c8_row2_col4" class="data row2 col4" >132</td>
#       <td id="T_639c8_row2_col5" class="data row2 col5" >od</td>
#       <td id="T_639c8_row2_col6" class="data row2 col6" >oper</td>
#       <td id="T_639c8_row2_col7" class="data row2 col7" >an</td>
#       <td id="T_639c8_row2_col8" class="data row2 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can also describe a given parameter (defined by shortName or paramId):

# %%
fs.describe("t")
# Out:
# <style type="text/css">
# #T_e0f4d th {
#   text-align: left;
# }
# #T_e0f4d_row0_col0, #T_e0f4d_row1_col0, #T_e0f4d_row2_col0, #T_e0f4d_row3_col0, #T_e0f4d_row4_col0, #T_e0f4d_row5_col0, #T_e0f4d_row6_col0, #T_e0f4d_row7_col0, #T_e0f4d_row8_col0, #T_e0f4d_row9_col0, #T_e0f4d_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_e0f4d">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0f4d_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_e0f4d_row0_col0" class="data row0 col0" >t</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_e0f4d_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_e0f4d_row2_col0" class="data row2 col0" >1000,850</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_e0f4d_row3_col0" class="data row3 col0" >20180801</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_e0f4d_row4_col0" class="data row4 col0" >1200</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row5" class="row_heading level0 row5" >step</th>
#       <td id="T_e0f4d_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row6" class="row_heading level0 row6" >paramId</th>
#       <td id="T_e0f4d_row6_col0" class="data row6 col0" >130</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_e0f4d_row7_col0" class="data row7 col0" >od</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row8" class="row_heading level0 row8" >stream</th>
#       <td id="T_e0f4d_row8_col0" class="data row8 col0" >oper</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row9" class="row_heading level0 row9" >type</th>
#       <td id="T_e0f4d_row9_col0" class="data row9 col0" >an</td>
#     </tr>
#     <tr>
#       <th id="T_e0f4d_level0_row10" class="row_heading level0 row10" >experimentVersionNumber</th>
#       <td id="T_e0f4d_row10_col0" class="data row10 col0" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %%
fs.describe(131)
# Out:
# <style type="text/css">
# #T_449bd th {
#   text-align: left;
# }
# #T_449bd_row0_col0, #T_449bd_row1_col0, #T_449bd_row2_col0, #T_449bd_row3_col0, #T_449bd_row4_col0, #T_449bd_row5_col0, #T_449bd_row6_col0, #T_449bd_row7_col0, #T_449bd_row8_col0, #T_449bd_row9_col0, #T_449bd_row10_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_449bd">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_449bd_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_449bd_row0_col0" class="data row0 col0" >u</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_449bd_row1_col0" class="data row1 col0" >isobaricInhPa</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_449bd_row2_col0" class="data row2 col0" >1000,850</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_449bd_row3_col0" class="data row3 col0" >20180801</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_449bd_row4_col0" class="data row4 col0" >1200</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row5" class="row_heading level0 row5" >step</th>
#       <td id="T_449bd_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row6" class="row_heading level0 row6" >paramId</th>
#       <td id="T_449bd_row6_col0" class="data row6 col0" >131</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_449bd_row7_col0" class="data row7 col0" >od</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row8" class="row_heading level0 row8" >stream</th>
#       <td id="T_449bd_row8_col0" class="data row8 col0" >oper</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row9" class="row_heading level0 row9" >type</th>
#       <td id="T_449bd_row9_col0" class="data row9 col0" >an</td>
#     </tr>
#     <tr>
#       <th id="T_449bd_level0_row10" class="row_heading level0 row10" >experimentVersionNumber</th>
#       <td id="T_449bd_row10_col0" class="data row10 col0" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting individual field metadata

# %%
fs[0].as_mars()
# Out:
# {'domain': 'g',
#  'levtype': 'pl',
#  'levelist': 1000,
#  'date': 20180801,
#  'time': 1200,
#  'step': 0,
#  'param': 't',
#  'class': 'od',
#  'type': 'an',
#  'stream': 'oper',
#  'expver': '0001'}

# %%
fs[0].metadata(namespace="mars")
# Out:
# {'domain': 'g',
#  'levtype': 'pl',
#  'levelist': 1000,
#  'date': 20180801,
#  'time': 1200,
#  'step': 0,
#  'param': 't',
#  'class': 'od',
#  'type': 'an',
#  'stream': 'oper',
#  'expver': '0001'}

# %% [markdown]
# ### Inspecting all the namespace keys for a message

# %% [markdown]
# info() gives a tabbed interface to inspect the various namespaces:

# %%
fs[0].info()
# Out:
# <style type="text/css"> /* Based on:
#  https://codepen.io/htmlcssfreebies/pen/WNpVeRK
#  https://github.com/pydata/xarray/blob/main/xarray/static/css/style.css
#  */
#
#  :root {
#     --eh-font-color0: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#     --eh-font-color2: var(--jp-content-font-color2, rgba(0, 0, 0, 0.54));
#     --eh-font-color3: var(--jp-content-font-color3, rgba(0, 0, 0, 0.38));
#     --eh-border-color: var(--jp-border-color2, #e0e0e0);
#     --eh-disabled-color: var(--jp-layout-color3, #bdbdbd);
#     --eh-background-color: var(--jp-layout-color0, white);
#   }
#
# html[theme=dark],
# body[data-theme=dark],
# body.vscode-dark {
#   --eh-font-color0: rgba(255, 255, 255, 1);
#   --eh-font-color2: rgba(255, 255, 255, 0.54);
#   --eh-font-color3: rgba(255, 255, 255, 0.38);
#   --eh-border-color: #1F1F1F;
#   --eh-disabled-color: #515151;
#   --eh-background-color: #111111;
# }
#
#  /* Reset */
#  *,
#  *::before,
#  *::after {
#      box-sizing: border-box;
#  }
#
#  .eh-description {
#     color: var(--eh-font-color2);
#  }
#
#  .eh-section {
#     padding-left: 0px;
#  }
#
#  /* Tabs Container */
#  .eh-tabs-container {
#      padding: 0px;
#  }
#
#  /* Tabs Block */
#  .eh-tabs-block {
#      display: flex;
#      align-items: center;
#      justify-content: center;
#      padding-top: 4px;
#  }
#
#  /* Tabs */
#  .eh-tabs {
#      display: flex;
#      flex-wrap: wrap;
#      width: 100%;
#  }
#
#  .eh-tabs label {
#      width: 100%;
#      display: flex;
#      align-items: center;
#      justify-content: center;
#      padding-left: 6px;
#      padding-right: 6px;
#      font-weight: 400;
#      cursor: pointer;
#      color: var(--eh-font-color2);
#      background-color: var(--eh-background-color);
#      border-top: 1px solid var(--eh-background-color);
#      border-bottom: 1px solid var(--eh-disabled-color);
#  }
#
#  /* Tab page contents */
#  .eh-tabs .tab {
#      flex-grow: 1;
#      width: 100%;
#      height: 100%;
#      display: none;
#      padding: 2px 2px;
#  }
#
#  .eh-tabs [type=radio] {
#      display: none;
#  }
#
#  .eh-tabs [type=radio]:checked + label {
#      font-weight: 500;
#      color: var(--eh-font-color0);
#      border: 1px solid var(--eh-disabled-color);
#  }
#
#  .eh-tabs [type=radio]:checked + label + .tab {
#      display: block;
#  }
#
#  .eh-tabs [type=radio]:not(:checked) + label:hover {
#     color: var(--xr-font-color0);
#  }
#
#
#  @media (min-width: 768px) {
#
#      .eh-tabs-container {
#          padding: 1rem 1rem;
#      }
#
#      .eh-tabs label {
#          order: 1;
#          width: auto;
#      }
#
#      .eh-tabs .tab {
#          order: 9;
#      }
#
#      .eh-tabs [type=radio]:checked + label {
#          border-bottom: none;
#      }
#  }
#  @media (min-width: 992px) {
#
#      .eh-tabs {
#          width: 800px;
#      }
#  }</style><div class="eh-description">GribField</div>
# <div>
# <section class="eh-section>
# <div class="eh-tabs-container">
# <div class="eh-tabs-block">
# <div class="eh-tabs">
#
# <input type="radio" name="eh-tabs" id="8c791302-4515-4f09-83e0-44f75a69808e"  />
# <label for="8c791302-4515-4f09-83e0-44f75a69808e" title="Keys in the ecCodes ls namespace">ls</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>edition</b></td><td>1</td></tr> <tr><td><b>centre</b></td><td>ecmf</td></tr> <tr><td><b>typeOfLevel</b></td><td>isobaricInhPa</td></tr> <tr><td><b>level</b></td><td>1000</td></tr> <tr><td><b>dataDate</b></td><td>20180801</td></tr> <tr><td><b>stepRange</b></td><td>0</td></tr> <tr><td><b>dataType</b></td><td>an</td></tr> <tr><td><b>shortName</b></td><td>t</td></tr> <tr><td><b>packingType</b></td><td>grid_simple</td></tr> <tr><td><b>gridType</b></td><td>regular_ll</td></tr>
# </table>
# </div>
#
# <input type="radio" name="eh-tabs" id="8b25cd32-e650-4ab5-b2e0-d9e885de6836"  />
# <label for="8b25cd32-e650-4ab5-b2e0-d9e885de6836" title="Keys in the ecCodes geography namespace">geography</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>bitmapPresent</b></td><td>0</td></tr> <tr><td><b>latitudeOfFirstGridPointInDegrees</b></td><td>90.0</td></tr> <tr><td><b>longitudeOfFirstGridPointInDegrees</b></td><td>0.0</td></tr> <tr><td><b>latitudeOfLastGridPointInDegrees</b></td><td>-90.0</td></tr> <tr><td><b>longitudeOfLastGridPointInDegrees</b></td><td>330.0</td></tr> <tr><td><b>iScansNegatively</b></td><td>0</td></tr> <tr><td><b>jScansPositively</b></td><td>0</td></tr> <tr><td><b>jPointsAreConsecutive</b></td><td>0</td></tr> <tr><td><b>jDirectionIncrementInDegrees</b></td><td>30.0</td></tr> <tr><td><b>iDirectionIncrementInDegrees</b></td><td>30.0</td></tr> <tr><td><b>gridType</b></td><td>regular_ll</td></tr>
# </table>
# </div>
#
# <input type="radio" name="eh-tabs" id="d1f7ca07-593a-45f8-a2d8-ab7d0908202d"  />
# <label for="d1f7ca07-593a-45f8-a2d8-ab7d0908202d" title="Keys in the ecCodes mars namespace">mars</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>domain</b></td><td>g</td></tr> <tr><td><b>levtype</b></td><td>pl</td></tr> <tr><td><b>levelist</b></td><td>1000</td></tr> <tr><td><b>date</b></td><td>20180801</td></tr> <tr><td><b>time</b></td><td>1200</td></tr> <tr><td><b>step</b></td><td>0</td></tr> <tr><td><b>param</b></td><td>t</td></tr> <tr><td><b>class</b></td><td>od</td></tr> <tr><td><b>type</b></td><td>an</td></tr> <tr><td><b>stream</b></td><td>oper</td></tr> <tr><td><b>expver</b></td><td>0001</td></tr>
# </table>
# </div>
#
# <input type="radio" name="eh-tabs" id="f36a9746-80bb-4352-bca9-5634013872ca" checked />
# <label for="f36a9746-80bb-4352-bca9-5634013872ca" title="Keys in the ecCodes parameter namespace">parameter</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>centre</b></td><td>ecmf</td></tr> <tr><td><b>paramId</b></td><td>130</td></tr> <tr><td><b>units</b></td><td>K</td></tr> <tr><td><b>name</b></td><td>Temperature</td></tr> <tr><td><b>shortName</b></td><td>t</td></tr>
# </table>
# </div>
#
# <input type="radio" name="eh-tabs" id="89985d89-3f15-463d-87a7-e03951abdb7a"  />
# <label for="89985d89-3f15-463d-87a7-e03951abdb7a" title="Keys in the ecCodes time namespace">time</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>dataDate</b></td><td>20180801</td></tr> <tr><td><b>dataTime</b></td><td>1200</td></tr> <tr><td><b>stepUnits</b></td><td>1</td></tr> <tr><td><b>stepType</b></td><td>instant</td></tr> <tr><td><b>stepRange</b></td><td>0</td></tr> <tr><td><b>startStep</b></td><td>0</td></tr> <tr><td><b>endStep</b></td><td>0</td></tr> <tr><td><b>validityDate</b></td><td>20180801</td></tr> <tr><td><b>validityTime</b></td><td>1200</td></tr>
# </table>
# </div>
#
# <input type="radio" name="eh-tabs" id="4b7e27a6-be8e-4167-a9f4-cae23e7a495f"  />
# <label for="4b7e27a6-be8e-4167-a9f4-cae23e7a495f" title="Keys in the ecCodes vertical namespace">vertical</label>
# <div class="tab">
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>typeOfLevel</b></td><td>isobaricInhPa</td></tr> <tr><td><b>level</b></td><td>1000</td></tr>
# </table>
# </div>
#
# </div>
# </div>
# </div>
# </section>
# </div>

# %% [markdown]
# For performance reasons the "statistics" namespace has to be accessed separately:

# %%
fs[1].info(namespace="statistics")
# Out:
# <style type="text/css">table.eh td {
#     vertical-align: top;
#     text-align: left !important;
# }
# </style>
# <table class="eh-table">
# <tr><td><b>max</b></td><td>17.713119506835938</td></tr> <tr><td><b>min</b></td><td>-6.2868804931640625</td></tr> <tr><td><b>avg</b></td><td>-0.38211858840215773</td></tr> <tr><td><b>sd</b></td><td>5.60531008364273</td></tr> <tr><td><b>skew</b></td><td>1.1390041721633803</td></tr> <tr><td><b>kurt</b></td><td>1.0187797684130695</td></tr> <tr><td><b>const</b></td><td>0.0</td></tr>
# </table>

# %% [markdown]
# HTML formatting can be switched off:

# %%
fs[1].info(namespace="mars", html=False)
# Out:
# {'mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 1000,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 'u',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'}}
