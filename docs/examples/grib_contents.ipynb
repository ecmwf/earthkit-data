# %% [markdown]
# ## GRIB: listing contents

# %% [raw]
# We will work with a GRIB file containing 6 messages. First we ensure the example file is available, then read the file with :ref:`from_source() <data-sources-file>`.

# %%
import earthkit.data as ekd
ekd.download_example_file("test6.grib")
# Out:
# /Users/cgr/venv/dev/lib/python3.13/site-packages/array_api_compat/torch/_info.py:361: UserWarning: 'mkldnn' is no longer used as device type. So torch.device('mkldnn') will be deprecated and removed in the future. Please use other valid device types instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/c10/core/Device.cpp:42.)
#   a = torch.empty((0,), device=torch.device(device_name, index=i))

# %%
ds = ekd.from_source("file", "test6.grib")

# %% [markdown]
# ### Using head(), tail() and ls()

# %% [raw]
# All these methods (:py:meth:`~data.readers.grib.index.GribFieldList.head`, :py:meth:`~data.readers.grib.index.GribFieldList.tail` and :py:meth:`~data.readers.grib.index.GribFieldList.ls`) take the same set of keyword arguments:
#
# - n: number of messages to list
# - keys: the metadata keys to dump
# - extra_keys: extra keys of top of the default set of keys
# - namespace: the namespace(s) to use

# %% [markdown]
# #### head()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.head` displays the first 5 messages by default:

# %%
ds.head()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll

# %% [markdown]
# The number of fields can be passed as an argument:

# %%
ds.head(2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %%
ds.head(n=2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %% [markdown]
# ##### Keys and extra keys

# %% [markdown]
# We can use our own list of keys instead of the default ones.

# %%
ds.head(keys="base_datetime")
# Out:
#         base_datetime
# 0 2018-08-01 12:00:00
# 1 2018-08-01 12:00:00
# 2 2018-08-01 12:00:00
# 3 2018-08-01 12:00:00
# 4 2018-08-01 12:00:00

# %%
ds.head(keys=["base_datetime", "level"])
# Out:
#         base_datetime  level
# 0 2018-08-01 12:00:00   1000
# 1 2018-08-01 12:00:00   1000
# 2 2018-08-01 12:00:00   1000
# 3 2018-08-01 12:00:00    850
# 4 2018-08-01 12:00:00    850

# %% [markdown]
# The default list of keys can be extended:

# %%
ds.head(extra_keys="units")
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type    units
# 0      pressure      0  regular_ll        K
# 1      pressure      0  regular_ll  m s**-1
# 2      pressure      0  regular_ll  m s**-1
# 3      pressure      0  regular_ll        K
# 4      pressure      0  regular_ll  m s**-1

# %% [markdown]
# ##### Namespaces

# %% [markdown]
# The keys can be taken from an earthkit namespace:

# %%
ds.head(namespace="time")
# Out:
#         base_datetime      valid_datetime   step
# 0 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 1 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 2 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 3 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 4 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days

# %%
ds.head(namespace=["parameter", "time"])
# Out:
#         base_datetime      valid_datetime   step variable    units
# 0 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        t        K
# 1 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        u  m s**-1
# 2 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        v  m s**-1
# 3 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        t        K
# 4 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        u  m s**-1

# %% [markdown]
# It is possible to use any [ecCodes GRIB namespace](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ):

# %%
ds.head(namespace="grib.ls")
# Out:
#    grib.edition grib.centre grib.typeOfLevel  grib.level  grib.dataDate  \
# 0             1        ecmf    isobaricInhPa        1000       20180801
# 1             1        ecmf    isobaricInhPa        1000       20180801
# 2             1        ecmf    isobaricInhPa        1000       20180801
# 3             1        ecmf    isobaricInhPa         850       20180801
# 4             1        ecmf    isobaricInhPa         850       20180801
#
#   grib.stepRange grib.dataType grib.shortName grib.packingType grib.gridType
# 0              0            an              t      grid_simple    regular_ll
# 1              0            an              u      grid_simple    regular_ll
# 2              0            an              v      grid_simple    regular_ll
# 3              0            an              t      grid_simple    regular_ll
# 4              0            an              u      grid_simple    regular_ll

# %% [markdown]
# #### tail()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.tail` displays the last 5 messages by default:

# %%
ds.tail(5)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 3        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll

# %% [markdown]
# #### ls()

# %% [raw]
# By default :py:meth:`~data.readers.grib.index.GribFieldList.ls` lists all the fields:

# %%
ds.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 5        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll
# 5      pressure      0  regular_ll

# %% [markdown]
# The number of fields to list can also be specified:

# %%
ds.ls(2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %%
ds.ls(-2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %% [markdown]
# ### Using describe

# %% [raw]
# With :py:meth:`~data.readers.grib.index.GribFieldList.describe` the contents of the fieldlist is presented in a concise way.

# %%
ds.describe()
# Out:
# <style type="text/css">
# #T_4929b th {
#   text-align: left;
# }
# </style>
# <table id="T_4929b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4929b_level0_col0" class="col_heading level0 col0" >shortName</th>
#       <th id="T_4929b_level0_col1" class="col_heading level0 col1" >typeOfLevel</th>
#       <th id="T_4929b_level0_col2" class="col_heading level0 col2" >level</th>
#       <th id="T_4929b_level0_col3" class="col_heading level0 col3" >date</th>
#       <th id="T_4929b_level0_col4" class="col_heading level0 col4" >time</th>
#       <th id="T_4929b_level0_col5" class="col_heading level0 col5" >stepRange</th>
#       <th id="T_4929b_level0_col6" class="col_heading level0 col6" >number</th>
#       <th id="T_4929b_level0_col7" class="col_heading level0 col7" >paramId</th>
#       <th id="T_4929b_level0_col8" class="col_heading level0 col8" >class</th>
#       <th id="T_4929b_level0_col9" class="col_heading level0 col9" >stream</th>
#       <th id="T_4929b_level0_col10" class="col_heading level0 col10" >type</th>
#       <th id="T_4929b_level0_col11" class="col_heading level0 col11" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.describe` can be used with a given parameter (defined by variable or paramId):

# %%
ds.describe("t")
# Out:
# <style type="text/css">
# #T_97f6b th {
#   text-align: left;
# }
# #T_97f6b_row0_col0, #T_97f6b_row1_col0, #T_97f6b_row2_col0, #T_97f6b_row3_col0, #T_97f6b_row4_col0, #T_97f6b_row5_col0, #T_97f6b_row6_col0, #T_97f6b_row7_col0, #T_97f6b_row8_col0, #T_97f6b_row9_col0, #T_97f6b_row10_col0, #T_97f6b_row11_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_97f6b">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97f6b_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_97f6b_row0_col0" class="data row0 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_97f6b_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_97f6b_row2_col0" class="data row2 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_97f6b_row3_col0" class="data row3 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_97f6b_row4_col0" class="data row4 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row5" class="row_heading level0 row5" >stepRange</th>
#       <td id="T_97f6b_row5_col0" class="data row5 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row6" class="row_heading level0 row6" >number</th>
#       <td id="T_97f6b_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row7" class="row_heading level0 row7" >paramId</th>
#       <td id="T_97f6b_row7_col0" class="data row7 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_97f6b_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row9" class="row_heading level0 row9" >stream</th>
#       <td id="T_97f6b_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row10" class="row_heading level0 row10" >type</th>
#       <td id="T_97f6b_row10_col0" class="data row10 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_97f6b_level0_row11" class="row_heading level0 row11" >experimentVersionNumber</th>
#       <td id="T_97f6b_row11_col0" class="data row11 col0" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
ds.describe(131)
# Out:
# <style type="text/css">
# #T_74128 th {
#   text-align: left;
# }
# #T_74128_row0_col0, #T_74128_row1_col0, #T_74128_row2_col0, #T_74128_row3_col0, #T_74128_row4_col0, #T_74128_row5_col0, #T_74128_row6_col0, #T_74128_row7_col0, #T_74128_row8_col0, #T_74128_row9_col0, #T_74128_row10_col0, #T_74128_row11_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_74128">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74128_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_74128_row0_col0" class="data row0 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_74128_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_74128_row2_col0" class="data row2 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_74128_row3_col0" class="data row3 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_74128_row4_col0" class="data row4 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row5" class="row_heading level0 row5" >stepRange</th>
#       <td id="T_74128_row5_col0" class="data row5 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row6" class="row_heading level0 row6" >number</th>
#       <td id="T_74128_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row7" class="row_heading level0 row7" >paramId</th>
#       <td id="T_74128_row7_col0" class="data row7 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_74128_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row9" class="row_heading level0 row9" >stream</th>
#       <td id="T_74128_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row10" class="row_heading level0 row10" >type</th>
#       <td id="T_74128_row10_col0" class="data row10 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_74128_level0_row11" class="row_heading level0 row11" >experimentVersionNumber</th>
#       <td id="T_74128_row11_col0" class="data row11 col0" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Getting namespaces

# %% [markdown]
# The field namespaces can be collected as a dict via the namespace() method:

# %%
ds[0].namespace("parameter")
# Out:
# {'variable': 't', 'units': 'K'}

# %%
ds[0].namespace(["parameter", "time"])
# Out:
# {'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'parameter': {'variable': 't', 'units': 'K'}}

# %%
ds[0].namespace()
# Out:
# {'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'parameter': {'variable': 't', 'units': 'K'},
#  'geography': {},
#  'vertical': {'level': 1000, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '0'},
#  'proc': {}}

# %% [markdown]
# With this method we can also inspect any [ecCodes GRIB namespace](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ):

# %%
ds[0].namespace("grib.ls")
# Out:
# {'grib.edition': 1,
#  'grib.centre': 'ecmf',
#  'grib.typeOfLevel': 'isobaricInhPa',
#  'grib.level': 1000,
#  'grib.dataDate': 20180801,
#  'grib.stepRange': '0',
#  'grib.dataType': 'an',
#  'grib.shortName': 't',
#  'grib.packingType': 'grid_simple',
#  'grib.gridType': 'regular_ll'}

# %%
ds[0].namespace("grib")
# Out:
# {'grib.ls': {'grib.edition': 1,
#   'grib.centre': 'ecmf',
#   'grib.typeOfLevel': 'isobaricInhPa',
#   'grib.level': 1000,
#   'grib.dataDate': 20180801,
#   'grib.stepRange': '0',
#   'grib.dataType': 'an',
#   'grib.shortName': 't',
#   'grib.packingType': 'grid_simple',
#   'grib.gridType': 'regular_ll'},
#  'grib.geography': {'grib.Ni': 12,
#   'grib.Nj': 7,
#   'grib.latitudeOfFirstGridPointInDegrees': 90.0,
#   'grib.longitudeOfFirstGridPointInDegrees': 0.0,
#   'grib.latitudeOfLastGridPointInDegrees': -90.0,
#   'grib.longitudeOfLastGridPointInDegrees': 330.0,
#   'grib.iScansNegatively': 0,
#   'grib.jScansPositively': 0,
#   'grib.jPointsAreConsecutive': 0,
#   'grib.jDirectionIncrementInDegrees': 30.0,
#   'grib.iDirectionIncrementInDegrees': 30.0,
#   'grib.gridType': 'regular_ll'},
#  'grib.mars': {'grib.domain': 'g',
#   'grib.levtype': 'pl',
#   'grib.levelist': 1000,
#   'grib.date': 20180801,
#   'grib.time': 1200,
#   'grib.step': 0,
#   'grib.param': 't',
#   'grib.class': 'od',
#   'grib.type': 'an',
#   'grib.stream': 'oper',
#   'grib.expver': '0001'},
#  'grib.parameter': {'grib.centre': 'ecmf',
#   'grib.paramId': 130,
#   'grib.units': 'K',
#   'grib.name': 'Temperature',
#   'grib.shortName': 't'},
#  'grib.statistics': {'grib.max': 320.5641784667969,
#   'grib.min': 240.56417846679688,
#   'grib.avg': 279.70703560965404,
#   'grib.sd': 19.67421739058438,
#   'grib.skew': -0.7312302105044428,
#   'grib.kurt': -0.16904561574741717,
#   'grib.const': 0.0},
#  'grib.time': {'grib.dataDate': 20180801,
#   'grib.dataTime': 1200,
#   'grib.stepUnits': 1,
#   'grib.stepType': 'instant',
#   'grib.stepRange': '0',
#   'grib.startStep': 0,
#   'grib.endStep': 0,
#   'grib.validityDate': 20180801,
#   'grib.validityTime': 1200},
#  'grib.vertical': {'grib.typeOfLevel': 'isobaricInhPa', 'grib.level': 1000}}

# %% [markdown]
# ### Using dump

# %% [raw]
# The :py:meth:`~data.readers.grib.codes.GribField.dump` method generates a tabbed interface with the fields content in a Jupyter notebook providing some interactivity.
#
# By default all the field namespaces are dumped.

# %%
ds[0].dump()
# Out:
# {'parameter': {'variable': 't', 'units': 'K'},
#  'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'vertical': {'level': 1000, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '0'}}

# %% [markdown]
# We can dump a given namespace or namespaces.

# %%
ds[0].dump("parameter")
# Out:
# {'parameter': {'variable': 't', 'units': 'K'}}

# %%
ds[0].dump(["parameter", "time"])
# Out:
# {'parameter': {'variable': 't', 'units': 'K'},
#  'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)}}

# %% [raw]
# The [ecCodes GRIB namespaces](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ) can also be used in  :py:meth:`~data.readers.grib.codes.GribField.dump`.

# %%
# get all the ecCodes GRIB namespaces
ds[0].dump("grib")
# Out:
# {'grib.ls': {'grib.edition': 1,
#   'grib.centre': 'ecmf',
#   'grib.typeOfLevel': 'isobaricInhPa',
#   'grib.level': 1000,
#   'grib.dataDate': 20180801,
#   'grib.stepRange': '0',
#   'grib.dataType': 'an',
#   'grib.shortName': 't',
#   'grib.packingType': 'grid_simple',
#   'grib.gridType': 'regular_ll'},
#  'grib.geography': {'grib.Ni': 12,
#   'grib.Nj': 7,
#   'grib.latitudeOfFirstGridPointInDegrees': 90.0,
#   'grib.longitudeOfFirstGridPointInDegrees': 0.0,
#   'grib.latitudeOfLastGridPointInDegrees': -90.0,
#   'grib.longitudeOfLastGridPointInDegrees': 330.0,
#   'grib.iScansNegatively': 0,
#   'grib.jScansPositively': 0,
#   'grib.jPointsAreConsecutive': 0,
#   'grib.jDirectionIncrementInDegrees': 30.0,
#   'grib.iDirectionIncrementInDegrees': 30.0,
#   'grib.gridType': 'regular_ll'},
#  'grib.mars': {'grib.domain': 'g',
#   'grib.levtype': 'pl',
#   'grib.levelist': 1000,
#   'grib.date': 20180801,
#   'grib.time': 1200,
#   'grib.step': 0,
#   'grib.param': 't',
#   'grib.class': 'od',
#   'grib.type': 'an',
#   'grib.stream': 'oper',
#   'grib.expver': '0001'},
#  'grib.parameter': {'grib.centre': 'ecmf',
#   'grib.paramId': 130,
#   'grib.units': 'K',
#   'grib.name': 'Temperature',
#   'grib.shortName': 't'},
#  'grib.statistics': {'grib.max': 320.5641784667969,
#   'grib.min': 240.56417846679688,
#   'grib.avg': 279.70703560965404,
#   'grib.sd': 19.67421739058438,
#   'grib.skew': -0.7312302105044428,
#   'grib.kurt': -0.16904561574741717,
#   'grib.const': 0.0},
#  'grib.time': {'grib.dataDate': 20180801,
#   'grib.dataTime': 1200,
#   'grib.stepUnits': 1,
#   'grib.stepType': 'instant',
#   'grib.stepRange': '0',
#   'grib.startStep': 0,
#   'grib.endStep': 0,
#   'grib.validityDate': 20180801,
#   'grib.validityTime': 1200},
#  'grib.vertical': {'grib.typeOfLevel': 'isobaricInhPa', 'grib.level': 1000}}

# %%
# get a given ecCodes GRIB namespace
ds[0].dump("grib.ls")
# Out:
# {'grib.ls': {'grib.edition': 1,
#   'grib.centre': 'ecmf',
#   'grib.typeOfLevel': 'isobaricInhPa',
#   'grib.level': 1000,
#   'grib.dataDate': 20180801,
#   'grib.stepRange': '0',
#   'grib.dataType': 'an',
#   'grib.shortName': 't',
#   'grib.packingType': 'grid_simple',
#   'grib.gridType': 'regular_ll'}}
