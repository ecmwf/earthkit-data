# %% [markdown]
# ## GRIB: listing contents

# %% [raw]
# We will work with a GRIB file containing 6 messages. First we ensure the example file is available, then read the file with :ref:`from_source() <data-sources-file>`.

# %%
import earthkit.data as ekd
ekd.download_example_file("test6.grib")
# Out:
# /Users/cgr/venv/dev/lib/python3.13/site-packages/array_api_compat/torch/_info.py:361: UserWarning: 'mkldnn' is no longer used as device type. So torch.device('mkldnn') will be deprecated and removed in the future. Please use other valid device types instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/c10/core/Device.cpp:42.)
#   a = torch.empty((0,), device=torch.device(device_name, index=i))

# %%
ds = ekd.from_source("file", "test6.grib")

# %% [markdown]
# ### Using head(), tail() and ls()

# %% [raw]
# All these methods (:py:meth:`~data.readers.grib.index.GribFieldList.head`, :py:meth:`~data.readers.grib.index.GribFieldList.tail` and :py:meth:`~data.readers.grib.index.GribFieldList.ls`) take the same set of keyword arguments:
#
# - n: number of messages to list
# - keys: the metadata keys to dump
# - extra_keys: extra keys of top of the default set of keys
# - namespace: the namespace(s) to use

# %% [markdown]
# #### head()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.head` displays the first 5 messages by default:

# %%
ds.head()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll

# %% [markdown]
# The number of fields can be passed as an argument:

# %%
ds.head(2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %%
ds.head(n=2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %% [markdown]
# ##### Keys and extra keys

# %% [markdown]
# We can use our own list of keys instead of the default ones.

# %%
ds.head(keys="base_datetime")
# Out:
#         base_datetime
# 0 2018-08-01 12:00:00
# 1 2018-08-01 12:00:00
# 2 2018-08-01 12:00:00
# 3 2018-08-01 12:00:00
# 4 2018-08-01 12:00:00

# %%
ds.head(keys=["base_datetime", "level"])
# Out:
#         base_datetime  level
# 0 2018-08-01 12:00:00   1000
# 1 2018-08-01 12:00:00   1000
# 2 2018-08-01 12:00:00   1000
# 3 2018-08-01 12:00:00    850
# 4 2018-08-01 12:00:00    850

# %% [markdown]
# The default list of keys can be extended:

# %%
ds.head(extra_keys="units")
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type    units
# 0      pressure      0  regular_ll        K
# 1      pressure      0  regular_ll  m s**-1
# 2      pressure      0  regular_ll  m s**-1
# 3      pressure      0  regular_ll        K
# 4      pressure      0  regular_ll  m s**-1

# %% [markdown]
# ##### Namespaces

# %% [markdown]
# The keys can be taken from an earthkit namespace:

# %%
ds.head(namespace="time")
# Out:
#         base_datetime      valid_datetime   step
# 0 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 1 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 2 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 3 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days
# 4 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days

# %%
ds.head(namespace=["parameter", "time"])
# Out:
#         base_datetime      valid_datetime   step variable    units
# 0 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        t        K
# 1 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        u  m s**-1
# 2 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        v  m s**-1
# 3 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        t        K
# 4 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days        u  m s**-1

# %% [markdown]
# It is possible to use any [ecCodes GRIB namespace](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ):

# %%
ds.head(namespace="grib.ls")
# Out:
#    edition centre    typeOfLevel  level  dataDate stepRange dataType  \
# 0        1   ecmf  isobaricInhPa   1000  20180801         0       an
# 1        1   ecmf  isobaricInhPa   1000  20180801         0       an
# 2        1   ecmf  isobaricInhPa   1000  20180801         0       an
# 3        1   ecmf  isobaricInhPa    850  20180801         0       an
# 4        1   ecmf  isobaricInhPa    850  20180801         0       an
#
#   shortName  packingType    gridType
# 0         t  grid_simple  regular_ll
# 1         u  grid_simple  regular_ll
# 2         v  grid_simple  regular_ll
# 3         t  grid_simple  regular_ll
# 4         u  grid_simple  regular_ll

# %% [markdown]
# #### tail()

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.tail` displays the last 5 messages by default:

# %%
ds.tail(5)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 3        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll

# %% [markdown]
# #### ls()

# %% [raw]
# By default :py:meth:`~data.readers.grib.index.GribFieldList.ls` lists all the fields:

# %%
ds.ls()
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 2        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 3        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 4        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 5        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll
# 2      pressure      0  regular_ll
# 3      pressure      0  regular_ll
# 4      pressure      0  regular_ll
# 5      pressure      0  regular_ll

# %% [markdown]
# The number of fields to list can also be specified:

# %%
ds.ls(2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        t 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
# 1        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days   1000
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %%
ds.ls(-2)
# Out:
#   variable      valid_datetime       base_datetime   step  level  \
# 0        u 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
# 1        v 2018-08-01 12:00:00 2018-08-01 12:00:00 0 days    850
#
#   vertical_type member   grid_type
# 0      pressure      0  regular_ll
# 1      pressure      0  regular_ll

# %% [markdown]
# ### Using describe

# %% [raw]
# With :py:meth:`~data.readers.grib.index.GribFieldList.describe` the contents of the fieldlist is presented in a concise way.

# %%
ds.describe()
# Out:
# <style type="text/css">
# #T_0fe29 th {
#   text-align: left;
# }
# </style>
# <table id="T_0fe29">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fe29_level0_col0" class="col_heading level0 col0" >shortName</th>
#       <th id="T_0fe29_level0_col1" class="col_heading level0 col1" >typeOfLevel</th>
#       <th id="T_0fe29_level0_col2" class="col_heading level0 col2" >level</th>
#       <th id="T_0fe29_level0_col3" class="col_heading level0 col3" >date</th>
#       <th id="T_0fe29_level0_col4" class="col_heading level0 col4" >time</th>
#       <th id="T_0fe29_level0_col5" class="col_heading level0 col5" >stepRange</th>
#       <th id="T_0fe29_level0_col6" class="col_heading level0 col6" >number</th>
#       <th id="T_0fe29_level0_col7" class="col_heading level0 col7" >paramId</th>
#       <th id="T_0fe29_level0_col8" class="col_heading level0 col8" >class</th>
#       <th id="T_0fe29_level0_col9" class="col_heading level0 col9" >stream</th>
#       <th id="T_0fe29_level0_col10" class="col_heading level0 col10" >type</th>
#       <th id="T_0fe29_level0_col11" class="col_heading level0 col11" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [raw]
# :py:meth:`~data.readers.grib.index.GribFieldList.describe` can be used with a given parameter (defined by variable or paramId):

# %%
ds.describe("t")
# Out:
# <style type="text/css">
# #T_49e3a th {
#   text-align: left;
# }
# #T_49e3a_row0_col0, #T_49e3a_row1_col0, #T_49e3a_row2_col0, #T_49e3a_row3_col0, #T_49e3a_row4_col0, #T_49e3a_row5_col0, #T_49e3a_row6_col0, #T_49e3a_row7_col0, #T_49e3a_row8_col0, #T_49e3a_row9_col0, #T_49e3a_row10_col0, #T_49e3a_row11_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_49e3a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49e3a_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_49e3a_row0_col0" class="data row0 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_49e3a_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_49e3a_row2_col0" class="data row2 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_49e3a_row3_col0" class="data row3 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_49e3a_row4_col0" class="data row4 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row5" class="row_heading level0 row5" >stepRange</th>
#       <td id="T_49e3a_row5_col0" class="data row5 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row6" class="row_heading level0 row6" >number</th>
#       <td id="T_49e3a_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row7" class="row_heading level0 row7" >paramId</th>
#       <td id="T_49e3a_row7_col0" class="data row7 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_49e3a_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row9" class="row_heading level0 row9" >stream</th>
#       <td id="T_49e3a_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row10" class="row_heading level0 row10" >type</th>
#       <td id="T_49e3a_row10_col0" class="data row10 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_49e3a_level0_row11" class="row_heading level0 row11" >experimentVersionNumber</th>
#       <td id="T_49e3a_row11_col0" class="data row11 col0" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
ds.describe(131)
# Out:
# <style type="text/css">
# #T_4b9e9 th {
#   text-align: left;
# }
# #T_4b9e9_row0_col0, #T_4b9e9_row1_col0, #T_4b9e9_row2_col0, #T_4b9e9_row3_col0, #T_4b9e9_row4_col0, #T_4b9e9_row5_col0, #T_4b9e9_row6_col0, #T_4b9e9_row7_col0, #T_4b9e9_row8_col0, #T_4b9e9_row9_col0, #T_4b9e9_row10_col0, #T_4b9e9_row11_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_4b9e9">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b9e9_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_4b9e9_row0_col0" class="data row0 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_4b9e9_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_4b9e9_row2_col0" class="data row2 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_4b9e9_row3_col0" class="data row3 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_4b9e9_row4_col0" class="data row4 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row5" class="row_heading level0 row5" >stepRange</th>
#       <td id="T_4b9e9_row5_col0" class="data row5 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row6" class="row_heading level0 row6" >number</th>
#       <td id="T_4b9e9_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row7" class="row_heading level0 row7" >paramId</th>
#       <td id="T_4b9e9_row7_col0" class="data row7 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_4b9e9_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row9" class="row_heading level0 row9" >stream</th>
#       <td id="T_4b9e9_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row10" class="row_heading level0 row10" >type</th>
#       <td id="T_4b9e9_row10_col0" class="data row10 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_4b9e9_level0_row11" class="row_heading level0 row11" >experimentVersionNumber</th>
#       <td id="T_4b9e9_row11_col0" class="data row11 col0" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Getting namespaces

# %% [markdown]
# The field namespaces can be collected as a dict via the namespace() method:

# %%
ds[0].namespace("parameter")
# Out:
# {'variable': 't', 'units': 'K'}

# %%
ds[0].namespace(["parameter", "time"])
# Out:
# {'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'parameter': {'variable': 't', 'units': 'K'}}

# %%
ds[0].namespace()
# Out:
# {'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'parameter': {'variable': 't', 'units': 'K'},
#  'geography': {},
#  'vertical': {'level': 1000, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '0'},
#  'proc': {}}

# %% [markdown]
# With this method we can also inspect any [ecCodes GRIB namespace](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ):

# %%
ds[0].namespace("grib.ls")
# Out:
# {'edition': 1,
#  'centre': 'ecmf',
#  'typeOfLevel': 'isobaricInhPa',
#  'level': 1000,
#  'dataDate': 20180801,
#  'stepRange': '0',
#  'dataType': 'an',
#  'shortName': 't',
#  'packingType': 'grid_simple',
#  'gridType': 'regular_ll'}

# %%
ds[0].namespace("grib")
# Out:
# {'grib.ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 1000,
#   'dataDate': 20180801,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 't',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'grib.geography': {'Ni': 12,
#   'Nj': 7,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPointInDegrees': 330.0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 30.0,
#   'iDirectionIncrementInDegrees': 30.0,
#   'gridType': 'regular_ll'},
#  'grib.mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 1000,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 't',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'},
#  'grib.parameter': {'centre': 'ecmf',
#   'paramId': 130,
#   'units': 'K',
#   'name': 'Temperature',
#   'shortName': 't'},
#  'grib.statistics': {'max': 320.5641784667969,
#   'min': 240.56417846679688,
#   'avg': 279.70703560965404,
#   'sd': 19.67421739058438,
#   'skew': -0.7312302105044428,
#   'kurt': -0.16904561574741717,
#   'const': 0.0},
#  'grib.time': {'dataDate': 20180801,
#   'dataTime': 1200,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'validityDate': 20180801,
#   'validityTime': 1200},
#  'grib.vertical': {'typeOfLevel': 'isobaricInhPa', 'level': 1000}}

# %% [markdown]
# ### Using dump

# %% [raw]
# The :py:meth:`~data.readers.grib.codes.GribField.dump` method generates a tabbed interface with the fields content in a Jupyter notebook providing some interactivity.
#
# By default all the field namespaces are dumped.

# %%
ds[0].dump()
# Out:
# {'parameter': {'variable': 't', 'units': 'K'},
#  'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)},
#  'vertical': {'level': 1000, 'level_type': 'pressure', 'units': 'hPa'},
#  'ensemble': {'member': '0'}}

# %% [markdown]
# We can dump a given namespace or namespaces.

# %%
ds[0].dump("parameter")
# Out:
# {'parameter': {'variable': 't', 'units': 'K'}}

# %%
ds[0].dump(["parameter", "time"])
# Out:
# {'parameter': {'variable': 't', 'units': 'K'},
#  'time': {'base_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'valid_datetime': datetime.datetime(2018, 8, 1, 12, 0),
#   'step': datetime.timedelta(0)}}

# %% [raw]
# The [ecCodes GRIB namespaces](https://confluence.ecmwf.int/display/UDOC/What+are+namespaces+-+ecCodes+GRIB+FAQ) can also be used in  :py:meth:`~data.readers.grib.codes.GribField.dump`.

# %%
# get all the ecCodes GRIB namespaces
ds[0].dump("grib")
# Out:
# {'grib.ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 1000,
#   'dataDate': 20180801,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 't',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'grib.geography': {'Ni': 12,
#   'Nj': 7,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPointInDegrees': 330.0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 30.0,
#   'iDirectionIncrementInDegrees': 30.0,
#   'gridType': 'regular_ll'},
#  'grib.mars': {'domain': 'g',
#   'levtype': 'pl',
#   'levelist': 1000,
#   'date': 20180801,
#   'time': 1200,
#   'step': 0,
#   'param': 't',
#   'class': 'od',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0001'},
#  'grib.parameter': {'centre': 'ecmf',
#   'paramId': 130,
#   'units': 'K',
#   'name': 'Temperature',
#   'shortName': 't'},
#  'grib.statistics': {'max': 320.5641784667969,
#   'min': 240.56417846679688,
#   'avg': 279.70703560965404,
#   'sd': 19.67421739058438,
#   'skew': -0.7312302105044428,
#   'kurt': -0.16904561574741717,
#   'const': 0.0},
#  'grib.time': {'dataDate': 20180801,
#   'dataTime': 1200,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'validityDate': 20180801,
#   'validityTime': 1200},
#  'grib.vertical': {'typeOfLevel': 'isobaricInhPa', 'level': 1000}}

# %%
# get a given ecCodes GRIB namespace
ds[0].dump("grib.ls")
# Out:
# {'grib.ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'isobaricInhPa',
#   'level': 1000,
#   'dataDate': 20180801,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 't',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'}}
