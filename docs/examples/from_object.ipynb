# %% [markdown]
# ## Reading data from objects

# %%
import logging
import xarray as xr
import numpy as np

from earthkit import data

# %%
demo_ndarray = np.random.rand(10,10)*10.
demo_lats = np.arange(0,91,10)
demo_lons = np.arange(0,91,10)
# demo_ndarray

# %%
demo_da = xr.DataArray(
    demo_ndarray, name="temperature", dims={'latitude':demo_lats, 'longitude': demo_lons},
    attrs={'units': 'Celsius', "standard_name": "air_temperature"}
)
demo_ds = demo_da.to_dataset().assign_attrs({'purpose': 'Demonstration', 'source': 'EarthkitExamples'})

demo_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (latitude: 10, longitude: 10)
# Dimensions without coordinates: latitude, longitude
# Data variables:
#     temperature  (latitude, longitude) float64 0.05828 2.912 ... 2.748 2.558
# Attributes:
#     purpose:  Demonstration
#     source:   EarthkitExamples

# %%
ek_nd = data.from_object(demo_ndarray)
ek_nd.to_numpy()
# Out:
# array([[0.05827872, 2.91154962, 2.92894463, 6.28009786, 9.39347282,
#         2.37047484, 1.98624965, 3.57400816, 8.15354063, 4.36849505],
#        [8.38969588, 9.21303089, 2.43139474, 4.13165809, 0.79307006,
#         8.82290079, 2.34814344, 8.12333515, 0.68332288, 3.1194494 ],
#        [6.40722454, 2.97737132, 3.0069401 , 5.97770113, 1.33622858,
#         7.85575739, 4.40375609, 3.57648129, 6.65829491, 2.41468629],
#        [5.91029461, 3.55563487, 9.50799586, 5.10092219, 0.3146072 ,
#         2.05616751, 1.06915918, 3.12765743, 5.80442294, 3.49504726],
#        [4.78020937, 7.33478496, 0.40963729, 8.70348007, 6.08962379,
#         1.46078601, 7.29671525, 2.63720008, 2.4453612 , 8.8977739 ],
#        [8.82604053, 2.85740327, 4.16631075, 3.88215929, 8.32662553,
#         7.42049282, 8.21414252, 6.74502541, 3.04233978, 1.38716398],
#        [6.33520038, 6.43419955, 0.17072537, 5.10363802, 6.77263183,
#         7.07695924, 9.35023018, 3.96740433, 5.49837843, 0.31239375],
#        [3.55184812, 4.51771137, 0.96461098, 3.88987227, 0.36413125,
#         7.04907769, 8.70467832, 8.38364842, 5.33254428, 8.61093043],
#        [3.53023191, 6.65667325, 6.42738161, 9.86803322, 7.41070787,
#         2.32698453, 5.06438867, 5.18241816, 8.02464439, 5.98752759],
#        [3.21063753, 4.82812247, 3.8936196 , 7.1947277 , 9.36070759,
#         4.73650954, 2.77944049, 2.8212291 , 2.74758957, 2.5576353 ]])

# %%
ek_da = data.from_object(demo_da)
ek_da.to_pandas()
# Out:
#                     temperature
# latitude longitude
# 0        0             0.058279
#          1             2.911550
#          2             2.928945
#          3             6.280098
#          4             9.393473
# ...                         ...
# 9        5             4.736510
#          6             2.779440
#          7             2.821229
#          8             2.747590
#          9             2.557635
#
# [100 rows x 1 columns]

# %%
ek_ds = data.from_object(demo_ds)
ek_ds.to_pandas()
# Out:
#                     temperature
# latitude longitude
# 0        0             0.058279
#          1             2.911550
#          2             2.928945
#          3             6.280098
#          4             9.393473
# ...                         ...
# 9        5             4.736510
#          6             2.779440
#          7             2.821229
#          8             2.747590
#          9             2.557635
#
# [100 rows x 1 columns]
