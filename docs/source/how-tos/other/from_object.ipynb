# %% [markdown]
# ## Reading data from objects

# %%
import numpy as np
import xarray as xr

import earthkit.data as ekd

# %% [raw]
# We can read Python objects into an earthkit-data object using :func:`from_object`.

# %% [markdown]
# First, we create Numpy and Xarray input data.

# %%
# demo ndarray
demo_ndarray = np.random.rand(10, 10) * 10.0
demo_lats = np.arange(0, 91, 10)
demo_lons = np.arange(0, 91, 10)

# demo Xarray
demo_da = xr.DataArray(
    demo_ndarray,
    name="temperature",
    dims={"latitude": demo_lats, "longitude": demo_lons},
    attrs={"units": "Celsius", "standard_name": "air_temperature"},
)
demo_ds = demo_da.to_dataset().assign_attrs({"purpose": "Demonstration", "source": "EarthkitExamples"})

demo_ds
# Out:
# <xarray.Dataset> Size: 800B
# Dimensions:      (latitude: 10, longitude: 10)
# Dimensions without coordinates: latitude, longitude
# Data variables:
#     temperature  (latitude, longitude) float64 800B 4.731 6.136 ... 8.372 5.136
# Attributes:
#     purpose:  Demonstration
#     source:   EarthkitExamples

# %% [markdown]
# ## Numpy input

# %%
d = ekd.from_object(demo_ndarray)
d

# %%
d.to_numpy()
# Out:
# array([[4.73124422, 6.13623834, 8.57073664, 2.08835836, 3.90606196,
#         0.54847908, 1.90416285, 9.98431349, 5.1833568 , 7.04702453],
#        [6.61015808, 5.65906805, 2.12519224, 6.97370376, 8.59050762,
#         2.95556606, 7.65509745, 5.7246794 , 6.10430917, 9.48281467],
#        [6.97010633, 1.14613531, 8.02567947, 6.84184349, 5.91308076,
#         6.70122376, 1.82584456, 3.73058165, 0.48796005, 3.20607957],
#        [7.05750217, 5.78655271, 7.12051478, 4.21566202, 5.21124654,
#         2.24633025, 3.02109279, 7.61794178, 2.13527108, 7.50759501],
#        [6.52827153, 6.20219776, 7.00458098, 7.02613466, 7.14146174,
#         7.42806005, 3.87452898, 8.74654699, 2.10623829, 1.31583712],
#        [6.15947049, 7.78293456, 7.57194152, 0.11775311, 7.4913719 ,
#         4.9970285 , 4.69835701, 7.58431571, 3.70495212, 5.16745585],
#        [3.96415308, 8.30768497, 8.18408498, 0.53347706, 1.444869  ,
#         8.60669407, 2.34302918, 8.22355906, 2.35169722, 8.60608378],
#        [2.32763849, 9.75987779, 1.75603864, 4.73788669, 8.56244574,
#         0.31232764, 6.32524264, 8.08788262, 0.36046855, 5.53043007],
#        [1.20855227, 4.16041487, 0.72419371, 1.63784098, 9.6142344 ,
#         1.73244572, 7.15609499, 6.40409556, 4.59863442, 3.04651323],
#        [8.11017844, 4.86777452, 1.98319863, 4.50254629, 1.55480246,
#         3.37599427, 4.25319624, 1.34339692, 8.37170481, 5.13586852]])

# %% [markdown]
# ## Xarray input

# %%
d = ekd.from_object(demo_da)
d

# %%
d.to_xarray()
# Out:
# <xarray.DataArray 'temperature' (latitude: 10, longitude: 10)> Size: 800B
# array([[4.73124422, 6.13623834, 8.57073664, 2.08835836, 3.90606196,
#         0.54847908, 1.90416285, 9.98431349, 5.1833568 , 7.04702453],
#        [6.61015808, 5.65906805, 2.12519224, 6.97370376, 8.59050762,
#         2.95556606, 7.65509745, 5.7246794 , 6.10430917, 9.48281467],
#        [6.97010633, 1.14613531, 8.02567947, 6.84184349, 5.91308076,
#         6.70122376, 1.82584456, 3.73058165, 0.48796005, 3.20607957],
#        [7.05750217, 5.78655271, 7.12051478, 4.21566202, 5.21124654,
#         2.24633025, 3.02109279, 7.61794178, 2.13527108, 7.50759501],
#        [6.52827153, 6.20219776, 7.00458098, 7.02613466, 7.14146174,
#         7.42806005, 3.87452898, 8.74654699, 2.10623829, 1.31583712],
#        [6.15947049, 7.78293456, 7.57194152, 0.11775311, 7.4913719 ,
#         4.9970285 , 4.69835701, 7.58431571, 3.70495212, 5.16745585],
#        [3.96415308, 8.30768497, 8.18408498, 0.53347706, 1.444869  ,
#         8.60669407, 2.34302918, 8.22355906, 2.35169722, 8.60608378],
#        [2.32763849, 9.75987779, 1.75603864, 4.73788669, 8.56244574,
#         0.31232764, 6.32524264, 8.08788262, 0.36046855, 5.53043007],
#        [1.20855227, 4.16041487, 0.72419371, 1.63784098, 9.6142344 ,
#         1.73244572, 7.15609499, 6.40409556, 4.59863442, 3.04651323],
#        [8.11017844, 4.86777452, 1.98319863, 4.50254629, 1.55480246,
#         3.37599427, 4.25319624, 1.34339692, 8.37170481, 5.13586852]])
# Dimensions without coordinates: latitude, longitude
# Attributes:
#     units:          Celsius
#     standard_name:  air_temperature

# %%
d.to_pandas()
# Out:
#                     temperature
# latitude longitude
# 0        0             4.731244
#          1             6.136238
#          2             8.570737
#          3             2.088358
#          4             3.906062
# ...                         ...
# 9        5             3.375994
#          6             4.253196
#          7             1.343397
#          8             8.371705
#          9             5.135869
#
# [100 rows x 1 columns]

# %%
d = ekd.from_object(demo_ds)
d

# %%
d.to_xarray()
# Out:
# <xarray.Dataset> Size: 800B
# Dimensions:      (latitude: 10, longitude: 10)
# Dimensions without coordinates: latitude, longitude
# Data variables:
#     temperature  (latitude, longitude) float64 800B 4.731 6.136 ... 8.372 5.136
# Attributes:
#     purpose:  Demonstration
#     source:   EarthkitExamples

# %%
d.to_pandas()
# Out:
#                     temperature
# latitude longitude
# 0        0             4.731244
#          1             6.136238
#          2             8.570737
#          3             2.088358
#          4             3.906062
# ...                         ...
# 9        5             3.375994
#          6             4.253196
#          7             1.343397
#          8             8.371705
#          9             5.135869
#
# [100 rows x 1 columns]
