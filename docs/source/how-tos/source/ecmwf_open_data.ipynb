# %% [markdown]
# # Retrieving ECMWF open data

# %% [raw]
# The :ref:`ecmwf-open-data <data-sources-eod>` source provides access to the `ECMWF open data <https://www.ecmwf.int/en/forecasts/datasets/open-data>`_ .

# %%
import earthkit.data as ekd

d = ekd.from_source(
    "ecmwf-open-data",
    request=dict(param=["t", "gh"], levelist="500", step=[0, 24, 48]),
)
d
# Out:
# <multiple>:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# By downloading data from the ECMWF open data dataset, you agree to the terms: Attribution 4.0 International (CC BY 4.0). Please attribute ECMWF when downloading this data.
# GribData(path=/var/folders/93/w0p869rx17q98wxk83gn9ys40000gn/T/earthkit-data-cgr/e-odretriever-f16112c6a02c9bd8dbcf06c315b9e887138e5b4fe969ea4f8bce9d58980eaa10.cache)

# %%
d.to_fieldlist().ls()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  t 2026-03-29 06:00:00 2026-03-29 06:00:00    0 days
# 1                 gh 2026-03-29 06:00:00 2026-03-29 06:00:00    0 days
# 2                  t 2026-03-30 06:00:00 2026-03-29 06:00:00    1 days
# 3                 gh 2026-03-30 06:00:00 2026-03-29 06:00:00    1 days
# 4                  t 2026-03-31 06:00:00 2026-03-29 06:00:00    2 days
# 5                 gh 2026-03-31 06:00:00 2026-03-29 06:00:00    2 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0             500            pressure               0          regular_ll
# 1             500            pressure               0          regular_ll
# 2             500            pressure               0          regular_ll
# 3             500            pressure               0          regular_ll
# 4             500            pressure               0          regular_ll
# 5             500            pressure               0          regular_ll
