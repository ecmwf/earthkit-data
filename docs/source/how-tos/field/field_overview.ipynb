# %% [markdown]
# # Field overview

# %% [markdown]
# Please note that this notebook is still under development.

# %%
import earthkit.data as ekd

# %%
d = ekd.from_source("file", "../test.grib")
d
# Out:
# GribData(path=../test.grib)

# %%
f = d.to_fieldlist()[0]
f
# Out:
# Field(2t, 2020-05-13 12:00:00, 2020-05-13 12:00:00, 0:00:00, 0, surface, 0, regular_ll)
