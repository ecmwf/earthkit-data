# %%
from earthkit.data import from_source

ds = from_source("file", "../../examples/tuv_pl.grib", stream=True)

# %%
type(ds)
# Out:
# earthkit.data.indexing.stream.StreamFieldList

# %%
for f in ds:
    print(f.vertical.level)
# Out:
# 1000
# 1000
# 1000
# 850
# 850
# 850
# 700
# 700
# 700
# 500
# 500
# 500
# 400
# 400
# 400
# 300
# 300
# 300

# %%
for f in ds:
    print(f.level)
