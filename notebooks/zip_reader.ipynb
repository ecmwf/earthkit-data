# %%
import emohawk
SINGLE_NETCDF_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_single_netcdf.zip'
MULTI_NETCDF_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_multi_netcdf.zip'
MIXED_MULTI_NETCDF_ZIP_FILE = '../notebooks/data/ERA5_UK_mixed_multi_netcdf.zip'
INCOMPATIBLE_MULTI_NETCDF_ZIP_FILE = '../notebooks/data/ERA5_incompatible_mixed_multi_netcdf.zip'
SINGLE_GRIB_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_single_grib.zip'
MULTI_CSV_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_multi_csv.zip'
SINGLE_CSV_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_single_csv.zip'
MULTI_GRIB_ZIP_FILE = '../notebooks/data/ERA5_t2m_UK_multi_grib.zip'

# %%
data = emohawk.open(INCOMPATIBLE_MULTI_NETCDF_ZIP_FILE)
ds = data.to_xarray(concat=False)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 81, latitude: 81, time: 4)
# Coordinates:
#   * longitude  (longitude) float32 -15.0 -14.75 -14.5 -14.25 ... 4.5 4.75 5.0
#   * latitude   (latitude) float32 70.0 69.75 69.5 69.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2022-12-01 ... 2022-12-01T03:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 81), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-12-20 08:56:47 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
data = emohawk.open(SINGLE_NETCDF_ZIP_FILE)
data.to_xarray()

# %%
data = emohawk.open(MULTI_NETCDF_ZIP_FILE)
data.to_xarray(concat=False)
# Out:
# [<xarray.Dataset>
#  Dimensions:    (longitude: 81, latitude: 81, time: 1)
#  Coordinates:
#    * longitude  (longitude) float32 -15.0 -14.75 -14.5 -14.25 ... 4.5 4.75 5.0
#    * latitude   (latitude) float32 70.0 69.75 69.5 69.25 ... 50.5 50.25 50.0
#    * time       (time) datetime64[ns] 2022-12-01
#  Data variables:
#      t2m        (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 81), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2022-12-20 08:56:47 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  <xarray.Dataset>
#  Dimensions:    (longitude: 81, latitude: 81, time: 1)
#  Coordinates:
#    * longitude  (longitude) float32 -15.0 -14.75 -14.5 -14.25 ... 4.5 4.75 5.0
#    * latitude   (latitude) float32 70.0 69.75 69.5 69.25 ... 50.5 50.25 50.0
#    * time       (time) datetime64[ns] 2022-12-01T01:00:00
#  Data variables:
#      t2m        (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 81), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2022-12-20 08:56:50 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  <xarray.Dataset>
#  Dimensions:    (longitude: 81, latitude: 81, time: 1)
#  Coordinates:
#    * longitude  (longitude) float32 -15.0 -14.75 -14.5 -14.25 ... 4.5 4.75 5.0
#    * latitude   (latitude) float32 70.0 69.75 69.5 69.25 ... 50.5 50.25 50.0
#    * time       (time) datetime64[ns] 2022-12-01T02:00:00
#  Data variables:
#      t2m        (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 81), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2022-12-20 08:56:54 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  <xarray.Dataset>
#  Dimensions:    (longitude: 81, latitude: 81, time: 1)
#  Coordinates:
#    * longitude  (longitude) float32 -15.0 -14.75 -14.5 -14.25 ... 4.5 4.75 5.0
#    * latitude   (latitude) float32 70.0 69.75 69.5 69.25 ... 50.5 50.25 50.0
#    * time       (time) datetime64[ns] 2022-12-01T03:00:00
#  Data variables:
#      t2m        (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 81), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2022-12-20 08:56:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...]

# %%
data = emohawk.open(MIXED_MULTI_NETCDF_ZIP_FILE)
# data._content
ds = data.to_xarray(concat=True)
ds

# %%
data = emohawk.open(SINGLE_CSV_ZIP_FILE)
data.to_pandas()

# %%
# NOT YET IMPLEMENTED
# data = emohawk.open(MULTI_CSV_ZIP_FILE)
# data.to_pandas()

# %%
# NOT YET IMPLEMENTED
# data = emohawk.open(SINGLE_GRIB_ZIP_FILE)
# data.to_xarray()

# %%
# NOT YET IMPLEMENTED
# data = emohawk.open(MULTI_GRIB_ZIP_FILE, filter='*.grib')
# data.to_xarray(xarray_open_mfdataset_kwargs=dict(combine='nested', concat_dim='time'))
